# %% [markdown]
# ## PUDL Output to CSV

# %% [markdown]
# The output layer of PUDL compiles many tables and generates less normalized (more spreadsheet-like, less database-like) tables. Some of these output tables include derived values. If you want to see any of the processing that has been done to the original PUDL tables, check out `pudl/output` and `pudl/analysis/mcoe`.
#
# If you want to generate all of the csv's, you can press the ⏩ button or select 'Kernel > Resart & Run All'.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import sqlalchemy as sa
import pudl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Here we are generating the PUDL output object. Right now, it is set up with a monthly frequency (freq="MS"), but if you want an annual frequency you can change this to "AS". You can also constrain the data range with agruments like start_date="2012-01-01" and end_date="2017-12-31".

# %%
defaults = pudl.workspace.setup.get_defaults()
pudl_settings = pudl.workspace.setup.derive_paths(pudl_in=defaults["pudl_in"],
                                                  pudl_out=defaults["pudl_out"])
pudl_engine = sa.create_engine(pudl_settings["pudl_db"])
pudl_out = pudl.output.pudltabl.PudlTabl(pudl_engine, freq="MS")

# %% [markdown]
# Here is a list of the output objects elements that can be used to grab some of the compiled tables.

# %%
elements = [ x for x in dir(pudl_out) if ("__" not in x) and
            (x not in ['_dfs', 'freq','end_date','start_date','testing',]) ]
print(elements)
# Out:
# ['bf_eia923', 'bga', 'bga_eia860', 'capacity_factor', 'fbp_ferc1', 'frc_eia923', 'fuel_cost', 'fuel_ferc1', 'gen_eia923', 'gens_eia860', 'gf_eia923', 'hr_by_gen', 'hr_by_unit', 'mcoe', 'own_eia860', 'plants_eia860', 'plants_steam_ferc1', 'pu_eia860', 'pu_ferc1', 'pudl_engine', 'utils_eia860']

# %% [markdown]
# ## CSV export for output tables

# %% [markdown]
# Below we'll generate csv's for each of the pudl output tables. These should show up in this folder. If you want to see or select any records from any of the tables, there are examples at the end of this notebook.

# %% [markdown]
# ### FERC 1 Tables

# %%
# Plant Utility Associations for FERC Form 1
pu_ferc1_df = pudl_out.pu_ferc1()
pu_ferc1_df.to_csv('plant_utility_associations_ferc1.csv', index=False)

# Steam Plants FERC1
plants_steam_ferc1_df = pudl_out.plants_steam_ferc1()
plants_steam_ferc1_df.to_csv('plants_steam_ferc1.csv', index=False)

# Fuel FERC1
fuel_ferc1_df = pudl_out.fuel_ferc1()
fuel_ferc1_df.to_csv('fuel_ferc1.csv', index=False)

# Fuel by Plant FERC1
# This is a derived output that aggregates fuel_ferc1 on a per-plant basis:
fbc_ferc1_df = pudl_out.fbp_ferc1()
fbc_ferc1_df.to_csv('fuel_by_plant_ferc1.csv', index=False)

# %% [markdown]
# ### EIA 860 Tables

# %%
# Plants EIA 860
plants_eia860_df = pudl_out.plants_eia860()
plants_eia860_df.to_csv('plants_eia860.csv', index=False)

# Utilities EIA 860
utils_eia860_df = pudl_out.utils_eia860()
utils_eia860_df.to_csv('utilities_eia860.csv', index=False)

# Plant Utility Associations EIA 860
pu_eia860_df = pudl_out.pu_eia860()
pu_eia860_df.to_csv('plant_utility_associations_eia860.csv', index=False)

# Generators EIA 860
gens_eia860_df = pudl_out.gens_eia860()
gens_eia860_df.to_csv('generators_eia860.csv', index=False)

# Ownership EIA 860
own_eia860_df = pudl_out.own_eia860()
own_eia860_df.to_csv('ownership_eia860.csv', index=False)

# %% [markdown]
# ### EIA 923 Tables

# %%
# Boiler Fuel from EIA 923
bf_eia923_df = pudl_out.bf_eia923()
bf_eia923_df.to_csv('boiler_fuel_eia923.csv', index=False)

# Fuel Receipts Costs EIA923
frc_eia923_df = pudl_out.frc_eia923()
frc_eia923_df.to_csv('fuel_receipts_costs_eia923.csv', index=False)

# Generation EIA 923
gen_eia923_df = pudl_out.gen_eia923()
gen_eia923_df.to_csv('generation_eia923.csv', index=False)

# Generation Fuel EIA 923
gf_eia923_df = pudl_out.gf_eia923()
gf_eia923_df.to_csv('generator_fuel_eia923.csv', index=False)

# %% [markdown]
# ### MCOE Derived Tables
# These tables feed into the compilation of MCOE by generator.

# %%
# Boiler Generator Associations
bga_df = pudl_out.bga()
bga_df.to_csv('boiler_generator_association.csv', index=False,)

# Heat Rate By Generator
hr_by_gen_df = pudl_out.hr_by_gen()
hr_by_gen_df.to_csv('heat_rate_by_gen.csv', index=False)

# Heat Rate By Unit
hr_by_unit_df = pudl_out.hr_by_unit()
hr_by_unit_df.to_csv('heat_rate_by_unit.csv', index=False)

# Capacity Factor
capacity_factor_df = pudl_out.capacity_factor()
capacity_factor_df.to_csv('capacity_factor.csv', index=False)

# Fuel Cost
fuel_cost_df = pudl_out.fuel_cost()
fuel_cost_df.to_csv('fuel_cost.csv', index=False)

# Marginal Cost of Electricity
mcoe_df = pudl_out.mcoe()
mcoe_df.to_csv('marginal_cost_of_electricity.csv', index=False)
# Out:
# /home/zane/miniconda3/envs/pudl/lib/python3.7/site-packages/pandas/core/frame.py:7116: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %% [markdown]
# ### Quick examples of how to use the dataframes

# %%
# head give the top records of the dataframe. 
# Without a number in the parentheses, it will return 5 records, but you can change the 3 below.
mcoe_df.head(3)
# Out:
#   report_date  plant_id_eia  plant_id_pudl  unit_id_pudl generator_id  \
# 0  2011-01-01             3             32             1            1
# 1  2011-02-01             3             32             1            1
# 2  2011-03-01             3             32             1            1
#
#   plant_name  utility_id_eia  utility_id_pudl      utility_name  \
# 0      Barry             195               18  Alabama Power Co
# 1      Barry             195               18  Alabama Power Co
# 2      Barry             195               18  Alabama Power Co
#
#   balancing_authority_code  ... technology_description  \
# 0                     SOCO  ...                   None
# 1                     SOCO  ...                   None
# 2                     SOCO  ...                   None
#
#    time_cold_shutdown_full_load_code  total_fuel_cost total_mmbtu  \
# 0                               None    552215.244806  130352.376
# 1                               None    938485.263136  214999.327
# 2                               None    668436.999202  157116.798
#
#   turbines_inverters_hydrokinetics turbines_num uprate_derate_completed_date  \
# 0                             None          NaN                         None
# 1                             None          NaN                         None
# 2                             None          NaN                         None
#
#   uprate_derate_during_year winter_capacity_mw winter_estimated_capability_mw
# 0                     False              138.0                           None
# 1                     False              138.0                           None
# 2                     False              138.0                           None
#
# [3 rows x 74 columns]

# %%
# this returns a random sample of records
mcoe_df.sample(5)
# Out:
#        report_date  plant_id_eia  plant_id_pudl  unit_id_pudl generator_id  \
# 81735   2017-04-01          2952            398             2            4
# 120112  2016-05-01          6190            511             2            2
# 51797   2011-06-01          1731           1141             1            1
# 137383  2011-08-01          8224            601             1            1
# 114998  2013-03-01          6077           2529             2            2
#
#                  plant_name  utility_id_eia  utility_id_pudl  \
# 81735              Muskogee           14063              237
# 120112  Brame Energy Center            3265               69
# 51797          Harbor Beach            5109               89
# 137383          North Valmy           17166              287
# 114998     Gerald Gentleman           13337             2562
#
#                           utility_name balancing_authority_code  ...  \
# 81735       Oklahoma Gas & Electric Co                     SWPP  ...
# 120112                 Cleco Power LLC                     MISO  ...
# 51797             DTE Electric Company                     MISO  ...
# 137383         Sierra Pacific Power Co                     NEVP  ...
# 114998  Nebraska Public Power District                     SWPP  ...
#
#          technology_description  time_cold_shutdown_full_load_code  \
# 81735   Conventional Steam Coal                               OVER
# 120112  Conventional Steam Coal                               OVER
# 51797                      None                               None
# 137383                     None                               None
# 114998                     None                               OVER
#
#         total_fuel_cost  total_mmbtu turbines_inverters_hydrokinetics  \
# 81735      5.988862e+06  3024677.830                             None
# 120112     3.475791e+06  1629280.222                             None
# 51797      5.016410e+05   166687.260                             None
# 137383     9.333487e+05   376602.246                             None
# 114998     5.719361e+06  4564226.260                             None
#
#        turbines_num uprate_derate_completed_date uprate_derate_during_year  \
# 81735           NaN                         None                     False
# 120112          NaN                         None                     False
# 51797           NaN                         None                     False
# 137383          NaN                         None                     False
# 114998          NaN                         None                     False
#
#        winter_capacity_mw winter_estimated_capability_mw
# 81735               493.0                           None
# 120112              493.0                           None
# 51797               103.0                           None
# 137383              254.0                           None
# 114998              700.0                           None
#
# [5 rows x 74 columns]

# %%
# if you care about a specifc plant and you know the plant id from EIA, you can select just that plant
mcoe_df[mcoe_df['plant_id_eia'] == 117]
# Out:
#      report_date  plant_id_eia  plant_id_pudl  unit_id_pudl generator_id  \
# 4264  2014-05-01           117            736             1         C4-1
# 4265  2014-06-01           117            736             1         C4-1
# 4266  2014-07-01           117            736             1         C4-1
# 4267  2014-08-01           117            736             1         C4-1
# 4268  2014-09-01           117            736             1         C4-1
# ...          ...           ...            ...           ...          ...
# 4543  2017-08-01           117            736             5           3B
# 4544  2017-09-01           117            736             5           3B
# 4545  2017-10-01           117            736             5           3B
# 4546  2017-11-01           117            736             5           3B
# 4547  2017-12-01           117            736             5           3B
#
#         plant_name  utility_id_eia  utility_id_pudl  \
# 4264  West Phoenix             803               31
# 4265  West Phoenix             803               31
# 4266  West Phoenix             803               31
# 4267  West Phoenix             803               31
# 4268  West Phoenix             803               31
# ...            ...             ...              ...
# 4543  West Phoenix             803               31
# 4544  West Phoenix             803               31
# 4545  West Phoenix             803               31
# 4546  West Phoenix             803               31
# 4547  West Phoenix             803               31
#
#                    utility_name balancing_authority_code  ...  \
# 4264  Arizona Public Service Co                     AZPS  ...
# 4265  Arizona Public Service Co                     AZPS  ...
# 4266  Arizona Public Service Co                     AZPS  ...
# 4267  Arizona Public Service Co                     AZPS  ...
# 4268  Arizona Public Service Co                     AZPS  ...
# ...                         ...                      ...  ...
# 4543  Arizona Public Service Co                     AZPS  ...
# 4544  Arizona Public Service Co                     AZPS  ...
# 4545  Arizona Public Service Co                     AZPS  ...
# 4546  Arizona Public Service Co                     AZPS  ...
# 4547  Arizona Public Service Co                     AZPS  ...
#
#                 technology_description  time_cold_shutdown_full_load_code  \
# 4264  Natural Gas Fired Combined Cycle                                 1H
# 4265  Natural Gas Fired Combined Cycle                                 1H
# 4266  Natural Gas Fired Combined Cycle                                 1H
# 4267  Natural Gas Fired Combined Cycle                                 1H
# 4268  Natural Gas Fired Combined Cycle                                 1H
# ...                                ...                                ...
# 4543  Natural Gas Fired Combined Cycle                                 1H
# 4544  Natural Gas Fired Combined Cycle                                 1H
# 4545  Natural Gas Fired Combined Cycle                                 1H
# 4546  Natural Gas Fired Combined Cycle                                 1H
# 4547  Natural Gas Fired Combined Cycle                                 1H
#
#       total_fuel_cost total_mmbtu turbines_inverters_hydrokinetics  \
# 4264         0.000000       0.000                             None
# 4265         0.000000       0.000                             None
# 4266    693496.037720  125112.040                             None
# 4267    666648.631488  131852.973                             None
# 4268    304980.269322   59776.611                             None
# ...               ...         ...                              ...
# 4543    797716.817920  214902.160                             None
# 4544    635049.067521  169301.271                             None
# 4545    583309.638016  177190.048                             None
# 4546    150729.049152   41776.344                             None
# 4547    725926.677280  206698.940                             None
#
#      turbines_num uprate_derate_completed_date uprate_derate_during_year  \
# 4264          NaN                         None                     False
# 4265          NaN                         None                     False
# 4266          NaN                         None                     False
# 4267          NaN                         None                     False
# 4268          NaN                         None                     False
# ...           ...                          ...                       ...
# 4543          NaN                         None                     False
# 4544          NaN                         None                     False
# 4545          NaN                         None                     False
# 4546          NaN                         None                     False
# 4547          NaN                         None                     False
#
#      winter_capacity_mw winter_estimated_capability_mw
# 4264               80.0                           None
# 4265               80.0                           None
# 4266               80.0                           None
# 4267               80.0                           None
# 4268               80.0                           None
# ...                 ...                            ...
# 4543               92.0                           None
# 4544               92.0                           None
# 4545               92.0                           None
# 4546               92.0                           None
# 4547               92.0                           None
#
# [335 rows x 74 columns]
