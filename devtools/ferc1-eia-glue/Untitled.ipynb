# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard libraries
import logging
import sys
import os
import pathlib

# 3rd party libraries
import geopandas as gpd
import dask.dataframe as dd
from dask.distributed import Client
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import seaborn as sns
import sqlalchemy as sa
#import pickle

# Local libraries
import pudl

# %%
# Enable viewing of logging outputs
logger=logging.getLogger()
logger.setLevel(logging.INFO)
handler = logging.StreamHandler(stream=sys.stdout)
formatter = logging.Formatter('%(message)s')
handler.setFormatter(formatter)
logger.handlers = [handler]

# %%
# Establish connection to pudl database
pudl_settings = pudl.workspace.setup.get_defaults()
pudl_engine = sa.create_engine(pudl_settings['pudl_db'])
pudl_out = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine,
    freq='AS'
)

# %%
eia = pudl_out.gens_eia860()
steam = pudl_out.plants_steam_ferc1()

# %%
steam[steam['plant_id_pudl']==41]
#steam[steam['plant_name_ferc1'].str.contains('ninemile')]
# Out:
#        report_year  utility_id_ferc1  utility_id_pudl  \
# 27538         2010               151              280
# 27539         2011               151              280
# 27540         2012               151              280
# 27541         2013               151              280
# 27542         2014               151              280
# 27543         2015               151              280
#
#                            utility_name_ferc1  plant_id_pudl  plant_id_ferc1  \
# 27538  Rochester Gas and Electric Corporation             41             553
# 27539  Rochester Gas and Electric Corporation             41             553
# 27540  Rochester Gas and Electric Corporation             41             553
# 27541  Rochester Gas and Electric Corporation             41             553
# 27542  Rochester Gas and Electric Corporation             41             553
# 27543  Rochester Gas and Electric Corporation             41             553
#
#       plant_name_ferc1  asset_retirement_cost  avg_num_employees  \
# 27538   beebee station              3412569.0                NaN
# 27539   beebee station              3412569.0                NaN
# 27540   beebee station              3412569.0                NaN
# 27541   beebee station              3412569.0                NaN
# 27542   beebee station              7568959.0                NaN
# 27543   beebee station              2010116.0                NaN
#
#        capacity_factor  ...  opex_steam  opex_steam_other  opex_structures  \
# 27538              NaN  ...         NaN               NaN              NaN
# 27539              NaN  ...         NaN               NaN              NaN
# 27540              NaN  ...         NaN               NaN              NaN
# 27541          0.00069  ...         NaN               NaN              NaN
# 27542              NaN  ...         NaN               NaN              NaN
# 27543              NaN  ...         NaN               NaN              NaN
#
#        opex_transfer  peak_demand_mw  plant_capability_mw  \
# 27538            NaN             NaN                  NaN
# 27539            NaN             NaN                  NaN
# 27540            NaN             NaN                  NaN
# 27541            NaN            19.0                  NaN
# 27542            NaN             NaN                  NaN
# 27543            NaN             NaN                  NaN
#
#       plant_hours_connected_while_generating  plant_type  \
# 27538                                    NaN       steam
# 27539                                    NaN       steam
# 27540                                 7791.0       steam
# 27541                                  201.0       steam
# 27542                                    NaN       steam
# 27543                                    NaN       steam
#
#                       record_id  water_limited_capacity_mw
# 27538  f1_steam_2010_12_151_0_5                        NaN
# 27539  f1_steam_2011_12_151_0_5                        NaN
# 27540  f1_steam_2012_12_151_0_5                        NaN
# 27541  f1_steam_2013_12_151_0_5                        NaN
# 27542  f1_steam_2014_12_151_0_5                        NaN
# 27543  f1_steam_2015_12_151_0_5                        NaN
#
# [6 rows x 47 columns]

# %%
Entergy Louisiana, LLC
ninemile point 4 & 5
