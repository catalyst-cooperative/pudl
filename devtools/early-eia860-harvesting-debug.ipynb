# %% [markdown]
# # Working with the EIA Extract / Transform
# This notebook steps through PUDL's extract and transform steps for the EIA 860 and 923 datasets, to make it easier to test and add new years of data, or new tables from the various spreadsheets that haven't been integrated yet.

# %%
# %load_ext autoreload
# %autoreload 2
import pudl
from pudl import constants as pc
import logging
import sys
from pathlib import Path
import pandas as pd
pd.options.display.max_columns = None

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)
handler = logging.StreamHandler(stream=sys.stdout)
formatter = logging.Formatter('%(message)s')
handler.setFormatter(formatter)
logger.handlers = [handler]

# %%
pudl_settings = pudl.workspace.setup.get_defaults()

# %% [markdown]
# ## Set the scope for the Extract-Transform:

# %%
eia860_tables = pc.pudl_tables['eia860']
eia860_years = pudl.constants.working_partitions['eia860']["years"]
eia923_tables = pc.pudl_tables['eia923']
eia923_years = pudl.constants.working_partitions['eia923']["years"]
eia860_ytd = True
eia860m_years = ["2020-08"]
sandbox = False

# %%
# %%time
sandbox = pudl_settings.get("sandbox", False)
ds = pudl.workspace.datastore.Datastore(
    Path(pudl_settings["pudl_in"]),
    sandbox=sandbox)
# Extract EIA forms 923, 860
eia923_raw_dfs = pudl.extract.eia923.Extractor(ds).extract(
    year=eia923_years)
eia860_raw_dfs = pudl.extract.eia860.Extractor(ds).extract(
    year=eia860_years)
# if we are trying to add the EIA 860M YTD data, then extract it and append
if eia860_ytd:
    eia860m_raw_dfs = pudl.extract.eia860m.Extractor(ds).extract(
        year_month=pc.working_partitions['eia860m']['year_month'])
    eia860_raw_dfs = pudl.extract.eia860m.append_eia860m(
        eia860_raw_dfs=eia860_raw_dfs, eia860m_raw_dfs=eia860m_raw_dfs)

# Transform EIA forms 923, 860
eia860_transformed_dfs = pudl.transform.eia860.transform(
    eia860_raw_dfs, eia860_tables=eia860_tables)
eia923_transformed_dfs = pudl.transform.eia923.transform(
    eia923_raw_dfs, eia923_tables=eia923_tables)
# create an eia transformed dfs dictionary
eia_transformed_dfs = eia860_transformed_dfs.copy()
eia_transformed_dfs.update(eia923_transformed_dfs.copy())

# # Add EIA-EPA crosswalk tables
# eia_transformed_dfs = _add_eia_epacems_crosswalk(eia_transformed_dfs)

# # convert types..
# eia_transformed_dfs = pudl.helpers.convert_dfs_dict_dtypes(
#     eia_transformed_dfs, 'eia')
# Out:
# Extracting eia923 spreadsheet data.
#
# boiler_fuel
#
# fuel_receipts_costs
#
# generation_fuel
#
# generator
#
# plant_frame
#
# stocks
# Extracting eia860 spreadsheet data.
#
# boiler_generator_assn
# Columns for boiler_generator_assn are off: should be 4 but got 9
# Unmapped raw columns: {'utility_name', 'plant_name', 'generator_association', 'report_year', 'steam_plant_type'}
#
# generator
# Columns for generator are off: should be 67 but got 75
# Unmapped raw columns: {'fercewgdoc', 'planned_derates_net_summer_cap', 'summer_capacity', 'fercdock', 'report_year', 'ferccogen', 'fercother', 'winter_capacity'}
#
# generator_existing
#
# generator_proposed
# Columns for generator_proposed are off: should be 62 but got 68
# Unmapped raw columns: {'summer_capacity', 'winter_estimated_capacity', 'report_year', 'data_source', 'summer_estimated_capacity', 'winter_capacity'}
#
# generator_retired
#
# ownership
#
# plant
# Columns for plant are off: should be 47 but got 50
# Unmapped raw columns: {'ownertransdist', 'ferc_exempt_wholesale_generator_docket_number', 'report_year'}
#
# utility
# Columns for utility are off: should be 30 but got 32
# Unmapped raw columns: {'areacode', 'report_year'}
# Extracting eia860m spreadsheet data.
#
# generator_existing
#
# generator_proposed
#
# generator_retired
# Transforming raw EIA 860 DataFrames for ownership_eia860 concatenated across all years.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74488 entries, 0 to 74487
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   fraction_owned           74442 non-null  float64
#  1   generator_id             74488 non-null  object
#  2   operational_status_code  54604 non-null  object
#  3   owner_city               28912 non-null  object
#  4   owner_name               74391 non-null  object
#  5   owner_state              42087 non-null  string
#  6   owner_street_address     28313 non-null  object
#  7   owner_utility_id_eia     74488 non-null  Int64
#  8   owner_zip_code           28843 non-null  object
#  9   plant_id_eia             74488 non-null  Int64
#  10  plant_name_eia           58253 non-null  object
#  11  state                    47356 non-null  object
#  12  utility_id_eia           74488 non-null  Int64
#  13  utility_name_eia         58253 non-null  object
#  14  report_date              74488 non-null  datetime64[ns]
# dtypes: Int64(3), datetime64[ns](1), float64(1), object(9), string(1)
# memory usage: 8.7+ MB
# None
#
# Transforming raw EIA 860 DataFrames for generators_eia860 concatenated across all years.
# Transforming raw EIA 860 DataFrames for plants_eia860 concatenated across all years.
# Transforming raw EIA 860 DataFrames for boiler_generator_assn_eia860 concatenated across all years.
# Transforming raw EIA 860 DataFrames for utilities_eia860 concatenated across all years.
# Transforming raw EIA 923 DataFrames for generation_fuel_eia923 concatenated across all years.
# Transforming raw EIA 923 DataFrames for boiler_fuel_eia923 concatenated across all years.
# Transforming raw EIA 923 DataFrames for generation_eia923 concatenated across all years.
# Transforming raw EIA 923 DataFrames for coalmine_eia923 concatenated across all years.
# Transforming raw EIA 923 DataFrames for fuel_receipts_costs_eia923 concatenated across all years.
# CPU times: user 16min 31s, sys: 39.8 s, total: 17min 11s
# Wall time: 17min 22s

# %%
from pudl.etl import _add_eia_epacems_crosswalk

print(eia_transformed_dfs.keys())
eia_transformed_dfs = _add_eia_epacems_crosswalk(eia_transformed_dfs)

# convert types..
eia_transformed_dfs = pudl.helpers.convert_dfs_dict_dtypes(
    eia_transformed_dfs, 'eia')

print(eia_transformed_dfs.keys())
# Out:
# dict_keys(['ownership_eia860', 'generators_eia860', 'plants_eia860', 'boiler_generator_assn_eia860', 'utilities_eia860', 'generation_fuel_eia923', 'boiler_fuel_eia923', 'generation_eia923', 'coalmine_eia923', 'fuel_receipts_costs_eia923'])
# grabbing original crosswalk
# splitting crosswalk into three normalized tables
# dict_keys(['ownership_eia860', 'generators_eia860', 'plants_eia860', 'boiler_generator_assn_eia860', 'utilities_eia860', 'generation_fuel_eia923', 'boiler_fuel_eia923', 'generation_eia923', 'coalmine_eia923', 'fuel_receipts_costs_eia923', 'plant_unit_epa', 'assn_plant_id_eia_epa', 'assn_gen_eia_unit_epa'])

# %%
debug=True
# create the empty entities df to fill up
entities_dfs = {}

# for each of the entities, harvest the static and annual columns.
# the order of the entities matter! the
# for entity in pc.entities.keys():
entity = 'plants'
logger.info(f"Harvesting IDs & consistently static attributes "
            f"for EIA {entity}")

entities_dfs, eia_transformed_dfs, col_dfs = pudl.transform.eia.harvesting(
    entity, eia_transformed_dfs, entities_dfs,
    debug=debug, eia860_ytd=eia860_ytd)
# Out:
# Harvesting IDs & consistently static attributes for EIA plants
# service_area has low consistency: 0.816.
# Average consistency of static plants values is 98.71%

# %%
service_area_df = col_dfs['service_area']

total_number_of_plant_ids = len(service_area_df.drop_duplicates(subset=['plant_id_eia']))

plants_with_consistent_service_area = service_area_df[service_area_df["service_area_consistent"]]

print(service_area_df.shape)
print(plants_with_consistent_service_area.shape)
# Out:
# (19024, 7)
# (14996, 7)

# %%
service_area_df.sort_values(by="service_area_consistent_rate", ascending=True).sample(n=10)
# Out:
#        plant_id_eia report_date                     service_area  \
# 7189          54999  2003-01-01     Savannah Electric & Power Co
# 449           55224  2001-01-01                   PSI Energy Inc
# 11697         10879  2005-01-01     Imperial Irrigation District
# 12050         50301  2004-01-01        Pacific Gas & Electric Co
# 11747         55521  2001-01-01        Pacific Gas & Electric Co
# 9194          55012  2003-01-01        Massachusetts Electric Co
# 12498         54535  2006-01-01  Jacksonville Electric Authority
# 3130           7153  2004-01-01   Delmarva Power & Light Company
# 5870          55475  2004-01-01        Niagara Mohawk Power Corp
# 12813         52106  2001-01-01                   PECO Energy Co
#
#        entity_occurences  record_occurences  service_area_consistent_rate  \
# 7189                   6                  6                      1.000000
# 449                    5                  5                      1.000000
# 11697                  6                  6                      1.000000
# 12050                  6                  6                      1.000000
# 11747                  6                  1                      0.166667
# 9194                   6                  6                      1.000000
# 12498                  6                  4                      0.666667
# 3130                   6                  5                      0.833333
# 5870                   6                  6                      1.000000
# 12813                  6                  6                      1.000000
#
#        service_area_consistent
# 7189                      True
# 449                       True
# 11697                     True
# 12050                     True
# 11747                    False
# 9194                      True
# 12498                    False
# 3130                      True
# 5870                      True
# 12813                     True

# %%
plant_id_eia = 56311
service_area_df[service_area_df["plant_id_eia"] == plant_id_eia]
# Out:
#        plant_id_eia report_date                   service_area  \
# 18676         56311  2004-01-01     TXU Energy Trading Co., LP
# 18677         56311  2005-01-01  TXU Electric Delivery Company
# 18678         56311  2006-01-01  TXU Electric Delivery Company
#
#        entity_occurences  record_occurences  service_area_consistent_rate  \
# 18676                  3                  1                      0.333333
# 18677                  3                  2                      0.666667
# 18678                  3                  2                      0.666667
#
#        service_area_consistent
# 18676                    False
# 18677                    False
# 18678                    False

# %%
service_area_df.query("service_area_consistent_rate < 0.7").sort_values(by=["plant_id_eia", "service_area_consistent_rate"], ascending=False).head(20)
# Out:
#        plant_id_eia report_date                     service_area  \
# 18838         56417  2006-01-01           Commonwealth Edison Co
# 18837         56417  2005-01-01    Commonwealth Edison Co IN Inc
# 18748         56336  2006-01-01          Public Service Co of NM
# 18747         56336  2005-01-01        Arizona Public Service Co
# 18677         56311  2005-01-01    TXU Electric Delivery Company
# 18678         56311  2006-01-01    TXU Electric Delivery Company
# 18676         56311  2004-01-01       TXU Energy Trading Co., LP
# 18513         56307  2005-01-01             Dairyland Power Coop
# 18514         56307  2006-01-01             Dairyland Power Coop
# 18512         56307  2004-01-01      Dairyland Power Cooperative
# 18656         56294  2006-01-01     Public Service Elec & Gas Co
# 18655         56294  2005-01-01     Public Service Elec & Gas Co
# 18654         56294  2004-01-01                   PSEG Power LLC
# 18589         56236  2005-01-01            The Potomac Edison Co
# 18590         56236  2006-01-01            The Potomac Edison Co
# 18588         56236  2004-01-01        Potomac Electric Power Co
# 18417         56221  2003-01-01  Allegheny Energy Supply Co, LLC
# 18418         56221  2004-01-01  Allegheny Energy Supply Co, LLC
# 18419         56221  2005-01-01                  Allegheny Power
# 18420         56221  2006-01-01                  Allegheny Power
#
#        entity_occurences  record_occurences  service_area_consistent_rate  \
# 18838                  2                  1                      0.500000
# 18837                  2                  1                      0.500000
# 18748                  2                  1                      0.500000
# 18747                  2                  1                      0.500000
# 18677                  3                  2                      0.666667
# 18678                  3                  2                      0.666667
# 18676                  3                  1                      0.333333
# 18513                  3                  2                      0.666667
# 18514                  3                  2                      0.666667
# 18512                  3                  1                      0.333333
# 18656                  3                  2                      0.666667
# 18655                  3                  2                      0.666667
# 18654                  3                  1                      0.333333
# 18589                  3                  2                      0.666667
# 18590                  3                  2                      0.666667
# 18588                  3                  1                      0.333333
# 18417                  4                  2                      0.500000
# 18418                  4                  2                      0.500000
# 18419                  4                  2                      0.500000
# 18420                  4                  2                      0.500000
#
#        service_area_consistent
# 18838                    False
# 18837                    False
# 18748                    False
# 18747                    False
# 18677                    False
# 18678                    False
# 18676                    False
# 18513                    False
# 18514                    False
# 18512                    False
# 18656                    False
# 18655                    False
# 18654                    False
# 18589                    False
# 18590                    False
# 18588                    False
# 18417                    False
# 18418                    False
# 18419                    False
# 18420                    False

# %% [markdown]
# ### Calculate the ratio
# total number of entities with a consistent value / total number of entities with service area information?

# %%
n_plants_with_consistent_values = len(plants_with_consistent_service_area.drop_duplicates(subset=["plant_id_eia"]))

n_plants_with_values = len(service_area_df.drop_duplicates(subset=['plant_id_eia']))

ratio = n_plants_with_consistent_values / n_plants_with_values
print(ratio)
# Out:
# 0.8161016949152542

# %% [markdown]
# ## Is `service_area` static?

# %%
sample = ["TXU Energy Trading Co., LP", "TXU Electric Delivery Company", "TXU Electric Delivery Company"]

# %%
import itertools

list(itertools.combinations(sample, 2))
# Out:
# [('TXU Energy Trading Co., LP', 'TXU Electric Delivery Company'),
#  ('TXU Energy Trading Co., LP', 'TXU Electric Delivery Company'),
#  ('TXU Electric Delivery Company', 'TXU Electric Delivery Company')]

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def group_similarity(grp):
    similarities = []
    if len(grp) == 1:
        return 1
    else:
        for a,b in itertools.combinations(grp, 2):
            similarities.append(similar(a, b))
        return pd.Series(similarities).mean()

average_service_area_similarities = service_area_df.groupby("plant_id_eia")['service_area'].apply(group_similarity)

# %%
average_service_area_similarities = average_service_area_similarities.reset_index().rename(columns={"service_area": "average_similarity"})

# %%
average_service_area_similarities.average_similarity.describe()
# Out:
# count    3540.000000
# mean        0.948972
# std         0.115329
# min         0.177778
# 25%         0.989116
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: average_similarity, dtype: float64

# %% [markdown]
# 75% of plants have an average service area similarity of 98%. Given this it seems strange our etl process throws an error due to its inconsistency.

# %% [markdown]
# ### Inspect plants with the least similar service areas

# %%
service_area_df_with_similarities = service_area_df.merge(average_service_area_similarities, on="plant_id_eia", how="left", validate="m:1")

service_area_df_with_similarities.sort_values(by="average_similarity", ascending=True).head(5)
# Out:
#       plant_id_eia report_date                service_area  entity_occurences  \
# 1923         50219  2006-01-01        PG&E Energy Services                  2
# 1914         50219  2001-01-01   Pacific Gas & Electric Co                  2
# 1913         50218  2006-01-01        PG&E Energy Services                  2
# 1892         50218  2001-01-01   Pacific Gas & Electric Co                  2
# 1787         56107  2005-01-01  Tennessee Valley Authority                  2
#
#       record_occurences  service_area_consistent_rate  \
# 1923                  1                           0.5
# 1914                  1                           0.5
# 1913                  1                           0.5
# 1892                  1                           0.5
# 1787                  1                           0.5
#
#       service_area_consistent  average_similarity
# 1923                    False            0.177778
# 1914                    False            0.177778
# 1913                    False            0.177778
# 1892                    False            0.177778
# 1787                    False            0.320000

# %% [markdown]
# It looks like the plants with the least similar service_area fields refer to very similar service areas in reality.

# %% [markdown]
# ## play with `strictness` so `ratio > 0.9`

# %%
# default is 0.7. Higher means less strict.
strictness = 0.65


adj_strictness_service_area_df = service_area_df.copy()

adj_strictness_service_area_df['service_area_consistent'] = adj_strictness_service_area_df.service_area_consistent_rate > strictness

# %%
n_plants = len(adj_strictness_service_area_df.drop_duplicates(subset="plant_id_eia"))

n_consistent_plants = len(adj_strictness_service_area_df[adj_strictness_service_area_df['service_area_consistent']].drop_duplicates(subset="plant_id_eia"))

print(n_consistent_plants)
print(n_plants)
print(n_consistent_plants / n_plants)
# Out:
# 3389
# 3540
# 0.9573446327683616

# %% [markdown]
# When strictness is > 0.66 the ratio is 0.816. When the strictness is <= 0.66, the ratio is 0.95.
#
# This means there are a large number of plants where 2/3s of the service areas are the same and 1/3 are different.

# %%
import numpy as np

plant_ids_with_twothirds_consistency = adj_strictness_service_area_df[np.isclose(adj_strictness_service_area_df["service_area_consistent_rate"], 0.666666)].plant_id_eia

# %%
adj_strictness_service_area_df[adj_strictness_service_area_df.plant_id_eia.isin(plant_ids_with_twothirds_consistency)].sort_values(by="plant_id_eia").head(40)
# Out:
#        plant_id_eia report_date                    service_area  \
# 6722            594  2003-01-01  Delmarva Power & Light Company
# 6725            594  2006-01-01  Delmarva Power & Light Company
# 6724            594  2005-01-01  Delmarva Power & Light Company
# 6723            594  2004-01-01  Delmarva Power & Light Company
# 6720            594  2001-01-01                        Conectiv
# 6721            594  2002-01-01    Conectiv Energy Services Inc
# 13731          1564  2003-01-01  Delmarva Power & Light Company
# 13732          1564  2004-01-01  Delmarva Power & Light Company
# 13733          1564  2005-01-01  Delmarva Power & Light Company
# 13734          1564  2006-01-01  Delmarva Power & Light Company
# 13729          1564  2001-01-01                        Conectiv
# 13730          1564  2002-01-01    Conectiv Energy Services Inc
# 15565          1570  2002-01-01    Allegheny Electric Coop, Inc
# 15564          1570  2001-01-01  Allegheny Energy Supply Co LLC
# 15569          1570  2006-01-01           The Potomac Edison Co
# 15567          1570  2004-01-01           The Potomac Edison Co
# 15566          1570  2003-01-01           The Potomac Edison Co
# 15568          1570  2005-01-01           The Potomac Edison Co
# 16513          1590  2006-01-01                Boston Edison Co
# 16512          1590  2005-01-01                Boston Edison Co
# 16508          1590  2001-01-01          Commonwealth Edison Co
# 16509          1590  2002-01-01        Commonwealth Electric Co
# 16511          1590  2004-01-01                Boston Edison Co
# 16510          1590  2003-01-01                Boston Edison Co
# 15451          1619  2002-01-01  Fall River Rural Elec Coop Inc
# 15450          1619  2001-01-01  Fall River Rural Elec Coop Inc
# 15452          1619  2003-01-01       Massachusetts Electric Co
# 15453          1619  2004-01-01       Massachusetts Electric Co
# 15455          1619  2006-01-01       Massachusetts Electric Co
# 15454          1619  2005-01-01       Massachusetts Electric Co
# 2888           2379  2002-01-01    Conectiv Energy Services Inc
# 2892           2379  2006-01-01       Atlantic City Electric Co
# 2887           2379  2001-01-01          Conectiv Mid-Merit Inc
# 2890           2379  2004-01-01       Atlantic City Electric Co
# 2889           2379  2003-01-01       Atlantic City Electric Co
# 2891           2379  2005-01-01       Atlantic City Electric Co
# 2894           2380  2002-01-01    Conectiv Energy Services Inc
# 2898           2380  2006-01-01       Atlantic City Electric Co
# 2897           2380  2005-01-01       Atlantic City Electric Co
# 2893           2380  2001-01-01          Conectiv Mid-Merit Inc
#
#        entity_occurences  record_occurences  service_area_consistent_rate  \
# 6722                   6                  4                      0.666667
# 6725                   6                  4                      0.666667
# 6724                   6                  4                      0.666667
# 6723                   6                  4                      0.666667
# 6720                   6                  1                      0.166667
# 6721                   6                  1                      0.166667
# 13731                  6                  4                      0.666667
# 13732                  6                  4                      0.666667
# 13733                  6                  4                      0.666667
# 13734                  6                  4                      0.666667
# 13729                  6                  1                      0.166667
# 13730                  6                  1                      0.166667
# 15565                  6                  1                      0.166667
# 15564                  6                  1                      0.166667
# 15569                  6                  4                      0.666667
# 15567                  6                  4                      0.666667
# 15566                  6                  4                      0.666667
# 15568                  6                  4                      0.666667
# 16513                  6                  4                      0.666667
# 16512                  6                  4                      0.666667
# 16508                  6                  1                      0.166667
# 16509                  6                  1                      0.166667
# 16511                  6                  4                      0.666667
# 16510                  6                  4                      0.666667
# 15451                  6                  2                      0.333333
# 15450                  6                  2                      0.333333
# 15452                  6                  4                      0.666667
# 15453                  6                  4                      0.666667
# 15455                  6                  4                      0.666667
# 15454                  6                  4                      0.666667
# 2888                   6                  1                      0.166667
# 2892                   6                  4                      0.666667
# 2887                   6                  1                      0.166667
# 2890                   6                  4                      0.666667
# 2889                   6                  4                      0.666667
# 2891                   6                  4                      0.666667
# 2894                   6                  1                      0.166667
# 2898                   6                  4                      0.666667
# 2897                   6                  4                      0.666667
# 2893                   6                  1                      0.166667
#
#        service_area_consistent
# 6722                      True
# 6725                      True
# 6724                      True
# 6723                      True
# 6720                     False
# 6721                     False
# 13731                     True
# 13732                     True
# 13733                     True
# 13734                     True
# 13729                    False
# 13730                    False
# 15565                    False
# 15564                    False
# 15569                     True
# 15567                     True
# 15566                     True
# 15568                     True
# 16513                     True
# 16512                     True
# 16508                    False
# 16509                    False
# 16511                     True
# 16510                     True
# 15451                    False
# 15450                    False
# 15452                     True
# 15453                     True
# 15455                     True
# 15454                     True
# 2888                     False
# 2892                      True
# 2887                     False
# 2890                      True
# 2889                      True
# 2891                      True
# 2894                     False
# 2898                      True
# 2897                      True
# 2893                     False

# %% [markdown]
# ### Examples
# - **plant_id_eia: 594, 1564:**"In 1998, Delmarva Power acquired Atlantic Energy, which owned Atlantic City Electric in New Jersey, for 968 million. The merged utility company became known as Conectiv Power Delivery. Conectiv Power Delivery was acquired by the Potomac Electric Power Company in 2002 for 5.4 billion, which resulted in Pepco Holdings being created as a holding company that owned both utility companies.[6] In 2005, Pepco Holdings brought back the Delmarva Power and Atlantic City Electric names in place of Conectiv Power Delivery.[7]" - https://en.wikipedia.org/wiki/Delmarva_Power
# - **plant-id-eia: 1570:** The Potomac Edison Company" was a subsidiary of Allegheny Electric Coop. https://en.wikipedia.org/wiki/Allegheny_Energy
# - **plant_id_eia: 1590, 1590** In 1999 Boston Edison CO was merged with Cambridge Electric Light Company, Commonwealth Electric Company, and NSTAR Gas Company to form NSTAR.[4] After subsequent mergers, what remains of the Boston Edison Company is now part of Eversource Energy.[4] https://en.wikipedia.org/wiki/Boston_Edison_Company
#
#
# Seems like some of these change because of acquisitions and rebrandings. This does seems pretty rare given the vast majorty of plants have very consistent service areas. **How do we handle ownership changes of plants?**

# %% [markdown]
# ## Why was the consistency higher before adding 2001 - 2003?

# %%
aaa

# %%
adj_strictness_service_area_df.drop_duplicates(subset='plant_id_eia').entity_occurences.describe()
# Out:
# count    3540.000000
# mean        5.374011
# std         1.452343
# min         1.000000
# 25%         6.000000
# 50%         6.000000
# 75%         6.000000
# max         6.000000
# Name: entity_occurences, dtype: float64

# %%
adj_strictness_service_area_df.drop_duplicates(subset='plant_id_eia').record_occurences.describe()
# Out:
# count    3540.000000
# mean        4.289831
# std         2.125388
# min         1.000000
# 25%         2.000000
# 50%         6.000000
# 75%         6.000000
# max         6.000000
# Name: record_occurences, dtype: float64

# %%
import numpy as np

adj_strictness_service_area_df[np.isclose(adj_strictness_service_area_df["service_area_consistent_rate"], 0.667)]
# Out:
# Empty DataFrame
# Columns: [plant_id_eia, report_date, service_area, entity_occurences, record_occurences, service_area_consistent_rate, service_area_consistent]
# Index: []

# %%
adj_strictness_service_area_df.query("service_area_consistent_rate < 0.67 & service_area_consistent_rate > 0.65").sort_values(by="service_area_consistent_rate", ascending=False).drop_duplicates(.shape
# Out:
# (1966, 7)

# %%
from pudl.transform.eia import _compile_all_entity_records

compiled_plants = _compile_all_entity_records("plants", eia_transformed_dfs)
# Out:
#          ash_impoundment  ash_impoundment_lined ash_impoundment_status  \
# 0                   <NA>                   <NA>                   <NA>
# 1                   <NA>                   <NA>                   <NA>
# 2                   <NA>                   <NA>                   <NA>
# 3                   <NA>                   <NA>                   <NA>
# 4                   <NA>                   <NA>                   <NA>
# ...                  ...                    ...                    ...
# 5424867             <NA>                   <NA>                   <NA>
# 5424868             <NA>                   <NA>                   <NA>
# 5424869             <NA>                   <NA>                   <NA>
# 5424870             <NA>                   <NA>                   <NA>
# 5424871             <NA>                   <NA>                   <NA>
#
#         balancing_authority_code_eia balancing_authority_name_eia  city  \
# 0                                NaN                         <NA>  <NA>
# 1                                NaN                         <NA>  <NA>
# 2                                NaN                         <NA>  <NA>
# 3                                NaN                         <NA>  <NA>
# 4                                NaN                         <NA>  <NA>
# ...                              ...                          ...   ...
# 5424867                          NaN                         <NA>  <NA>
# 5424868                          NaN                         <NA>  <NA>
# 5424869                          NaN                         <NA>  <NA>
# 5424870                          NaN                         <NA>  <NA>
# 5424871                          NaN                         <NA>  <NA>
#
#         county datum  energy_storage ferc_cogen_docket_no  ferc_cogen_status  \
# 0         <NA>  <NA>            <NA>                 <NA>               <NA>
# 1         <NA>  <NA>            <NA>                 <NA>               <NA>
# 2         <NA>  <NA>            <NA>                 <NA>               <NA>
# 3         <NA>  <NA>            <NA>                 <NA>               <NA>
# 4         <NA>  <NA>            <NA>                 <NA>               <NA>
# ...        ...   ...             ...                  ...                ...
# 5424867   <NA>  <NA>            <NA>                 <NA>               <NA>
# 5424868   <NA>  <NA>            <NA>                 <NA>               <NA>
# 5424869   <NA>  <NA>            <NA>                 <NA>               <NA>
# 5424870   <NA>  <NA>            <NA>                 <NA>               <NA>
# 5424871   <NA>  <NA>            <NA>                 <NA>               <NA>
#
#          ferc_exempt_wholesale_generator  \
# 0                                   <NA>
# 1                                   <NA>
# 2                                   <NA>
# 3                                   <NA>
# 4                                   <NA>
# ...                                  ...
# 5424867                             <NA>
# 5424868                             <NA>
# 5424869                             <NA>
# 5424870                             <NA>
# 5424871                             <NA>
#
#         ferc_exempt_wholesale_generator_docket_no  ferc_small_power_producer  \
# 0                                            <NA>                       <NA>
# 1                                            <NA>                       <NA>
# 2                                            <NA>                       <NA>
# 3                                            <NA>                       <NA>
# 4                                            <NA>                       <NA>
# ...                                           ...                        ...
# 5424867                                      <NA>                       <NA>
# 5424868                                      <NA>                       <NA>
# 5424869                                      <NA>                       <NA>
# 5424870                                      <NA>                       <NA>
# 5424871                                      <NA>                       <NA>
#
#         ferc_small_power_producer_docket_no  grid_voltage_2_kv  \
# 0                                      <NA>                NaN
# 1                                      <NA>                NaN
# 2                                      <NA>                NaN
# 3                                      <NA>                NaN
# 4                                      <NA>                NaN
# ...                                     ...                ...
# 5424867                                <NA>                NaN
# 5424868                                <NA>                NaN
# 5424869                                <NA>                NaN
# 5424870                                <NA>                NaN
# 5424871                                <NA>                NaN
#
#          grid_voltage_3_kv  grid_voltage_kv iso_rto_code  latitude  \
# 0                      NaN              NaN         <NA>       NaN
# 1                      NaN              NaN         <NA>       NaN
# 2                      NaN              NaN         <NA>       NaN
# 3                      NaN              NaN         <NA>       NaN
# 4                      NaN              NaN         <NA>       NaN
# ...                    ...              ...          ...       ...
# 5424867                NaN              NaN         <NA>       NaN
# 5424868                NaN              NaN         <NA>       NaN
# 5424869                NaN              NaN         <NA>       NaN
# 5424870                NaN              NaN         <NA>       NaN
# 5424871                NaN              NaN         <NA>       NaN
#
#          liquefied_natural_gas_storage  longitude  \
# 0                                 <NA>        NaN
# 1                                 <NA>        NaN
# 2                                 <NA>        NaN
# 3                                 <NA>        NaN
# 4                                 <NA>        NaN
# ...                                ...        ...
# 5424867                           <NA>        NaN
# 5424868                           <NA>        NaN
# 5424869                           <NA>        NaN
# 5424870                           <NA>        NaN
# 5424871                           <NA>        NaN
#
#         natural_gas_local_distribution_company natural_gas_pipeline_name_1  \
# 0                                         <NA>                        <NA>
# 1                                         <NA>                        <NA>
# 2                                         <NA>                        <NA>
# 3                                         <NA>                        <NA>
# 4                                         <NA>                        <NA>
# ...                                        ...                         ...
# 5424867                                   <NA>                        <NA>
# 5424868                                   <NA>                        <NA>
# 5424869                                   <NA>                        <NA>
# 5424870                                   <NA>                        <NA>
# 5424871                                   <NA>                        <NA>
#
#         natural_gas_pipeline_name_2 natural_gas_pipeline_name_3  \
# 0                              <NA>                        <NA>
# 1                              <NA>                        <NA>
# 2                              <NA>                        <NA>
# 3                              <NA>                        <NA>
# 4                              <NA>                        <NA>
# ...                             ...                         ...
# 5424867                        <NA>                        <NA>
# 5424868                        <NA>                        <NA>
# 5424869                        <NA>                        <NA>
# 5424870                        <NA>                        <NA>
# 5424871                        <NA>                        <NA>
#
#          natural_gas_storage nerc_region  net_metering pipeline_notes  \
# 0                       <NA>         NaN          <NA>           <NA>
# 1                       <NA>         NaN          <NA>           <NA>
# 2                       <NA>         NaN          <NA>           <NA>
# 3                       <NA>         NaN          <NA>           <NA>
# 4                       <NA>         NaN          <NA>           <NA>
# ...                      ...         ...           ...            ...
# 5424867                 <NA>         NaN          <NA>           <NA>
# 5424868                 <NA>         NaN          <NA>           <NA>
# 5424869                 <NA>         NaN          <NA>           <NA>
# 5424870                 <NA>         NaN          <NA>           <NA>
# 5424871                 <NA>         NaN          <NA>           <NA>
#
#          plant_id_eia plant_name_eia  primary_purpose_naics_id  \
# 0                  10           <NA>                      <NA>
# 1                  10           <NA>                      <NA>
# 2                  10           <NA>                      <NA>
# 3                  10           <NA>                      <NA>
# 4                  10           <NA>                      <NA>
# ...               ...            ...                       ...
# 5424867         60926           <NA>                      <NA>
# 5424868         60926           <NA>                      <NA>
# 5424869         61035           <NA>                      <NA>
# 5424870         61643           <NA>                      <NA>
# 5424871         61890           <NA>                      <NA>
#
#         regulatory_status_code report_date  sector_id sector_name  \
# 0                         <NA>  2001-01-01       <NA>        <NA>
# 1                         <NA>  2001-01-01       <NA>        <NA>
# 2                         <NA>  2002-01-01       <NA>        <NA>
# 3                         <NA>  2002-01-01       <NA>        <NA>
# 4                         <NA>  2003-01-01       <NA>        <NA>
# ...                        ...         ...        ...         ...
# 5424867                   <NA>  2019-01-01       <NA>        <NA>
# 5424868                   <NA>  2019-01-01       <NA>        <NA>
# 5424869                   <NA>  2019-01-01       <NA>        <NA>
# 5424870                   <NA>  2019-01-01       <NA>        <NA>
# 5424871                   <NA>  2019-01-01       <NA>        <NA>
#
#         service_area state street_address                       table  \
# 0               <NA>  <NA>           <NA>            ownership_eia860
# 1               <NA>  <NA>           <NA>            ownership_eia860
# 2               <NA>  <NA>           <NA>            ownership_eia860
# 3               <NA>  <NA>           <NA>            ownership_eia860
# 4               <NA>  <NA>           <NA>            ownership_eia860
# ...              ...   ...            ...                         ...
# 5424867         <NA>  <NA>           <NA>  fuel_receipts_costs_eia923
# 5424868         <NA>  <NA>           <NA>  fuel_receipts_costs_eia923
# 5424869         <NA>  <NA>           <NA>  fuel_receipts_costs_eia923
# 5424870         <NA>  <NA>           <NA>  fuel_receipts_costs_eia923
# 5424871         <NA>  <NA>           <NA>  fuel_receipts_costs_eia923
#
#          transmission_distribution_owner_id  \
# 0                                      <NA>
# 1                                      <NA>
# 2                                      <NA>
# 3                                      <NA>
# 4                                      <NA>
# ...                                     ...
# 5424867                                <NA>
# 5424868                                <NA>
# 5424869                                <NA>
# 5424870                                <NA>
# 5424871                                <NA>
#
#         transmission_distribution_owner_name  \
# 0                                       <NA>
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# ...                                      ...
# 5424867                                 <NA>
# 5424868                                 <NA>
# 5424869                                 <NA>
# 5424870                                 <NA>
# 5424871                                 <NA>
#
#         transmission_distribution_owner_state  utility_id_eia water_source  \
# 0                                        <NA>             195         <NA>
# 1                                        <NA>             195         <NA>
# 2                                        <NA>             195         <NA>
# 3                                        <NA>             195         <NA>
# 4                                        <NA>             195         <NA>
# ...                                       ...             ...          ...
# 5424867                                  <NA>            <NA>         <NA>
# 5424868                                  <NA>            <NA>         <NA>
# 5424869                                  <NA>            <NA>         <NA>
# 5424870                                  <NA>            <NA>         <NA>
# 5424871                                  <NA>            <NA>         <NA>
#
#         zip_code
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 5424867      NaN
# 5424868      NaN
# 5424869      NaN
# 5424870      NaN
# 5424871      NaN
#
# [5424872 rows x 47 columns]

# %%
compiled_plants['table'].value_counts()
# Out:
# generation_fuel_eia923          2401225
# boiler_fuel_eia923              1214200
# fuel_receipts_costs_eia923       536118
# generation_eia923                513862
# generators_eia860                459931
# plants_eia860                    144699
# boiler_generator_assn_eia860      80356
# ownership_eia860                  74481
# Name: table, dtype: int64

# %%
compiled_plants.groupby("table").count()
# Out:
#                               ash_impoundment  ash_impoundment_lined  \
# table
# boiler_fuel_eia923                          0                      0
# boiler_generator_assn_eia860                0                      0
# fuel_receipts_costs_eia923                  0                      0
# generation_eia923                           0                      0
# generation_fuel_eia923                      0                      0
# generators_eia860                           0                      0
# ownership_eia860                            0                      0
# plants_eia860                           43223                  50451
#
#                               ash_impoundment_status  \
# table
# boiler_fuel_eia923                                 0
# boiler_generator_assn_eia860                       0
# fuel_receipts_costs_eia923                         0
# generation_eia923                                  0
# generation_fuel_eia923                             0
# generators_eia860                                  0
# ownership_eia860                                   0
# plants_eia860                                   2572
#
#                               balancing_authority_code_eia  \
# table
# boiler_fuel_eia923                                       0
# boiler_generator_assn_eia860                             0
# fuel_receipts_costs_eia923                               0
# generation_eia923                                        0
# generation_fuel_eia923                                   0
# generators_eia860                                    27900
# ownership_eia860                                         0
# plants_eia860                                        65859
#
#                               balancing_authority_name_eia    city  county  \
# table
# boiler_fuel_eia923                                       0       0       0
# boiler_generator_assn_eia860                             0       0       0
# fuel_receipts_costs_eia923                               0       0       0
# generation_eia923                                        0       0       0
# generation_fuel_eia923                                   0       0       0
# generators_eia860                                        0       0  300916
# ownership_eia860                                         0       0       0
# plants_eia860                                        65977  108012  144245
#
#                               datum  energy_storage  ferc_cogen_docket_no  \
# table
# boiler_fuel_eia923                0               0                     0
# boiler_generator_assn_eia860      0               0                     0
# fuel_receipts_costs_eia923        0               0                     0
# generation_eia923                 0               0                     0
# generation_fuel_eia923            0               0                     0
# generators_eia860                 0               0                  9180
# ownership_eia860                  0               0                     0
# plants_eia860                  5561           40528                  7022
#
#                               ferc_cogen_status  \
# table
# boiler_fuel_eia923                            0
# boiler_generator_assn_eia860                  0
# fuel_receipts_costs_eia923                    0
# generation_eia923                             0
# generation_fuel_eia923                        0
# generators_eia860                         95926
# ownership_eia860                              0
# plants_eia860                            109103
#
#                               ferc_exempt_wholesale_generator  \
# table
# boiler_fuel_eia923                                          0
# boiler_generator_assn_eia860                                0
# fuel_receipts_costs_eia923                                  0
# generation_eia923                                           0
# generation_fuel_eia923                                      0
# generators_eia860                                       96591
# ownership_eia860                                            0
# plants_eia860                                          109091
#
#                               ferc_exempt_wholesale_generator_docket_no  \
# table
# boiler_fuel_eia923                                                    0
# boiler_generator_assn_eia860                                          0
# fuel_receipts_costs_eia923                                            0
# generation_eia923                                                     0
# generation_fuel_eia923                                                0
# generators_eia860                                                  9512
# ownership_eia860                                                      0
# plants_eia860                                                      5086
#
#                               ferc_small_power_producer  \
# table
# boiler_fuel_eia923                                    0
# boiler_generator_assn_eia860                          0
# fuel_receipts_costs_eia923                            0
# generation_eia923                                     0
# generation_fuel_eia923                                0
# generators_eia860                                 96226
# ownership_eia860                                      0
# plants_eia860                                    109144
#
#                               ferc_small_power_producer_docket_no  \
# table
# boiler_fuel_eia923                                              0
# boiler_generator_assn_eia860                                    0
# fuel_receipts_costs_eia923                                      0
# generation_eia923                                               0
# generation_fuel_eia923                                          0
# generators_eia860                                            9048
# ownership_eia860                                                0
# plants_eia860                                               22330
#
#                               grid_voltage_2_kv  grid_voltage_3_kv  \
# table
# boiler_fuel_eia923                            0                  0
# boiler_generator_assn_eia860                  0                  0
# fuel_receipts_costs_eia923                    0                  0
# generation_eia923                             0                  0
# generation_fuel_eia923                        0                  0
# generators_eia860                             0                  0
# ownership_eia860                              0                  0
# plants_eia860                              1685                346
#
#                               grid_voltage_kv  iso_rto_code  latitude  \
# table
# boiler_fuel_eia923                          0             0         0
# boiler_generator_assn_eia860                0             0         0
# fuel_receipts_costs_eia923                  0             0         0
# generation_eia923                           0             0         0
# generation_fuel_eia923                      0             0         0
# generators_eia860                           0             0     29957
# ownership_eia860                            0             0         0
# plants_eia860                           80685         12990     75217
#
#                               liquefied_natural_gas_storage  longitude  \
# table
# boiler_fuel_eia923                                        0          0
# boiler_generator_assn_eia860                              0          0
# fuel_receipts_costs_eia923                                0          0
# generation_eia923                                         0          0
# generation_fuel_eia923                                    0          0
# generators_eia860                                         0      29954
# ownership_eia860                                          0          0
# plants_eia860                                         20172      75215
#
#                               natural_gas_local_distribution_company  \
# table
# boiler_fuel_eia923                                                 0
# boiler_generator_assn_eia860                                       0
# fuel_receipts_costs_eia923                                         0
# generation_eia923                                                  0
# generation_fuel_eia923                                             0
# generators_eia860                                                  0
# ownership_eia860                                                   0
# plants_eia860                                                   5257
#
#                               natural_gas_pipeline_name_1  \
# table
# boiler_fuel_eia923                                      0
# boiler_generator_assn_eia860                            0
# fuel_receipts_costs_eia923                              0
# generation_eia923                                       0
# generation_fuel_eia923                                  0
# generators_eia860                                       0
# ownership_eia860                                        0
# plants_eia860                                       13749
#
#                               natural_gas_pipeline_name_2  \
# table
# boiler_fuel_eia923                                      0
# boiler_generator_assn_eia860                            0
# fuel_receipts_costs_eia923                              0
# generation_eia923                                       0
# generation_fuel_eia923                                  0
# generators_eia860                                       0
# ownership_eia860                                        0
# plants_eia860                                         790
#
#                               natural_gas_pipeline_name_3  \
# table
# boiler_fuel_eia923                                      0
# boiler_generator_assn_eia860                            0
# fuel_receipts_costs_eia923                              0
# generation_eia923                                       0
# generation_fuel_eia923                                  0
# generators_eia860                                       0
# ownership_eia860                                        0
# plants_eia860                                         163
#
#                               natural_gas_storage  nerc_region  net_metering  \
# table
# boiler_fuel_eia923                              0            0             0
# boiler_generator_assn_eia860                    0            0             0
# fuel_receipts_costs_eia923                      0            0             0
# generation_eia923                               0            0             0
# generation_fuel_eia923                          0            0             0
# generators_eia860                               0            0             0
# ownership_eia860                                0            0             0
# plants_eia860                               24246       143961          1685
#
#                               pipeline_notes  plant_id_eia  plant_name_eia  \
# table
# boiler_fuel_eia923                         0       1214200               0
# boiler_generator_assn_eia860               0         80356               0
# fuel_receipts_costs_eia923                 0        536118               0
# generation_eia923                          0        513862               0
# generation_fuel_eia923                     0       2401225               0
# generators_eia860                          0        459931          403785
# ownership_eia860                           0         74481           58246
# plants_eia860                            746        144699          144699
#
#                               primary_purpose_naics_id  \
# table
# boiler_fuel_eia923                                   0
# boiler_generator_assn_eia860                         0
# fuel_receipts_costs_eia923                           0
# generation_eia923                                    0
# generation_fuel_eia923                               0
# generators_eia860                                    0
# ownership_eia860                                     0
# plants_eia860                                   144668
#
#                               regulatory_status_code  report_date  sector_id  \
# table
# boiler_fuel_eia923                                 0      1214200          0
# boiler_generator_assn_eia860                       0        80356          0
# fuel_receipts_costs_eia923                         0       536118          0
# generation_eia923                                  0       513862          0
# generation_fuel_eia923                             0      2401225          0
# generators_eia860                                  0       459931     266943
# ownership_eia860                                   0        74481          0
# plants_eia860                                 115438       144699      96136
#
#                               sector_name  service_area   state  \
# table
# boiler_fuel_eia923                      0             0       0
# boiler_generator_assn_eia860            0             0       0
# fuel_receipts_costs_eia923              0             0       0
# generation_eia923                       0             0       0
# generation_fuel_eia923                  0             0       0
# generators_eia860                  300365             0  403775
# ownership_eia860                        0             0   47349
# plants_eia860                       96136         19024  144689
#
#                               street_address  \
# table
# boiler_fuel_eia923                         0
# boiler_generator_assn_eia860               0
# fuel_receipts_costs_eia923                 0
# generation_eia923                          0
# generation_fuel_eia923                     0
# generators_eia860                          0
# ownership_eia860                           0
# plants_eia860                         106560
#
#                               transmission_distribution_owner_id  \
# table
# boiler_fuel_eia923                                             0
# boiler_generator_assn_eia860                                   0
# fuel_receipts_costs_eia923                                     0
# generation_eia923                                              0
# generation_fuel_eia923                                         0
# generators_eia860                                              0
# ownership_eia860                                               0
# plants_eia860                                             105641
#
#                               transmission_distribution_owner_name  \
# table
# boiler_fuel_eia923                                               0
# boiler_generator_assn_eia860                                     0
# fuel_receipts_costs_eia923                                       0
# generation_eia923                                                0
# generation_fuel_eia923                                           0
# generators_eia860                                                0
# ownership_eia860                                                 0
# plants_eia860                                                93877
#
#                               transmission_distribution_owner_state  \
# table
# boiler_fuel_eia923                                                0
# boiler_generator_assn_eia860                                      0
# fuel_receipts_costs_eia923                                        0
# generation_eia923                                                 0
# generation_fuel_eia923                                            0
# generators_eia860                                                 0
# ownership_eia860                                                  0
# plants_eia860                                                103247
#
#                               utility_id_eia  water_source  zip_code
# table
# boiler_fuel_eia923                         0             0         0
# boiler_generator_assn_eia860           80356             0         0
# fuel_receipts_costs_eia923                 0             0         0
# generation_eia923                          0             0         0
# generation_fuel_eia923                     0             0         0
# generators_eia860                     459931             0         0
# ownership_eia860                       74481             0         0
# plants_eia860                         144699         85893    144011

# %%
compiled_plants.groupby("table").count()["service_area"]
# Out:
# table
# boiler_fuel_eia923                  0
# boiler_generator_assn_eia860        0
# fuel_receipts_costs_eia923          0
# generation_eia923                   0
# generation_fuel_eia923              0
# generators_eia860                   0
# ownership_eia860                    0
# plants_eia860                   19024
# Name: service_area, dtype: int64

# %%
compiled_plants[~compiled_plants['service_area'].isna()].report_date.value_counts()
# Out:
# 2006-01-01    3379
# 2005-01-01    3244
# 2004-01-01    3176
# 2003-01-01    3137
# 2002-01-01    3099
# 2001-01-01    2989
# Name: report_date, dtype: int64

# %%
col_dfs["service_area"].sort_values(by="service_area_consistent_rate").head(15)
# Out:
#        plant_id_eia report_date                    service_area  \
# 9402          55569  2001-01-01                Exelon Energy Co
# 4952           3170  2002-01-01                 PECO Energy Co.
# 4940           3168  2002-01-01                 PECO Energy Co.
# 4934           3166  2002-01-01                 PECO Energy Co.
# 4928           3163  2002-01-01                 PECO Energy Co.
# 4922           3162  2002-01-01                 PECO Energy Co.
# 15607         55377  2002-01-01    Allegheny Electric Coop, Inc
# 15605         55196  2002-01-01    Allegheny Electric Coop, Inc
# 4910           3160  2002-01-01                 PECO Energy Co.
# 15576          3179  2001-01-01  Allegheny Energy Supply Co LLC
# 13431         50615  2001-01-01                 TXU Electric Co
# 6081          54905  2001-01-01                       ABTCO Inc
# 15564          1570  2001-01-01  Allegheny Energy Supply Co LLC
# 15565          1570  2002-01-01    Allegheny Electric Coop, Inc
# 15570          3178  2001-01-01  Allegheny Energy Supply Co LLC
#
#        entity_occurences  record_occurences  service_area_consistent_rate  \
# 9402                   6                  1                      0.166667
# 4952                   6                  1                      0.166667
# 4940                   6                  1                      0.166667
# 4934                   6                  1                      0.166667
# 4928                   6                  1                      0.166667
# 4922                   6                  1                      0.166667
# 15607                  6                  1                      0.166667
# 15605                  6                  1                      0.166667
# 4910                   6                  1                      0.166667
# 15576                  6                  1                      0.166667
# 13431                  6                  1                      0.166667
# 6081                   6                  1                      0.166667
# 15564                  6                  1                      0.166667
# 15565                  6                  1                      0.166667
# 15570                  6                  1                      0.166667
#
#        service_area_consistent
# 9402                     False
# 4952                     False
# 4940                     False
# 4934                     False
# 4928                     False
# 4922                     False
# 15607                    False
# 15605                    False
# 4910                     False
# 15576                    False
# 13431                    False
# 6081                     False
# 15564                    False
# 15565                    False
# 15570                    False

# %% [markdown]
# ## Create a locally cached datastore

# %%
ds = pudl.workspace.datastore.Datastore(local_cache_path=Path(pudl_settings["data_dir"]))

# %% [markdown]
# # EIA-860

# %% [markdown]
# ## Extract just the EIA-860

# %%
# %%time
eia860_extractor = pudl.extract.eia860.Extractor(ds)
eia860_raw_dfs = eia860_extractor.extract(year=eia860_years)
# Out:
# Extracting eia860 spreadsheet data.
#
# boiler_generator_assn
# Columns for boiler_generator_assn are off: should be 4 but got 8
# Unmapped raw columns: {'report_year', 'steam_plant_type', 'utility_name', 'plant_name'}
#
# generator
# Columns for generator are off: should be 67 but got 70
# Unmapped raw columns: {'report_year', 'fercdock', 'ferccogen'}
#
# generator_existing
#
# generator_proposed
#
# generator_retired
#
# ownership
#
# plant
# Columns for plant are off: should be 47 but got 49
# Unmapped raw columns: {'report_year', 'ferc_exempt_wholesale_generator_docket_number'}
#
# utility
# CPU times: user 51.1 s, sys: 956 ms, total: 52.1 s
# Wall time: 52.8 s

# %%
eia860_raw_dfs.keys()
# Out:
# dict_keys(['boiler_generator_assn', 'generator', 'generator_existing', 'generator_proposed', 'generator_retired', 'ownership', 'plant', 'utility'])

# %%
# for table_name, df in eia860_raw_dfs.items():
#     print(table_name)
#     print(df.info())
#     print()

# # eia860_raw_dfs["ownership"].info()

# %%
generators_df = eia860_raw_dfs['generator']

generators_df.report_year.value_counts()
# Out:
# 2001.0    16029
# Name: report_year, dtype: int64

# %% [markdown]
# ## Transform just the EIA-860

# %%
# %%time
eia860_transformed_dfs = pudl.transform.eia860.transform(
    eia860_raw_dfs, eia860_tables=eia860_tables)
# Out:
# Transforming raw EIA 860 DataFrames for ownership_eia860 concatenated across all years.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7595 entries, 0 to 7594
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   fraction_owned           7595 non-null   float64
#  1   generator_id             7595 non-null   object
#  2   operational_status_code  4792 non-null   object
#  3   owner_city               4531 non-null   object
#  4   owner_name               7595 non-null   object
#  5   owner_state              4511 non-null   string
#  6   owner_street_address     4415 non-null   object
#  7   owner_utility_id_eia     7595 non-null   Int64
#  8   owner_zip_code           4523 non-null   object
#  9   plant_id_eia             7595 non-null   Int64
#  10  plant_name_eia           4792 non-null   object
#  11  state                    4792 non-null   object
#  12  utility_id_eia           7595 non-null   Int64
#  13  utility_name_eia         4792 non-null   object
#  14  report_date              7595 non-null   datetime64[ns]
# dtypes: Int64(3), datetime64[ns](1), float64(1), object(9), string(1)
# memory usage: 912.4+ KB
# None
#
# Transforming raw EIA 860 DataFrames for generators_eia860 concatenated across all years.
# Transforming raw EIA 860 DataFrames for plants_eia860 concatenated across all years.
# Transforming raw EIA 860 DataFrames for boiler_generator_assn_eia860 concatenated across all years.
# Transforming raw EIA 860 DataFrames for utilities_eia860 concatenated across all years.
# CPU times: user 14.1 s, sys: 1.15 s, total: 15.2 s
# Wall time: 15.4 s

# %%
eia860_transformed_dfs.keys()
# Out:
# dict_keys(['ownership_eia860', 'generators_eia860', 'plants_eia860', 'boiler_generator_assn_eia860', 'utilities_eia860'])

# %%
eia860_transformed_dfs.keys()
# Out:
# dict_keys(['ownership_eia860', 'generators_eia860', 'plants_eia860', 'boiler_generator_assn_eia860', 'utilities_eia860'])

# %%
eia860_transformed_dfs['generators_eia860'].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67678 entries, 0 to 35093
# Data columns (total 106 columns):
#  #    Column                                     Dtype
# ---   ------                                     -----
#  0    associated_combined_heat_power             object
#  1    bypass_heat_recovery                       object
#  2    capacity_mw                                float64
#  3    carbon_capture                             object
#  4    cofire_fuels                               object
#  5    county                                     object
#  6    data_source                                object
#  7    deliver_power_transgrid                    object
#  8    distributed_generation                     object
#  9    duct_burners                               object
#  10   energy_source_1_transport_1                object
#  11   energy_source_1_transport_2                object
#  12   energy_source_1_transport_3                object
#  13   energy_source_2_transport_1                object
#  14   energy_source_2_transport_2                object
#  15   energy_source_2_transport_3                object
#  16   energy_source_code_1                       object
#  17   energy_source_code_2                       object
#  18   energy_source_code_3                       object
#  19   energy_source_code_4                       object
#  20   energy_source_code_5                       object
#  21   energy_source_code_6                       object
#  22   ferc_cogen_docket_no                       object
#  23   ferc_cogen_status                          object
#  24   ferc_exempt_wholesale_generator            object
#  25   ferc_exempt_wholesale_generator_docket_no  object
#  26   ferc_small_power_producer                  object
#  27   ferc_small_power_producer_docket_no        object
#  28   ferccogen                                  object
#  29   fercdock                                   object
#  30   fercextdoc                                 object
#  31   fercother                                  object
#  32   fluidized_bed_tech                         object
#  33   generator_id                               object
#  34   minimum_load_mw                            float64
#  35   multigen                                   object
#  36   multiple_fuels                             object
#  37   nameplate_power_factor                     float64
#  38   operating_switch                           float64
#  39   operational_status                         object
#  40   operational_status_code                    object
#  41   other_combustion_tech                      object
#  42   other_planned_modifications                object
#  43   owned_by_non_utility                       object
#  44   owner                                      object
#  45   ownership_code                             object
#  46   planned_energy_source_code_1               object
#  47   planned_modifications                      object
#  48   planned_net_summer_capacity_derate_mw      float64
#  49   planned_net_summer_capacity_uprate_mw      float64
#  50   planned_net_winter_capacity_derate_mw      float64
#  51   planned_net_winter_capacity_uprate_mw      float64
#  52   planned_new_capacity_mw                    float64
#  53   planned_new_prime_mover_code               object
#  54   plant_id_eia                               float64
#  55   plant_name_eia                             object
#  56   previously_canceled                        object
#  57   prime_mover_code                           object
#  58   propwind                                   float64
#  59   pulverized_coal_tech                       object
#  60   reactive_power_output_mvar                 float64
#  61   rto_iso_lmp_node_id                        object
#  62   rto_iso_location_wholesale_reporting_id    object
#  63   sector_id                                  float64
#  64   sector_name                                object
#  65   solid_fuel_gasification                    object
#  66   startup_source_code_1                      object
#  67   startup_source_code_2                      object
#  68   startup_source_code_3                      object
#  69   startup_source_code_4                      object
#  70   state                                      object
#  71   stoker_tech                                object
#  72   subcritical_tech                           object
#  73   summer_capacity_estimate                   object
#  74   summer_capacity_mw                         float64
#  75   summer_estimated_capability_mw             float64
#  76   supercritical_tech                         object
#  77   switch_oil_gas                             object
#  78   syncronized_transmission_grid              object
#  79   technology_description                     object
#  80   time_cold_shutdown_full_load_code          object
#  81   topping_bottoming_code                     object
#  82   transmode1                                 object
#  83   transmode2                                 object
#  84   turbines_inverters_hydrokinetics           float64
#  85   turbines_num                               float64
#  86   ultrasupercritical_tech                    object
#  87   unit_id_eia                                object
#  88   uprate_derate_during_year                  object
#  89   utility_id_eia                             float64
#  90   utility_name_eia                           object
#  91   winter_capacity_estimate                   object
#  92   winter_capacity_mw                         float64
#  93   winter_estimated_capability_mw             float64
#  94   current_planned_operating_date             datetime64[ns]
#  95   operating_date                             datetime64[ns]
#  96   original_planned_operating_date            datetime64[ns]
#  97   other_modifications_date                   datetime64[ns]
#  98   planned_derate_date                        datetime64[ns]
#  99   planned_repower_date                       datetime64[ns]
#  100  planned_retirement_date                    datetime64[ns]
#  101  planned_uprate_date                        datetime64[ns]
#  102  retirement_date                            datetime64[ns]
#  103  uprate_derate_completed_date               datetime64[ns]
#  104  fuel_type_code_pudl                        object
#  105  report_date                                datetime64[ns]
# dtypes: datetime64[ns](11), float64(20), object(75)
# memory usage: 55.2+ MB

# %% [markdown]
# # What is transmode1?

# %%
generators = eia860_transformed_dfs['generators_eia860']

# %%
generators.report_date.value_counts()
# Out:
# 2019-01-01    29009
# 2004-01-01    19493
# 2003-01-01    19176
# Name: report_date, dtype: int64

# %%
generators.groupby(generators.transmode1.isna()).report_date.value_counts()
# Out:
# transmode1  report_date
# False       2003-01-01     13972
# True        2019-01-01     29009
#             2004-01-01     19493
#             2003-01-01      5204
# Name: report_date, dtype: int64

# %% [markdown]
# Confirmed mutligen is only in 2003.

# %% [markdown]
# ## unit_id_eia

# %%
generators.groupby(generators.unit_id_eia.isna()).report_date.value_counts()
# Out:
# unit_id_eia  report_date
# False        2019-01-01      2210
#              2004-01-01       307
# True         2019-01-01     26799
#              2004-01-01     19186
#              2003-01-01     19176
# Name: report_date, dtype: int64

# %%
gen04 = generators.query("report_date == '2004-01-01'")

gen04[~gen04.unit_id_eia.isna()][["generator_id", "unit_id_eia"]]
# Out:
#       generator_id unit_id_eia
# 2240             4         4.0
# 17944            1        B151
# 17945            2        B151
# 17946            3        B151
# 17962            1        B152
# ...            ...         ...
# 33970         TG-2        F601
# 33971         TG-3        F601
# 34120         GEN1        F301
# 34121         GEN2        F301
# 34122         GEN3        F301
#
# [307 rows x 2 columns]

# %%
gen03 = generators.query("report_date == '2003-01-01'")

gen03[~gen03.multigen.isna()][["generator_id", "multigen"]]
# Out:
#       generator_id multigen
# 1602             1      1.0
# 1603             2      2.0
# 588              1     B151
# 589              2     B151
# 590              3     B151
# ...            ...      ...
# 16739         TG-2     F601
# 16740         TG-3     F601
# 16894         GEN1     F301
# 16895         GEN2     F301
# 16896         GEN3     F301
#
# [455 rows x 2 columns]

# %%
gen03.multigen.value_counts().head(10)
# Out:
# A094    27
# A096    23
# A092    18
# A103    16
# A110    14
# C789    13
# C052    12
# D004    12
# B148    10
# F901     8
# Name: multigen, dtype: int64

# %%
gen04.unit_id_eia.value_counts().head(10)
# Out:
# C789    13
# D004    12
# G281    12
# C052    12
# B148    10
# B061     8
# F901     8
# D016     8
# D002     6
# F401     5
# Name: unit_id_eia, dtype: int64

# %% [markdown]
# # EIA-923

# %% [markdown]
# ## Extract just the EIA-923

# %%
# %%time
eia923_extractor = pudl.extract.eia923.Extractor(ds)
eia923_raw_dfs = eia923_extractor.extract(year=eia923_years)

# %% [markdown]
# ## Transform just the EIA-923

# %%
# %%time
eia923_transformed_dfs = pudl.transform.eia923.transform(
    eia923_raw_dfs, eia923_tables=eia923_tables)

# %% [markdown]
# # Combined EIA Data

# %% [markdown]
# ## Merge the EIA-860 and EIA-923 Dataframe Dictionaries

# %%
# %%time
eia_transformed_dfs = eia923_transformed_dfs.copy()
eia_transformed_dfs.update(eia860_transformed_dfs.copy())

# %% [markdown]
# ## Set all column data types

# %%
# %%time
eia_transformed_dfs = pudl.helpers.convert_dfs_dict_dtypes(
    eia_transformed_dfs, 'eia')

# %% [markdown]
# ## Run the entity resolution process

# %%
entities_dfs, eia_transformed_dfs = pudl.transform.eia.transform(
    eia_transformed_dfs,
    eia860_years=eia860_years,
    eia923_years=eia923_years,
)

# %%
list(eia_transformed_dfs.keys())
