# %% [markdown]
# # Test the FERC analysis module
#
# Whew! this new analysis module is a bit much, so I created this notebook to explain what's going on, known quirks, etc.

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Standard libraries
import logging
import sys
import os
import pathlib
import random

# 3rd party libraries
import geopandas as gpd
import dask.dataframe as dd
from dask.distributed import Client
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import sqlalchemy as sa
import re

# Local libraries
import pudl
from pudl.analysis.clean_up_ferc1 import *

# Enable viewing of logging outputs
logger=logging.getLogger()
logger.setLevel(logging.INFO)
handler = logging.StreamHandler(stream=sys.stdout)
formatter = logging.Formatter('%(message)s')
handler.setFormatter(formatter)
logger.handlers = [handler]

# %%
# Establish connection to pudl database
pudl_settings = pudl.workspace.setup.get_defaults()
pudl_engine = sa.create_engine(pudl_settings['pudl_db'])
pudl_out = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine,
    freq='AS'
)

ferc_engine = sa.create_engine(pudl_settings['ferc1_db'])

# %%
# Recreate the transform process
small_plants_raw = pd.read_sql("f1_gnrt_plant", ferc_engine)
small_plants = pudl_out.plants_small_ferc1()

# Here we create a fake raw dfs dictionary with just the small plants df to run it through
# Zane's existing transform feature.
fake_dict = {'plants_small_ferc1': small_plants_raw}
new_dict = {}
small_plants_dict = pudl.transform.ferc1.plants_small(fake_dict, new_dict)
small_plants_out = small_plants_dict['plants_small_ferc1']

# drop rows with no plant name because we can't use that
small_plants_out = small_plants_out.dropna(subset=['plant_name_ferc1'])
# Out:
# /Users/aesharpe/miniconda3/envs/pudl-dev/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# Helper function

def get_rand_group(groups):
    random_set = random.choice(list(groups.groups.keys()))
    return groups.get_group(random_set)

# %%
com_cols = ['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1', 
            'row_type', 'construction_year', 'capacity_mw', 'net_generation_mwh']

# %% [markdown]
# ## Test Module

# %%
# Run full cleaning
# %%time
test_full = clean_small_gens(small_plants_out)
# Out:
# CLEANING SMALL GENS TABLE...
# Removing rows where an entire utility has reported NA in key columns
# Removing rows with three or more dashes for plant name
# Removing rows with NA for plant name
# Labeling header rows
# Labeling total rows
# Labeling notes rows
# Mapping header fuels to relevant rows
# Getting fuel type from plant name
# Extracting FERC license from plant name
# Mapping notes and ferc license from footnotes

# %%
# Run individual steps
#%%time
test1 = remove_bad_rows(small_plants_out, show_removed=True)
test2 = label_row_type(test1)
test3 = improve_plant_type(test2) ## COME UP WITH A WAY TO CHECK FUEL TYPE OVER TIME MAYBE BY PLANT ID?
test4 = extract_ferc_license(test3)
test5 = associate_notes_with_values(test4)
# Out:
# UsageError: Line magic function `%%time` not found.

# %% [markdown]
# ### Take a closer look at each of the steps...

# %% [markdown]
# #### LABELING ROW TYPE
#
# This step identifies the "type" of row as either a total, note, header, or NA (regular row).
# Pay attention to the `row_type` column.

# %%
# Look at random, relevant chunks of the data by utility and year
# Re-run this cell to refresh and see a new utility/year group

util_groups = test2.groupby(['utility_id_ferc1', 'report_year'])
get_rand_group(util_groups)[com_cols]
# Out:
#                          record_id  utility_id_ferc1  report_year  \
# 4820  f1_gnrt_plant_1999_12_95_0_1                95         1999
# 4821  f1_gnrt_plant_1999_12_95_0_2                95         1999
#
#      plant_name_ferc1 row_type  construction_year  capacity_mw  \
# 4820      gas turbine   header                NaN          0.0
# 4821        williston      NaN             1953.0          7.8
#
#       net_generation_mwh
# 4820                 NaN
# 4821             75700.0

# %% [markdown]
# #### EXTRACTING PLANT TYPE FROM HEADERS AND PLANT NAME
#
# This step extracts the plant type from the header rows as well as the plant name (when it's not a header) and puts it in the `plant_type_2` column (for comparison with Zane's `plant_type` column).
#
# Known issues:
# * 161, 1994
# * 29, 2000
# * 170, 1996
# * 44, 2003

# %%
print('\nCOMPARE PLANT TYPE FROM HEADERS WITH PLANT TYPE:')
same_plt_type = test5[
    test5['plant_type'] == test5['plant_type_2']]
diff_plt_type = test5[
    (test5['plant_type_2'].notna()) & 
    (test5['plant_type'].notna()) & 
    (test5['plant_type_2']!=test5['plant_type'])]
new_plt_type = test5[
    (test5['plant_type'].isna()) & 
    (test5['plant_type_2'].notna())]
print(
    f'''
    same plant type: {len(same_plt_type)}
    diff plant type: {len(diff_plt_type)} 
    new plant type: {len(new_plt_type)}''')

print("\nShow records where plant type differs")
display(diff_plt_type[com_cols + ['plant_type', 'plant_type_2']])
# Out:
# COMPARE PLANT TYPE FROM HEADERS WITH PLANT TYPE:
#
#     same plant type: 4547
#     diff plant type: 497
#     new plant type: 8787
#
# Show records where plant type differs
#                             record_id  utility_id_ferc1  report_year  \
# 8189     f1_gnrt_plant_2004_12_25_0_2                25         2004
# 8222    f1_gnrt_plant_2004_12_44_0_10                44         2004
# 8223    f1_gnrt_plant_2004_12_44_0_11                44         2004
# 8224    f1_gnrt_plant_2004_12_44_0_12                44         2004
# 8263    f1_gnrt_plant_2004_12_61_0_13                61         2004
# ...                               ...               ...          ...
# 16713   f1_gnrt_plant_2016_12_281_0_5               281         2016
# 16762   f1_gnrt_plant_2016_12_73_0_14                73         2016
# 16871  f1_gnrt_plant_2016_12_115_0_10               115         2016
# 16968  f1_gnrt_plant_2016_12_161_1_24               161         2016
# 16969  f1_gnrt_plant_2016_12_161_1_25               161         2016
#
#                   plant_name_ferc1 row_type  construction_year  capacity_mw  \
# 8189                    st. albans      NaN             1950.0          2.6
# 8222               * connors creek      NaN             1971.0          5.5
# 8223                 *harbor beach      NaN             1967.0          4.0
# 8224                    *st. clair      NaN             1970.0          5.5
# 8263         vergennes station # 9      NaN             1963.0          4.0
# ...                            ...      ...                ...          ...
# 16713                 total diesel    total                NaN         10.0
# 16762                  twin branch      NaN             2016.0          2.6
# 16871           auburn gas turbine      NaN             2000.0          7.3
# 16968   uc santa barbara fuel cell      NaN             2012.0          0.2
# 16969  cs san bernardino fuel cell      NaN             2013.0          1.4
#
#        net_generation_mwh           plant_type         plant_type_2
# 8189                 43.0  internal_combustion       diesel_turbine
# 8222                -21.0  internal_combustion           steam_heat
# 8223                -45.0  internal_combustion           steam_heat
# 8224               -654.0  internal_combustion           steam_heat
# 8263                606.0  internal_combustion       diesel_turbine
# ...                   ...                  ...                  ...
# 16713           -182490.0  internal_combustion       diesel_turbine
# 16762              1388.0                hydro             solar_pv
# 16871               245.0          gas_turbine  internal_combustion
# 16968           1648683.0            fuel_cell             solar_pv
# 16969           6710246.0            fuel_cell             solar_pv
#
# [497 rows x 10 columns]

# %%
# Look at random, relevant chunks of the data by utility and year
# Re-run this cell to refresh and see a new utility/year group

util_groups = test3.groupby(['utility_id_ferc1', 'report_year'])
util_groups_with_row_types = (
    util_groups.filter(lambda x: x['row_type'].notna().any())
    .groupby(['utility_id_ferc1', 'report_year']))
get_rand_group(util_groups_with_row_types)[com_cols + ['plant_type', 'plant_type_2']]
# Out:
#                           record_id  utility_id_ferc1  report_year  \
# 3055   f1_gnrt_plant_1997_12_69_0_1                69         1997
# 3056   f1_gnrt_plant_1997_12_69_0_3                69         1997
# 3057   f1_gnrt_plant_1997_12_69_0_4                69         1997
# 3058   f1_gnrt_plant_1997_12_69_0_5                69         1997
# 3059   f1_gnrt_plant_1997_12_69_0_7                69         1997
# 3060  f1_gnrt_plant_1997_12_69_0_13                69         1997
# 3061  f1_gnrt_plant_1997_12_69_0_15                69         1997
# 3062  f1_gnrt_plant_1997_12_69_0_16                69         1997
# 3063  f1_gnrt_plant_1997_12_69_0_17                69         1997
# 3064  f1_gnrt_plant_1997_12_69_0_19                69         1997
# 3065  f1_gnrt_plant_1997_12_69_0_23                69         1997
#
#                                       plant_name_ferc1 row_type  \
# 3055                                    diesel plants:   header
# 3056                                       centerville      NaN
# 3057                                              ames      NaN
# 3058                                      marshalltown      NaN
# 3059  total diesel....................................    total
# 3060                                     hydro plants:   header
# 3061                                           anamosa      NaN
# 3062                                         maquoketa      NaN
# 3063                                        iowa falls      NaN
# 3064  total hydro.....................................    total
# 3065  total small plants..............................    total
#
#       construction_year  capacity_mw  net_generation_mwh plant_type  \
# 3055                NaN          NaN                 NaN        NaN
# 3056             1963.0         6.00            -38000.0        NaN
# 3057             1960.0         2.00              2500.0        NaN
# 3058             1941.0         5.00           -142020.0        NaN
# 3059                NaN        13.00           -177520.0        NaN
# 3060                NaN          NaN                 NaN        NaN
# 3061             1990.0         0.24           1050240.0        NaN
# 3062             1924.0         1.36           5465000.0        NaN
# 3063             1926.0         0.65           1548453.0        NaN
# 3064                NaN         2.25           8063693.0        NaN
# 3065                NaN        15.25           7886173.0        NaN
#
#         plant_type_2
# 3055  diesel_turbine
# 3056  diesel_turbine
# 3057  diesel_turbine
# 3058  diesel_turbine
# 3059  diesel_turbine
# 3060           hydro
# 3061           hydro
# 3062           hydro
# 3063           hydro
# 3064           hydro
# 3065           hydro

# %% [markdown]
# #### EXTRACTING FERC LICENSES AND ASSOCIATING NOTES WITH PROPER ROWS
#
# This step takes ferc licenses from the name and from notes and associates both the ferc license and the note with the relevant row when possible. Pay attention to the `ferc_license`, `ferc_license_manual`, and `notes` columns.
#
# Known issues:
# * 193, 2001
# * 61, 2002

# %%
manual_lic = test5[test5['ferc_license_manual'].notna()]
prog_lic_of_manual = manual_lic[manual_lic['ferc_license'].notna()]
print(f'{round(len(prog_lic_of_manual) / len(manual_lic) * 100)}% of FERC licenses that were manually mapped are caught by the program')
print('Sample of manual licenses not grabbed by program')
display(manual_lic[manual_lic['ferc_license'].isna()].sample(2))

same_lic = prog_lic_of_manual[prog_lic_of_manual['ferc_license_manual']==prog_lic_of_manual['ferc_license']]
print(f'\n{round(len(prog_lic_of_manual) / len(same_lic) * 100)}% of manual licenses are the same as the programatically mapped ones!')
print('Cases where manual license differs from programatic license excluding NA values')
display(prog_lic_of_manual[prog_lic_of_manual['ferc_license_manual']!=prog_lic_of_manual['ferc_license']])

prog_lic = test5[test5['ferc_license'].notna()]
print(f'\nThere are {len(manual_lic)} manually mapped licenses vs. {len(prog_lic)} programatically mapped licenses')
# Out:
# 90% of FERC licenses that were manually mapped are caught by the program
# Sample of manual licenses not grabbed by program
#        utility_id_ferc1  report_year          plant_name_ferc1 row_type  \
# 12726                61         2011  waterbury station # 22 a      NaN
# 9598                 17         2006            marshall hydro      NaN
#
#        construction_year  capacity_mw  peak_demand_mw  net_generation_mwh  \
# 12726             1953.0         5.52             0.0             24075.0
# 9598              1910.0         5.00             4.0           5357000.0
#
#        total_cost_of_plant  capex_per_mw  ...  opex_maintenance  fuel_type  \
# 12726            2359550.0      427455.0  ...          109688.0
# 9598            12177532.0     2435506.0  ...          115743.0        n/a
#
#        fuel_cost_per_mmbtu   plant_name_clean  plant_type ferc_license_manual  \
# 12726                  NaN  waterbury station       hydro                2090
# 9598                   NaN     marshall hydro       hydro                2380
#
#                           record_id  plant_type_2 ferc_license notes
# 12726  f1_gnrt_plant_2011_12_61_0_8         hydro         <NA>  <NA>
# 9598   f1_gnrt_plant_2006_12_17_0_1         hydro         <NA>  <NA>
#
# [2 rows x 22 columns]
# 100% of manual licenses are the same as the programatically mapped ones!
# Cases where manual license differs from programatic license excluding NA values
#        utility_id_ferc1  report_year                 plant_name_ferc1  \
# 9776                151         2006  rochester station #160 (note 3)
# 10472               151         2007  rochester station #160 (note 3)
#
#       row_type  construction_year  capacity_mw  peak_demand_mw  \
# 9776       NaN             1916.0         0.34             0.0
# 10472      NaN             1916.0         0.34             0.0
#
#        net_generation_mwh  total_cost_of_plant  capex_per_mw  ...  \
# 9776                  NaN             254356.0      748106.0  ...
# 10472                 NaN                  NaN           NaN  ...
#
#        opex_maintenance  fuel_type  fuel_cost_per_mmbtu  \
# 9776                NaN      hydro                  NaN
# 10472               NaN      hydro                  NaN
#
#              plant_name_clean  plant_type ferc_license_manual  \
# 9776   rochester station #160       hydro                2596
# 10472  rochester station #160       hydro                2596
#
#                            record_id  plant_type_2 ferc_license notes
# 9776   f1_gnrt_plant_2006_12_151_0_5           NaN          160   NaN
# 10472  f1_gnrt_plant_2007_12_151_0_5           NaN          160   NaN
#
# [2 rows x 22 columns]
# There are 1842 manually mapped licenses vs. 4754 programatically mapped licenses

# %%
# Look at random, relevant chunks of the data by utility and year
# Re-run this cell to refresh and see a new utility/year group

util_groups = test5.groupby(['utility_id_ferc1', 'report_year'])
util_groups_with_licenses = (
    util_groups.filter(lambda x: x['ferc_license'].notna().any())
    .groupby(['utility_id_ferc1', 'report_year']))
util_groups_with_notes = (
    util_groups.filter(lambda x: x['notes'].notna().any())
    .groupby(['utility_id_ferc1', 'report_year']))

# Show chunks with ferc licenses
print("HIGHLIGHT FERC LICENSES")
display(get_rand_group(util_groups_with_licenses)[com_cols + ['ferc_license', 'ferc_license_manual', 'notes']])

# Show chunks with notes
print("HIGHLIGHT NOTES")
display(get_rand_group(util_groups_with_notes)[com_cols + ['ferc_license', 'ferc_license_manual', 'notes']])
# Out:
# HIGHLIGHT FERC LICENSES
#                            record_id  utility_id_ferc1  report_year  \
# 8528   f1_gnrt_plant_2004_12_195_0_1               195         2004
# 8529   f1_gnrt_plant_2004_12_195_0_2               195         2004
# 8530   f1_gnrt_plant_2004_12_195_0_3               195         2004
# 8531   f1_gnrt_plant_2004_12_195_0_4               195         2004
# 8532   f1_gnrt_plant_2004_12_195_0_5               195         2004
# 8533   f1_gnrt_plant_2004_12_195_0_6               195         2004
# 8534   f1_gnrt_plant_2004_12_195_0_7               195         2004
# 8535   f1_gnrt_plant_2004_12_195_0_8               195         2004
# 8536   f1_gnrt_plant_2004_12_195_0_9               195         2004
# 8537  f1_gnrt_plant_2004_12_195_0_10               195         2004
# 8538  f1_gnrt_plant_2004_12_195_0_11               195         2004
# 8539  f1_gnrt_plant_2004_12_195_0_12               195         2004
# 8540  f1_gnrt_plant_2004_12_195_0_13               195         2004
# 8541  f1_gnrt_plant_2004_12_195_0_14               195         2004
# 8542  f1_gnrt_plant_2004_12_195_0_15               195         2004
# 8543  f1_gnrt_plant_2004_12_195_0_17               195         2004
# 8544  f1_gnrt_plant_2004_12_195_0_20               195         2004
# 8545  f1_gnrt_plant_2004_12_195_0_21               195         2004
# 8546  f1_gnrt_plant_2004_12_195_0_22               195         2004
# 8547  f1_gnrt_plant_2004_12_195_0_24               195         2004
# 8548  f1_gnrt_plant_2004_12_195_0_27               195         2004
# 8549  f1_gnrt_plant_2004_12_195_0_28               195         2004
# 8550  f1_gnrt_plant_2004_12_195_0_29               195         2004
# 8551  f1_gnrt_plant_2004_12_195_0_36               195         2004
# 8552  f1_gnrt_plant_2004_12_195_0_31               195         2004
# 8553  f1_gnrt_plant_2004_12_195_0_37               195         2004
#
#                            plant_name_ferc1 row_type  construction_year  \
# 8528                 hydro: lic project no.   header                NaN
# 8529                     caldron falls 2525      NaN             1924.0
# 8530                        high falls 2595      NaN             1910.0
# 8531                     johnson falls 2522      NaN             1923.0
# 8532                  sandstone rapids 2546      NaN             1925.0
# 8533                     potato rapids 2560      NaN             1921.0
# 8534                          peshtigo 2581      NaN             1920.0
# 8535                      otter rapids 1957      NaN             1907.0
# 8536                           hat rapids *      NaN             1905.0
# 8537                          tomahawk 1940      NaN             1937.0
# 8538                         alexander 1979      NaN             1924.0
# 8539                             merrill **      NaN             1917.0
# 8540                            wausau 1999      NaN             1921.0
# 8541                            jersey 2476      NaN             1920.0
# 8542                      grand rapids 2433      NaN             1910.0
# 8543                            total hydro    total                NaN
# 8544                    internal combustion   header                NaN
# 8545                            eagle river      NaN             1964.0
# 8546                          oneida casino      NaN             1996.0
# 8547              total internal combustion    total                NaN
# 8548                          wind turbines   header                NaN
# 8549                       lincoln turbines      NaN             1999.0
# 8550                      glenmore turbines      NaN             1998.0
# 8551     * license surrendered august 1982.      NaN                NaN
# 8552                             total wind    total                NaN
# 8553  ** license surrendered december 1981.     note                NaN
#
#       capacity_mw  net_generation_mwh  ferc_license  ferc_license_manual notes
# 8528         0.00                 NaN          <NA>                 <NA>  <NA>
# 8529         6.40             14872.0          2525                 2525  <NA>
# 8530         7.00             18520.0          2595                 2595  <NA>
# 8531         3.52             11715.0          2522                 2522  <NA>
# 8532         3.84             12557.0          2546                 2546  <NA>
# 8533         1.38              4335.0          2560                 2560  <NA>
# 8534         0.59              3405.0          2581                 2581  <NA>
# 8535         0.50              1589.0          1957                 1957  <NA>
# 8536         1.70              7723.0          <NA>                 <NA>  <NA>
# 8537         2.60             12276.0          1940                 1940  <NA>
# 8538         4.20             19944.0          1979                 1979  <NA>
# 8539         2.34              8405.0          <NA>                 <NA>  <NA>
# 8540         5.40             26011.0          1999                 1999  <NA>
# 8541         0.51              3030.0          2476                 2476  <NA>
# 8542         7.57             32660.0          2433                 2433  <NA>
# 8543        47.55            177042.0          <NA>                 <NA>  <NA>
# 8544         0.00                 NaN          <NA>                 <NA>  <NA>
# 8545         4.00                88.0          <NA>                 <NA>  <NA>
# 8546         4.00                 5.0          <NA>                 <NA>  <NA>
# 8547         8.00                93.0          <NA>                 <NA>  <NA>
# 8548         0.00                 NaN          <NA>                 <NA>  <NA>
# 8549         9.24             16432.0          <NA>                 <NA>  <NA>
# 8550         1.20              2004.0          <NA>                 <NA>  <NA>
# 8551         0.00                 NaN          <NA>                 <NA>  <NA>
# 8552        10.44             18436.0          <NA>                 <NA>  <NA>
# 8553         0.00                 NaN          <NA>                 <NA>  <NA>
# HIGHLIGHT NOTES
#                            record_id  utility_id_ferc1  report_year  \
# 3490   f1_gnrt_plant_1997_12_211_0_1               211         1997
# 3491  f1_gnrt_plant_1997_12_211_0_46               211         1997
#
#                            plant_name_ferc1 row_type  construction_year  \
# 3490  black creek hydroelectric project (1)      NaN             1994.0
# 3491                 (1) ferc project #6221     note                NaN
#
#       capacity_mw  net_generation_mwh  ferc_license  ferc_license_manual  \
# 3490          3.7          10474200.0          6221                 <NA>
# 3491          NaN                 NaN          6221                 <NA>
#
#                        notes
# 3490  (1) ferc project #6221
# 3491                    <NA>
