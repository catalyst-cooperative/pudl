# %% [markdown]
# # Clean up the small generators FERC table

# %% [markdown]
# **TO DO:**
# * [ ] Add fuel type for all obvious name drops (and account for outliers)
# * [ ] Create ferc id column
# * [ ] Reconsile fuel_type with plant_type columns
# * [ ]

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard libraries
import logging
import sys
import os
import pathlib
import random

# 3rd party libraries
import geopandas as gpd
import dask.dataframe as dd
from dask.distributed import Client
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import sqlalchemy as sa
import re

# Local libraries
import pudl
from pudl.analysis.clean_up_ferc1 import *

# Enable viewing of logging outputs
logger=logging.getLogger()
logger.setLevel(logging.INFO)
handler = logging.StreamHandler(stream=sys.stdout)
formatter = logging.Formatter('%(message)s')
handler.setFormatter(formatter)
logger.handlers = [handler]

# %%
# Establish connection to pudl database
pudl_settings = pudl.workspace.setup.get_defaults()
pudl_engine = sa.create_engine(pudl_settings['pudl_db'])
pudl_out = pudl.output.pudltabl.PudlTabl(
    pudl_engine=pudl_engine,
    freq='AS'
)

ferc_engine = sa.create_engine(pudl_settings['ferc1_db'])

# %%
small_plants_raw = pd.read_sql("f1_gnrt_plant", ferc_engine)
small_plants = pudl_out.plants_small_ferc1()

# %%
# Here we create a fake raw dfs dictionary with just the small plants df to run it through
# Zane's existing transform feature.
fake_dict = {'plants_small_ferc1': small_plants_raw}
new_dict = {}
small_plants_dict = pudl.transform.ferc1.plants_small(fake_dict, new_dict)
small_plants_out = small_plants_dict['plants_small_ferc1']

# drop rows with no plant name because we can't use that
small_plants_out = small_plants_out.dropna(subset=['plant_name_ferc1'])
# Out:
# /Users/aesharpe/miniconda3/envs/pudl-dev/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ## Constants

# %%
# If these columns are nan, we can assume it is either a header row or isn't useful
nan_cols = ['construction_year', 'net_generation_mwh', 'total_cost_of_plant', 'capex_per_mw', 'opex_total', 
            'opex_fuel', 'opex_maintenance', 'fuel_cost_per_mmbtu']

# If a potential header column has these strings, it's probably a useful header
header_strings = ['hydro', 'hyrdo', 'internal', 'wind', 'solar', 'gas', 'diesel', 'diesal', 
                  'steam', 'other', 'combustion', 'combustine', 'fuel cell', 'hydraulic', 
                  'waste', 'landfill', 'photovoltaic', 'nuclear', 'oil', 'renewable', 
                  'facilities', 'combined cycle']

# If a potential header has these strings, it is not a header...
exclude = ['#', '\*', 'pg', 'solargenix', 'solargennix', '\@', 'rockton', 'albany steam']

# ...unless it also has one of these strings
exceptions = ['hydro plants: licensed proj. no.', 'hydro license no.', 
              'hydro: license no.', 'hydro plants: licensed proj no.']

# plants with two fuel names
two_fuel_names_dict = {'las vegas solar': 'solar_pv', 'solar centaur': 'gas_turbine'}

# What we will rename the headers once we remove them as rows 
new_header_labels = {
    'hydroelectric': ['hydro', 'hyrdo'],
    'internal combustion': ['internal', 'interal', 'international combustion'],
    'combustion turbine': ['combustion turbine'],
    'combined cycle': ['combined cycle'],
    'gas turbine': ['gas'],
    'petroleum liquids': ['oil', 'diesel', 'diesal'],
    'solar': ['solar', 'photovoltaic'],
    'wind': ['wind'],
    'geothermal': ['geothermal'],
    'waste': ['waste', 'landfill'],
    'steam': ['steam'],
    'nuclear': ['nuclear'],
    'fuel_cell': ['fuel cell'],
    'other': ['other'],
    'renewables': ['renewables'],
}

# Header names that match the one's that zane used in his manual mapping (so we can 
# compare processes)
zane_header_labels = {
    'solar_pv': ['solar', 'photovoltaic'],
    'wind': ['wind'],
    'hydro': ['hydro', 'hyrdo'],
    'internal_combustion': ['internal', 'interal', 'international combustion', ],
    'combustion_turbine': ['combustion turbine', 'combustine turbine'],
    'combined_cycle': ['combined cycle'],
    'diesel_turbine': ['oil', 'diesel', 'diesal'],
    'gas_turbine': ['gas'],
    'geothermal': ['geothermal'],
    'waste_heat': ['waste', 'landfill'],
    'steam_heat': ['steam'],
    'nuclear': ['nuclear'],
    'fuel_cell': ['fuel cell'],
}

def expand_dict(dic):
    d = {}
    for k, lst in dic.items():    
        for i in range(len(lst)):
            d[lst[i]] = k
            #new_d = d.copy()
            #l.append(new_d)
    return d

import random

def get_rand_group(groups):
    random_set = random.choice(list(groups.groups.keys()))
    return groups.get_group(random_set)

# %% [markdown]
# ## TEST MODULE

# %%
# %%time
test1 = remove_bad_rows(small_plants_out, show_removed=False)
# Out:
# Removing rows where an entire utility has reported NA in key columns
# Removing rows with three or more dashes for plant name
# Removing rows with NA for plant name
# CPU times: user 278 ms, sys: 11.1 ms, total: 289 ms
# Wall time: 334 ms

# %%
# %%time
test2 = label_row_type(test1)
# Out:
# Labeling header rows
# Labeling total rows
# Labeling notes rows
# CPU times: user 14.6 s, sys: 144 ms, total: 14.7 s
# Wall time: 15.9 s

# %%
# TAKE A PEEK
util_groups = test2.groupby(['utility_id_ferc1', 'report_year'])
get_rand_group(util_groups)[['utility_id_ferc1', 'report_year', 'plant_name_ferc1', 'row_type', 'capacity_mw', 'net_generation_mwh', 'construction_year']]
# Out:
#       utility_id_ferc1  report_year       plant_name_ferc1 row_type  \
# 5504               132         2000                 hydro:   header
# 5505               132         2000              hoot lake      NaN
# 5506               132         2000                 wright      NaN
# 5507               132         2000                 pisgah      NaN
# 5508               132         2000          dayton hollow      NaN
# 5509               132         2000           taplin gorge      NaN
# 5510               132         2000                bemidji      NaN
# 5511               132         2000   internal combustion:   header
# 5512               132         2000  fergus control center      NaN
#
#       capacity_mw  net_generation_mwh  construction_year
# 5504         0.00                 NaN                NaN
# 5505         1.00           3020960.0             1914.0
# 5506         0.40           2937467.0             1922.0
# 5507         0.52           5326362.0             1917.0
# 5508         0.97           7713186.0             1909.0
# 5509         0.56           4090800.0             1925.0
# 5510         0.74           1624836.0                NaN
# 5511         0.00                 NaN                NaN
# 5512         1.83             23865.0             1995.0

# %%
# %%time
test3 = improve_fuel_type(test2)
# Out:
# Mapping header fuels to relevant rows
# Getting fuel type from plant name
# CPU times: user 99.3 ms, sys: 7.81 ms, total: 107 ms
# Wall time: 116 ms

# %%
# TAKE A PEEK
util_groups = test3.groupby(['utility_id_ferc1', 'report_year'])
get_rand_group(util_groups)[['utility_id_ferc1', 'report_year', 'plant_name_ferc1', 'row_type', 'fuel_type', 'construction_year']]
# Out:
#        utility_id_ferc1  report_year plant_name_ferc1 row_type fuel_type  \
# 15707               121         2015            hydro   header     hydro
# 15708               121         2015      apple river      NaN     hydro
# 15709               121         2015      cedar falls      NaN     hydro
# 15710               121         2015        menomonie      NaN     hydro
# 15711               121         2015        riverdale      NaN     hydro
# 15712               121         2015            trego      NaN     hydro
# 15713               121         2015        big falls      NaN     hydro
# 15714               121         2015          hayward      NaN     hydro
# 15715               121         2015        ladysmith      NaN     hydro
# 15716               121         2015      saxon falls      NaN     hydro
# 15717               121         2015   superior falls      NaN     hydro
# 15718               121         2015       thornapple      NaN     hydro
# 15719               121         2015      white river      NaN     hydro
#
#        construction_year
# 15707                NaN
# 15708             1901.0
# 15709             1910.0
# 15710             1958.0
# 15711             1905.0
# 15712             1926.0
# 15713             1922.0
# 15714             1910.0
# 15715             1941.0
# 15716             1912.0
# 15717             1917.0
# 15718             1927.0
# 15719             1907.0

# %%
# %%time
test4 = extract_ferc_license(test3)
# Out:
# Extracting FERC license from plant name
# CPU times: user 102 ms, sys: 5.67 ms, total: 108 ms
# Wall time: 114 ms

# %%
# TAKE A PEEK
util_groups = test4.groupby(['utility_id_ferc1', 'report_year'])
get_rand_group(util_groups)[['utility_id_ferc1', 'report_year', 'plant_name_ferc1', 'row_type', 'header_clean', 'fuel_type', 'ferc_license', 'ferc_license_manual']]
# Out:
#        utility_id_ferc1  report_year plant_name_ferc1 row_type header_clean  \
# 17073                88         2017      brown solar      NaN          NaN
#
#       fuel_type  ferc_license  ferc_license_manual
# 17073       NaN          <NA>                 <NA>

# %%
# %%time
test5 = associate_notes_with_values(test4)
# Out:
# Mapping notes and ferc license from footnotes
# CPU times: user 3.29 s, sys: 30.2 ms, total: 3.32 s
# Wall time: 3.44 s

# %%
# TAKE A PEEK
# weird: 
# 193	2001	
# not captured: 
# 61	2002	
util_groups = test5.groupby(['utility_id_ferc1', 'report_year'])
util_groups_with_notes = (
    util_groups.filter(lambda x: x['row_type'].str.contains('note').any())
    .groupby(['utility_id_ferc1', 'report_year']))
get_rand_group(util_groups_with_notes)[['utility_id_ferc1', 'report_year', 'plant_name_ferc1', 'row_type', 'ferc_license', 'ferc_license_manual', 'notes']]
# Out:
#       utility_id_ferc1  report_year          plant_name_ferc1 row_type  \
# 7121                61         2002                     hydro   header
# 7122                61         2002     middlesex station # 2      NaN
# 7123                61         2002    marshfield station # 6      NaN
# 7124                61         2002   vergennes station # 9 c      NaN
# 7125                61         2002  w, danville station # 15      NaN
# 7126                61         2002        gorge station # 18      NaN
# 7127                61         2002      essex station # 19 b      NaN
# 7128                61         2002  waterbury station # 22 a      NaN
# 7129                61         2002     deforge station # 1 d      NaN
# 7130                61         2002                    diesel   header
# 7131                61         2002     vergennes station # 9      NaN
# 7132                61         2002        essex station # 19      NaN
# 7134                61         2002      ( a ) license # 2090     note
# 7135                61         2002      ( b ) license # 2531     note
# 7136                61         2002      ( c ) license # 2674     note
# 7137                61         2002      ( d ) license # 2879     note
# 7138                61         2002                     total    total
#
#       ferc_license  ferc_license_manual notes
# 7121          <NA>                 <NA>  <NA>
# 7122          <NA>                 <NA>  <NA>
# 7123          <NA>                 <NA>  <NA>
# 7124          <NA>                 <NA>  <NA>
# 7125          <NA>                 <NA>  <NA>
# 7126          <NA>                 <NA>  <NA>
# 7127          <NA>                 <NA>  <NA>
# 7128          <NA>                 <NA>  <NA>
# 7129          <NA>                 <NA>  <NA>
# 7130          <NA>                 <NA>  <NA>
# 7131          <NA>                 <NA>  <NA>
# 7132          <NA>                 <NA>  <NA>
# 7134          2090                 <NA>  <NA>
# 7135          2531                 <NA>  <NA>
# 7136          2674                 <NA>  <NA>
# 7137          2879                 <NA>  <NA>
# 7138          <NA>                 <NA>  <NA>

# %%
print("PERCENT MANUAL LICENSES COVERED BY PROG:")
manual_lic = test5[test5['ferc_license_manual'].notna()]
prog_lic_of_manual = manual_lic[manual_lic['ferc_license'].notna()]
print(f'{round(len(prog_lic_of_manual) / len(manual_lic) * 100)}%')
display(manual_lic[manual_lic['ferc_license'].isna()].sample(5))

print("\nPERCENT MANUAL LICENSES SAME AS PROG:")
same_lic = prog_lic_of_manual[prog_lic_of_manual['ferc_license_manual']==prog_lic_of_manual['ferc_license']]
print(f'{round(len(prog_lic_of_manual) / len(same_lic) * 100)}%')
display(prog_lic_of_manual[prog_lic_of_manual['ferc_license_manual']!=prog_lic_of_manual['ferc_license']])

print('\nNUMBER OF MANUAL LICENSE VS PROG LICENSES:')
prog_lic = test5[test5['ferc_license'].notna()]
print(f'{len(manual_lic)} vs. {len(prog_lic)}')
# Out:
# PERCENT MANUAL LICENSES COVERED BY PROG:
# 90%
#        utility_id_ferc1  report_year          plant_name_ferc1 row_type  \
# 12808                25         2011          middlebury lower      NaN
# 9019                 61         2005  waterbury station # 22 a      NaN
# 10988                25         2008                 cavendish      NaN
# 15309               133         2014  potter valley ferc no.77      NaN
# 9018                 61         2005      essex station # 19 b      NaN
#
#        construction_year  capacity_mw  peak_demand_mw  net_generation_mwh  \
# 12808             1917.0         2.25             1.7             11225.0
# 9019              1953.0         5.52             0.0             11271.0
# 10988             1907.0         1.44             1.7              6666.0
# 15309             1910.0         9.46             9.2             11286.0
# 9018              1917.0         7.20             0.0             40934.0
#
#        total_cost_of_plant  capex_per_mw  opex_total  opex_fuel  \
# 12808            3019446.0     1341976.0    110910.0        NaN
# 9019             1363016.0      246923.0     47784.0        NaN
# 10988            1783040.0     1238222.0     57243.0        NaN
# 15309           35286843.0     3730110.0   3100876.0        NaN
# 9018             8395411.0      749590.0     94441.0        NaN
#
#        opex_maintenance fuel_type  fuel_cost_per_mmbtu     plant_name_clean  \
# 12808           41458.0     hydro                  NaN     middlebury lower
# 9019            59541.0     hydro                  NaN    waterbury station
# 10988          114344.0     hydro                  NaN            cavendish
# 15309          912103.0     hydro                  NaN        potter valley
# 9018           229487.0     hydro                  NaN  essex station hydro
#
#       plant_type  ferc_license_manual                       record_id  \
# 12808      hydro                 2737   f1_gnrt_plant_2011_12_25_0_13
# 9019       hydro                 2090    f1_gnrt_plant_2005_12_61_0_8
# 10988      hydro                 2489   f1_gnrt_plant_2008_12_25_0_10
# 15309      hydro                   77  f1_gnrt_plant_2014_12_133_0_17
# 9018       hydro                 2531    f1_gnrt_plant_2005_12_61_0_7
#
#        ferc_license notes
# 12808          <NA>  <NA>
# 9019           <NA>  <NA>
# 10988          <NA>  <NA>
# 15309          <NA>   NaN
# 9018           <NA>  <NA>
# PERCENT MANUAL LICENSES SAME AS PROG:
# 100%
#        utility_id_ferc1  report_year                 plant_name_ferc1  \
# 9776                151         2006  rochester station #160 (note 3)
# 10472               151         2007  rochester station #160 (note 3)
#
#       row_type  construction_year  capacity_mw  peak_demand_mw  \
# 9776       NaN             1916.0         0.34             0.0
# 10472      NaN             1916.0         0.34             0.0
#
#        net_generation_mwh  total_cost_of_plant  capex_per_mw  opex_total  \
# 9776                  NaN             254356.0      748106.0         NaN
# 10472                 NaN                  NaN           NaN         NaN
#
#        opex_fuel  opex_maintenance fuel_type  fuel_cost_per_mmbtu  \
# 9776         NaN               NaN       NaN                  NaN
# 10472        NaN               NaN       NaN                  NaN
#
#              plant_name_clean plant_type  ferc_license_manual  \
# 9776   rochester station #160      hydro                 2596
# 10472  rochester station #160      hydro                 2596
#
#                            record_id  ferc_license notes
# 9776   f1_gnrt_plant_2006_12_151_0_5           160   NaN
# 10472  f1_gnrt_plant_2007_12_151_0_5           160   NaN
# NUMBER OF MANUAL LICENSE VS PROG LICENSES:
# 1842 vs. 4754

# %% [markdown]
# ## 1) Remove Bad Data

# %% [markdown]
# First lets remove some **obviously bad rows**. That includes:
# * Utilities that have reported NA values for all `nan_cols` for ALL PLANTS in a given year
# * Rows just comprised or three or more dashes: `---`
# * Rows with obvious NA plant names: `'', 'none', 'na', 'n/a', 'not applicable'`

# %%
remove_bad_rows(small_plants_out, show_removed=True)
# Out:
# Removing rows where an entire utility has reported NA in key columns
# Removing rows with three or more dashes for plant name
# Removing rows with NA for plant name
#
#  REMOVED NAN VALUES:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 0 to 20243
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   construction_year    0 non-null      float64
#  1   net_generation_mwh   0 non-null      float64
#  2   total_cost_of_plant  0 non-null      float64
#  3   capex_per_mw         0 non-null      float64
#  4   opex_total           0 non-null      float64
#  5   opex_fuel            0 non-null      float64
#  6   opex_maintenance     0 non-null      float64
#  7   fuel_cost_per_mmbtu  0 non-null      float64
# dtypes: float64(8)
# memory usage: 16.5 KB
# None
#
#
#  REMOVED DASH NAMES:
#
#  plant_name_ferc1
# ------------------                     25
# -------------------                    16
# -----                                   3
# -----------                             3
# --------------------                    2
# ------------                            1
# -------------                           1
# ----------------                        1
# ------------------------                1
# -------------------------               1
# ---------------------------------       1
# -----------------------------------     1
# dtype: int64
#
#
#  REMOVED NA NAMES:
#
#  plant_name_ferc1
#                     186
# none                 81
# not applicable       23
# na                    8
# n/a                   7
# dtype: int64
#        utility_id_ferc1  report_year   plant_name_ferc1  construction_year  \
# 1                   115         1994              hydro                NaN
# 2                   115         1994   seneca falls (a)             1917.0
# 3                   115         1994  rainbow falls (c)             1926.0
# 4                   115         1994      cadyville (b)             1922.0
# 5                   115         1994       waterloo (a)             1915.0
# ...                 ...          ...                ...                ...
# 20432               193         2020    pine - 2486 (4)             1922.0
# 20433               193         2020              solar                NaN
# 20434               193         2020          solar now             2019.0
# 20435               193         2020              other                NaN
# 20436               193         2020  valley diesel (1)             1968.0
#
#        capacity_mw  peak_demand_mw  net_generation_mwh  total_cost_of_plant  \
# 1             0.00             0.0                 NaN                  NaN
# 2             8.00             6.0          17695840.0            2342818.0
# 3             2.64             2.8          17108000.0            2666266.0
# 4             5.53             4.9          26108906.0           15002778.0
# 5             1.92             1.3           5027300.0            1103365.0
# ...            ...             ...                 ...                  ...
# 20432         3.20             4.2          23517900.0            7081132.0
# 20433         0.00             0.0                 NaN                  NaN
# 20434        11.00             6.4           8325000.0           17649831.0
# 20435         0.00             0.0                 NaN                  NaN
# 20436         3.00             3.0                 NaN                  NaN
#
#        capex_per_mw  opex_total  opex_fuel  opex_maintenance fuel_type  \
# 1               NaN         NaN        NaN               NaN
# 2             293.0     45573.0        NaN           33766.0
# 3            1010.0     57909.0        NaN           40082.0
# 4            2713.0     55345.0        NaN          140692.0
# 5             575.0     71829.0        NaN           13091.0
# ...             ...         ...        ...               ...       ...
# 20432     2212854.0     78338.0        NaN          163434.0
# 20433           NaN         NaN        NaN               NaN
# 20434     1604530.0    236831.0        NaN               NaN
# 20435           NaN         NaN        NaN               NaN
# 20436           NaN         NaN     4398.0               NaN       oil
#
#        fuel_cost_per_mmbtu   plant_name_clean plant_type  ferc_license_id  \
# 1                      NaN              hydro        NaN              NaN
# 2                      NaN   seneca falls (a)        NaN              NaN
# 3                      NaN  rainbow falls (c)        NaN              NaN
# 4                      NaN      cadyville (b)        NaN              NaN
# 5                      NaN       waterloo (a)        NaN              NaN
# ...                    ...                ...        ...              ...
# 20432                  NaN    pine - 2486 (4)        NaN              NaN
# 20433                  NaN              solar        NaN              NaN
# 20434                  NaN          solar now        NaN              NaN
# 20435                  NaN              other        NaN              NaN
# 20436                  NaN  valley diesel (1)        NaN              NaN
#
#                             record_id
# 1       f1_gnrt_plant_1994_12_115_0_1
# 2       f1_gnrt_plant_1994_12_115_0_2
# 3       f1_gnrt_plant_1994_12_115_0_3
# 4       f1_gnrt_plant_1994_12_115_0_4
# 5       f1_gnrt_plant_1994_12_115_0_5
# ...                               ...
# 20432  f1_gnrt_plant_2020_12_193_0_14
# 20433  f1_gnrt_plant_2020_12_193_0_16
# 20434  f1_gnrt_plant_2020_12_193_0_17
# 20435  f1_gnrt_plant_2020_12_193_0_19
# 20436  f1_gnrt_plant_2020_12_193_0_20
#
# [19842 rows x 18 columns]

# %%
# Remove utilities with all NAN rows because these won't contain anything meaningful
# spc = small_plants_clean
spc = (
    small_plants_out
    .groupby('utility_id_ferc1').filter(lambda x: ~x[nan_cols].isna().all().all())
)
# Show what was removed
print('REMOVED NAN VALUES: \n')
pd.concat([small_plants_out,spc]).drop_duplicates(keep=False)[nan_cols].info()
# Out:
# REMOVED NAN VALUES:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 0 to 20243
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   construction_year    0 non-null      float64
#  1   net_generation_mwh   0 non-null      float64
#  2   total_cost_of_plant  0 non-null      float64
#  3   capex_per_mw         0 non-null      float64
#  4   opex_total           0 non-null      float64
#  5   opex_fuel            0 non-null      float64
#  6   opex_maintenance     0 non-null      float64
#  7   fuel_cost_per_mmbtu  0 non-null      float64
# dtypes: float64(8)
# memory usage: 16.5 KB

# %%
bb = spc[spc['plant_name_ferc1'].str.contains('---')]
spc.drop(bb.index)
# Out:
#        utility_id_ferc1  report_year   plant_name_ferc1  construction_year  \
# 1                   115         1994              hydro                NaN
# 2                   115         1994   seneca falls (a)             1917.0
# 3                   115         1994  rainbow falls (c)             1926.0
# 4                   115         1994      cadyville (b)             1922.0
# 5                   115         1994       waterloo (a)             1915.0
# ...                 ...          ...                ...                ...
# 20432               193         2020    pine - 2486 (4)             1922.0
# 20433               193         2020              solar                NaN
# 20434               193         2020          solar now             2019.0
# 20435               193         2020              other                NaN
# 20436               193         2020  valley diesel (1)             1968.0
#
#        capacity_mw  peak_demand_mw  net_generation_mwh  total_cost_of_plant  \
# 1             0.00             0.0                 NaN                  NaN
# 2             8.00             6.0          17695840.0            2342818.0
# 3             2.64             2.8          17108000.0            2666266.0
# 4             5.53             4.9          26108906.0           15002778.0
# 5             1.92             1.3           5027300.0            1103365.0
# ...            ...             ...                 ...                  ...
# 20432         3.20             4.2          23517900.0            7081132.0
# 20433         0.00             0.0                 NaN                  NaN
# 20434        11.00             6.4           8325000.0           17649831.0
# 20435         0.00             0.0                 NaN                  NaN
# 20436         3.00             3.0                 NaN                  NaN
#
#        capex_per_mw  opex_total  opex_fuel  opex_maintenance fuel_type  \
# 1               NaN         NaN        NaN               NaN
# 2             293.0     45573.0        NaN           33766.0
# 3            1010.0     57909.0        NaN           40082.0
# 4            2713.0     55345.0        NaN          140692.0
# 5             575.0     71829.0        NaN           13091.0
# ...             ...         ...        ...               ...       ...
# 20432     2212854.0     78338.0        NaN          163434.0
# 20433           NaN         NaN        NaN               NaN
# 20434     1604530.0    236831.0        NaN               NaN
# 20435           NaN         NaN        NaN               NaN
# 20436           NaN         NaN     4398.0               NaN       oil
#
#        fuel_cost_per_mmbtu   plant_name_clean plant_type  ferc_license_id  \
# 1                      NaN              hydro        NaN              NaN
# 2                      NaN   seneca falls (a)        NaN              NaN
# 3                      NaN  rainbow falls (c)        NaN              NaN
# 4                      NaN      cadyville (b)        NaN              NaN
# 5                      NaN       waterloo (a)        NaN              NaN
# ...                    ...                ...        ...              ...
# 20432                  NaN    pine - 2486 (4)        NaN              NaN
# 20433                  NaN              solar        NaN              NaN
# 20434                  NaN          solar now        NaN              NaN
# 20435                  NaN              other        NaN              NaN
# 20436                  NaN  valley diesel (1)        NaN              NaN
#
#                             record_id
# 1       f1_gnrt_plant_1994_12_115_0_1
# 2       f1_gnrt_plant_1994_12_115_0_2
# 3       f1_gnrt_plant_1994_12_115_0_3
# 4       f1_gnrt_plant_1994_12_115_0_4
# 5       f1_gnrt_plant_1994_12_115_0_5
# ...                               ...
# 20432  f1_gnrt_plant_2020_12_193_0_14
# 20433  f1_gnrt_plant_2020_12_193_0_16
# 20434  f1_gnrt_plant_2020_12_193_0_17
# 20435  f1_gnrt_plant_2020_12_193_0_19
# 20436  f1_gnrt_plant_2020_12_193_0_20
#
# [20147 rows x 18 columns]

# %%
test = spc[~spc['plant_name_ferc1'].str.contains('---')]
test.loc[:, 'plant_name_ferc1'] = 'hi'
# Out:
# /Users/aesharpe/miniconda3/envs/pudl-dev/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# Remove rows with --- or '' for names
aa = spc[~spc['plant_name_ferc1'].str.contains('---')]
spc1 = aa[~aa['plant_name_ferc1'].isin(['', 'none', 'na', 'n/a', 'not applicable'])].reset_index(drop=True)

# Show what was removed
print('REMOVED NAN NAMES:\n', pd.concat([spc, spc1]).drop_duplicates(keep=False).plant_name_ferc1.value_counts(), '\n')
# Out:
# REMOVED NAN NAMES:
#                                         186
# none                                    81
# ------------------                      25
# not applicable                          23
# -------------------                     16
# na                                       8
# n/a                                      7
# -----                                    3
# -----------                              3
# --------------------                     2
# ------------------------                 1
# -------------------------                1
# ------------                             1
# ----------------                         1
# -------------                            1
# ---------------------------------        1
# -----------------------------------      1
# Name: plant_name_ferc1, dtype: int64

# %%
# Show total rows removed
print(f'TOTAL ROWS REMOVED: {len(small_plants_out) - len(spc1)} rows. Current row total: {len(spc1)}')
# Out:
# TOTAL ROWS REMOVED: 595 rows. Current row total: 19842

# %% [markdown]
# ## 2/3) Label Row Types: `header, note, total`

# %% [markdown]
# Instead of removing rows, now we're going to flag them as:
# * `header`: critical rows are NA and contains predefined header keywords
# * `total`: critical rows are not NA and contains the word total
# * `note`: critical rows are NA and there are multiple in a row for a given utility report year
#
# We want to flag rather than get rid of these rows, because they contain useful information. For example, headers are often fuel types and notes sometimes contain ferc license ids.
#
# Example of a note containing a FERC license:
# * `spc4[spc4['row_type']=='clump']`
# * `spc4[(spc4['utility_id_ferc1'] == 115) & (spc4['report_year']==1994)]`

# %%
# Add some new helper columns
spc2 = spc1.copy()
spc2.insert(3, 'possible_header', False)
spc2.insert(3, 'row_type', np.nan)

# %% [markdown]
# Notes are similar to the headers in that they don't contain any useful information in certain columns. At first, we'll lump them all together under `possible_header == True`, and then we'll tease out the ones that are note clumps vs actual headers.

# %%
# Label possible header rows (based on the nan cols specified above)
spc2.loc[spc2.filter(nan_cols).isna().all(1), 'possible_header'] = True

# Label good header rows (based on whether they contain key strings)
possible_header = spc2['possible_header']
good_header = spc2['plant_name_ferc1'].str.contains('|'.join(header_strings))
not_bad = ~spc2['plant_name_ferc1'].str.contains('|'.join(exclude))

spc2.loc[possible_header & good_header & not_bad, 'row_type'] = 'header'
spc2.loc[spc2['plant_name_ferc1'].isin(exceptions), 'row_type'] = 'header'

# Label total rows
spc2.loc[spc2['plant_name_ferc1'].str.contains('total'), 'row_type'] = 'total'

# What you'll see when you look at the values listed as headers and totals is
# that many of them are actually notes. These next kernals will help identify
# and label those clumps accordingly.
spc2[spc2['row_type']=='total'].plant_name_ferc1.value_counts()
spc2[spc2['row_type']=='header'].plant_name_ferc1.value_counts()
# Out:
# internal combustion                           297
# hydro                                         237
# internal combustion:                          185
# hydro:                                        171
# hydro plants:                                 111
#                                              ...
# with e. hampton gas turbine on page 403.2.      1
# other-leased:                                   1
# other-steam expenses:                           1
# gas turbines:                                   1
# wind turbine plants:                            1
# Name: plant_name_ferc1, Length: 143, dtype: int64

# %%
def create_groups(group, group_col):
    """Count groups of headers in a given utiltiy group.

    This function takes a utility group and regroups it by of rows where 
    possible_header = True (i.e.: all values in the specified nan_cols are NA)
    vs. False. Rows where possible_header = True can be bad data, headers, or notes. 
    The result is a DataFrame that contains one row per clump of similar adjecent
    possible_header values with columns val_col depicting the number of rows per
    possible_header clump.

    Ex: If you pass in a df with the possible_header values: True, False False, True, True,
    the header_groups output df will look like this: {'header':[True, False, True], 'val_col:
    [1, 2, 2]}.

    Args:
        group (pandas.DataFrameGroupBy): A groupby object that you'd like to condense by group_col.
        group_col (str): The name of the column you'd like to make sub groups from.

    Returns:
        pandas.DataFrame: A condensed version of that dataframe input grouped by
            breaks in fuel type over the years.

    """
    # Make groups based on consecutive sections where the group_col is alike.
    header_groups = group.groupby((group[f'{group_col}'].shift() !=
                        group[f'{group_col}']).cumsum(), as_index=False)
    
    # Identify the first (and only) group_col value for each group and count how many
    # rows are in each group.
    header_groups_df = header_groups.agg(header=(f'{group_col}', 'first'), val_count=(f'{group_col}', 'count'))

    return header_groups, header_groups_df

# %%
def get_header_clumps_all(df):
    """
    Remove clumps of consecutive rows flagged as possible headers.
    
    FERC has lots of note rows that are not headers but are also not useful for analysis.
    This function looks for rows flagged as possible headers (based on NAN values) and checks to
    see if there are multiple in a row. A header row is (usually) defined as a row with NAN values
    followed by rows without NAN values, so when there are more than one clumped together they are
    likely either notes or not helpful.
    
    Sometimes note clumps will end with a meaningful header. This function also checks for this and will
    unclump any headers at the bottom of clumps. There is one exception to this case which is a header that 
    is followed by a plant that had no values reported... Unfortunately I haven't built a work around,
    but hopefully there aren't very many of these. Currently, that header and plant will be categorized
    as clumps and removed.
    
    """
    util_groups = df.groupby(['utility_id_ferc1', 'report_year'])
    
    def get_header_clumps(util_year_group):
        
        # Create mini groups that count pockets of true and false for each utility and year
        # create_groups() is a function from the fill_ferc1_fuel_gaps module-- basically what
        # it does is create a df where each row represents a clump of adjecent, equal values for
        # a given column. Ex: a column of True, True, True, False, True, False, False, will
        # appear as True, False, True, False with value counts for each
        group, header_count = create_groups(util_year_group, 'possible_header')
        
        # These are used later to enable exceptions
        max_idx_val = header_count.index.max()
        max_df_val = util_year_group.index.max()
        
        # Create a list of the index values that comprise each of the header clumps
        # It's only considered a clump if it is greater than 1.
        idx_list = list(header_count[
            (header_count['header']) & (header_count['val_count'] > 1)].index)
        
        # If the last row is not a clump (i.e. there is just one value) but it is a header (i.e. has nan values)
        # then also include it in the index values to be flagged because it might be a one-liner note. And
        # because it is at the bottom there is no chance it can actually be a useful header because there are
        # no value rows below it.
        last_row = header_count.tail(1)
        if (last_row['header'].item()) & (last_row['val_count'].item()==1):
            idx_list = idx_list + list(last_row.index)
        # If there are any clumped/end headers:
        if idx_list:
            for idx in idx_list:
                # Check to see if last clump bit is not a header... sometimes you might find a clump of
                # notes FOLLOWED by a useful header. This next bit will check the last row in each of
                # the identified clumps and "unclump" it if it looks like a valid header. We only need
                # to check clumps that fall in the middle because, as previously mentioned, the last row
                # cannot contain any meaningful header information because there are no values below it.
                idx_range = group.groups[idx+1]
                is_middle_clump = group.groups[idx+1].max() < max_df_val
                is_good_header = util_year_group.loc[
                    util_year_group.index.isin(group.groups[idx+1])].tail(1)['plant_name_ferc1'].str.contains('|'.join(header_strings)).all()  #.isin(header_strings).all()
                # If the clump is in the middle and the last row looks like a header, then drop it from the idx range
                if is_middle_clump & is_good_header:
                    idx_range = [x for x in idx_range if x != idx_range.max()]
                # Label the clump as a clump
                util_year_group.loc[
                    util_year_group.index.isin(idx_range), 'row_type'] = 'note'
        return util_year_group
    
    return util_groups.apply(lambda x: get_header_clumps(x))

# %%
spc3 = get_header_clumps_all(spc2)

# %%
# Take a look at the rows that were labeled as notes. Looks like notes to me!
# We label rather than remove them because it's possible the might contain useful information
# such as ferc license number.

print('CLUMP PLANT NAMES: \n\n', spc3[spc3['row_type']=='note'].plant_name_ferc1.unique())
print('NON CLUMP OR HEADER PLANT NAMES: \n\n', spc3[~spc3['row_type'].isin(['note', 'header'])].plant_name_ferc1.unique().tolist())
# Out:
# CLUMP PLANT NAMES:
#
#  ['(a) project #2438' '(b) project #2738' '(c) project #2835'
#  '(d) project #2852' 'license project: 2069'
#  '(1) applicable to atlantic city' 'electrics share of jointly-'
#  'owned facility.' 'note: generation provided in column (e)'
#  'is in kilowatt-hours.' 'a-internal combustion unit'
#  'b-combustion turbine unit' 'note: amounts per above are not'
#  'included on pages 402, 403, and 403a' '(plant not yet in service)'
#  'item 2. the generating unit is leased. the'
#  'cost of plant represents the annual rental cost.'
#  'ferc licensed project no. 2380' 'generator - hutsonville'
#  '(1) operated on an emergency basis only.' 'a project # 2090'
#  'b project # 2531' 'c project # 2674' 'd project # 2879'
#  'cummins diesel #3' 'cummins diesel #4' 'cummins diesel #5'
#  'internal combustion:' "yellowstone nat'l park:"
#  '*(1) ferc licensed project no. 2582'
#  '*(2) ferc licensed project no. 2584'
#  '*(3) ferc licensed project no. 2596' '*(4) water for power'
#  'other production' 'santa catalina island'
#  'note: dinner lake was placed on long-term'
#  'reserve standby march 1, 1994.' "*inc's silver lk"
#  '(a) ferc licensed project #2323'
#  'columns (h) and (j) are not maintained by'
#  'plant since they are in the same vicinity,'
#  "(martha's vineyard) therefore totals are" 'provided.' 'note:'
#  'south st. diesels have not generated'
#  'since 9/92, the units were deactivated in'
#  'mid 1993 and were rented to nantucket' 'electric in 1994'
#  'hydroelectric' 'generating plants' '(emergency standby units)'
#  '(continued on page 410-1)' 'wind turbine:' 'suisun wind power plant (r)'
#  'refineries:' '(r) retired in 1989. these plants are included'
#  'on this report as o&m costs are still being' 'charged'
#  'nl no federal license required' 'please see attach' 'notes'
#  'see notes on page 411-2 thru 411-5.' '(ferc licensed'
#  'project no. 2446)' 'note: columns (d) and (l) are not applicable.'
#  'n o n e' 'steam-common production' 'plant' '1' 'wind turbine'
#  '** license surrendered august 1982' 'na = not available'
#  '* license surrendered december 1981.' '(1) license # 2585'
#  '(2) license # 2607' '(3) license # 2406' '(4) locense # 2465'
#  '(5) license # 2332' 'note: columns (d) and (l) are not applicable'
#  '* license surrendered december 1981' '(a) project # 2438'
#  '(b) project # 2738' '(c) project # 2835' '(d) project # 2852'
#  '(1) directly connected to plant auxiliary load.'
#  '(2) a used 1929 model unit was purchased and'
#  "rebuilt. rating recalculated from 21' head" "to 16' head."
#  '(3) cost of plant is not separated.'
#  '(4) f.e.r.c. licensed project number.'
#  '(5) way plant is operated in conjunction with' 'michigamme reservior.'
#  '(6) excludes portion allocated to other water'
#  'users benefitting from this project.' '(put into'
#  'item 2. the generating unit leased expired. the'
#  'cost of plant represents rental costs through' 'may 1995.'
#  'operatied on emergency' 'basis only.' 'internal combustion'
#  'peaking units' '(1) salmon units are classified as standby.'
#  'gas turbine' '4th street (leased from the city'
#  'note: south st diesels have not generated since'
#  '9/92. the units were deactivated in' 'mid 1993 and were rented to'
#  'nantucket electric in 1994.'
#  'note: operation and maintenance expenses are'
#  'immaterial in nature and are no longer'
#  'available for specific diesel units.' '(1) operated under license #2576'
#  '(2) operated under license #2662' '(3) operated under license #2597'
#  'a - hydro license project no. 2315.' 'steam'
#  '(1) dinner lake was placed on long-term' '*includes silver' 'lake'
#  'total' 'deisel' '(a) license #2090' '(b) license #2531'
#  '(c) license #2674' '(d) license #2879' '(1) ferc project # 6221'
#  'confidential' "(a) amounts shown represent respondent's 12.34%"
#  'share of jointly-owned plant.'
#  "(b) amounts shown represent respondent's 11.39%" 'charged.'
#  '(a) licensed project number 2354.' '(b) leased from james white estate.'
#  '(c) licensed project number 1218.'
#  '(d) approximately 1928. record of owners inadeq.'
#  '(e) licensed project number 2341.' '(f) licensed project number 2350.'
#  '(put into "cold" reserve 9-1-95)'
#  '(1) the dixon hydro electric generating facility'
#  'was sold on march 20, 1996. see ferc page'
#  '108, number 3 and pages 206-207, line no.86'
#  'and note in column (e) for details. on'
#  'february 22, 1996, the ferc issued an order'
#  'approving transfer of, and amending,'
#  'license of this facility, designated as'
#  'project no. 2446-013-illinois.' 'ramada inn'
#  'alpine storage lake bonaparte' '(project no. 4486) (leased)'
#  '4th street (leased from the city of' 'production expenses related to'
#  '"replacement power" due to the' 'anticipated capacity shortage of'
#  'millstone units not being available' 'to the system'
#  'yellowstone national park:' '0'
#  'note: south st. diesels have not generated'
#  'since 9/92. the units were deactivated in'
#  'mid-1993 and were rented to nantucket' 'electric in 1994.'
#  'expenses also' 'include dams and' 'associated' 'structures as well'
#  'as the generation' 'plant themselves.'
#  '(2) a used 1929 model unit was purchassed and' 'michigamme reservoir.'
#  'plant since they are in the same vicinty,'
#  '4th street ( leased from the city' 'nl = no federal license required'
#  '(1) ferc licensed project #2582' '(2) ferc licensed project #2584'
#  '(3) ferc licensed project #2596' 'a-hydro license project no. 2315'
#  'dinner lake gas' '* license surrendered august 1982'
#  '** license surrendered december 1981' '(1) ferc project #6221'
#  'research and development costs (hydros)' 'leased plants'
#  'albany steam hydro expense' 'other/internal combustion'
#  'albany-turbines' "rebuilt. rating recaculated from 21' head to"
#  "16' head." '(6) plant sold in september 1997.' 'combustion turbine'
#  '(a) plant cost at 12/31/98 included the' 'remaining value of two leased'
#  'generating units capitalized in' 'conformity with fasb no. 71 and'
#  'ferc order no. 390.' '(b) included deferred fuel of $1,268'
#  '(c) included deferred fuel of $26,532' 'hydro:' 'elmore'
#  'column (f) the plants were sold 12/30/98'
#  'with east hampton gas turbine page 403-b'
#  'information for columns (h)-(l) are combined' 'fuel storage tanks'
#  'note: rockton plant was sold during the year;' 'see note 3, page 109.'
#  'information for columns (h) - (l) is combined'
#  'for columns (i) and (l) fuel costs incurred'
#  'include only fuel handling costs.'
#  'note: the blackhawk and janesville plants were'
#  'sold during the year; see note 3, page 109' '( a ) license # 2090'
#  '( b ) license # 2531' '( c ) license # 2674' '( d ) license # 2879'
#  '(hydroelectric facility)' '4th street leased from the city'
#  'project #2315' '(a) project # 2738' '(b) project # 2835'
#  '(c) project # 2852' 'allens falls (project no. 10462)(note 1)'
#  'baldwinsville (project no. 5217)(note 1)'
#  'belfort (project no. 2645)(note 1)'
#  'black river (project no. 2569)(note 1)'
#  'chasm (project no. 7320)(note 1)' 'eagle (project no. 2645)(note 1)'
#  'east norfolk (project no. 2330)(note 1)'
#  'eeel weir (project no. 2713)(note 1)'
#  'effley (project no. 2645)(note 1)' 'elmer (project no. 2645)(note 1)'
#  'ephratah (project no. 2706)(note 1)'
#  'flat rock (project no. 2713)(note 1)'
#  'franklin falls (project no. 4472)(note 2)'
#  'fulton (project no. 2474)(note 3)' 'glenwood (project no. 2667)(note 3)'
#  'green island (project no. 0013)(note 1)'
#  'hannawa (project no. 2320)(note 1)'
#  'herrings (project no. 2569)(note 1)'
#  'heuvelton (project no. 2713)(note 1)'
#  'high falls (project no. 2645)(note 1)'
#  'higley (project no. 7320)(note 1)'
#  'hogansburg (project no. 7518)(note 1)'
#  'hydraulic race (project no. 2424)(note 1)'
#  'inghams (project no. 2648)(note 1)'
#  'johnsonville (project no. 2616)(note 1)'
#  'kamargo (project no. 2569)(note 1)'
#  'lighthouse hill (project no. 11408)(note 1)'
#  'macomb (project no. 7321)(note 1)' 'minetto (project no. 2474)(note 1)'
#  'moshier (project no. 2645)(note 1)' 'norfolk (project no. 2330)(note 1)'
#  'norwood (project no. 2330)(note 1)'
#  'oak orchard (project no. 3452)(note 3)'
#  'oswegatchie (project no. 2713)(note 1)'
#  'oswego falls - east (project no. 5984)(note 1)'
#  'oswego falls - west (project no. 5984)(note 1)'
#  'parishville (project no. 10461)(note 1)'
#  'piercefield (project no. 7387)(note 1)'
#  'raymondville (project no. 2330)(note 1)'
#  'schuylerville (project no. 8606)(note 1)'
#  'sewalls island (project no. 2569)(note 1)'
#  'south edwards (project no. 2713)(note 1)'
#  'stuyvesant falls (project no. 2696)(note 1)'
#  'sugar island (project no. 2320)(note 1)'
#  'talcville hydro station(project no. 4402)(note 1'
#  'taylorville (project no. 2645)(note 1)'
#  'varick (project no. 2474)(note 1)'
#  'waterport (project no. 2667)(note 3)'
#  'yaleville (project no. 9222)(note 1)'
#  'feeder dam (project no. 2641)(notes 3&5)'
#  'glen park (project no. 4796)(note 6)'
#  'beebee island (project no. 2538)(note 1)' 'reservoirs'
#  'carry falls reservoir (project no. 2060)(note 1)'
#  'pleasant lake reservoir (note 1)' 'irving pond reservoir (note 1)'
#  '(6) milwaukee county is a steam utility plant'
#  'and the operation costs (column h) reflect'
#  'an allocation of electric related expenses' 'hydro' 'wind'
#  'which includes fuel.' 'note: operation and maintenance expenses'
#  'are immaterial in nature and are no longer'
#  'conemaugh - internal combustion' 'sold in 1999 - see page 402'
#  'shawville - internal combustion' 'note: the mobile generator previously'
#  'reported was sold in april 1999' 'in conjunction with the sale'
#  'of the south bay power plant.'
#  '(amounts are for the total of all 28 units)'
#  'franklin falls ( project no. 4472 )' 'fulton ( project no. 2474 )'
#  'glenwood ( project no. 2667 )' 'oak orchard ( project no. 3452 )'
#  'waterport ( project no. 2667 )' '* albany diesel has been sold to pseg'
#  'power new york as of may 12, 2000.'
#  '(1) information for columns (h) - (j) is'
#  'combined with e. hampton gas turbine on' 'pg. 403.2'
#  "rebuilt. rating recalculated from 21' head t"
#  '(7) oconto falls sold in 2000.' 'holyoke masonry dam'
#  'holyoke no. 1 overflow' 'holyoke no. 2 overflow'
#  'holyoke no. 3 overflow' 'holyoke no. 4 overflow'
#  'holyoke no. 5 overflow' 'holyoke 1st level canal'
#  'holyoke 2rd level canal' 'holyoke 3rd level canal' 'south hadley canal'
#  'other:' '(1) information for columns (h) - (i) is'
#  'note: status of algodones is' 'non-operational for 2001'
#  'internal combustion :' '*includes silver lake' 'hydro license'
#  'international combustion'
#  '(1)-information for columns (h)-(l) is combined'
#  'with e. hampton gas turbine on page 403.2.'
#  '* fuel oil inventory adjustment'
#  'cost of plant for diesel plants is included in' 'the hydro plant above'
#  '* plants were inactivated and any remaining'
#  'net book value of non-depreciable land'
#  'investment was transferred to account' '121, nonutility property.'
#  '*changing the installed capacity for salmon'
#  'creek for 1984 from 9.5 for previous years'
#  'to the correct number. the upper salmon power'
#  'size of the penstock limits the maximum power'
#  'out of salmon creek to 5 mw.'
#  'plant was decommissioned in 1997 & the capacity'
#  'was never subtracted from the project. the'
#  'installed capacity is 8.5 mw' 'actual project capacity is 5.0 mw.'
#  'not applicable.' '* includes silver lake'
#  '* inactivated plants, no longer in service -'
#  'all remaining net book value of non-depreciable'
#  'property was transferred to account 121,'
#  'nonutility property and account 122,'
#  'accumulated provision for depreciation' 'and amortization.'
#  '(1) directly connect to plant auxiliary load'
#  '(4) f.e.r.c licensed project number.' 'michigamme reservior'
#  '(7) sturgeon taken out of service dec, 2004'
#  '** license surrendered december 1981.'
#  'available for specific diesel unit.' 'other-steam expenses:'
#  'the size of the penstock limits the maximum'
#  'power out of salmon creek to 5 mw.' 'project capacity is 5 mw'
#  '(4) excludes expenses not directly charged' 'to the station.'
#  'steam heating plant' '* license surrendered august 1982.'
#  '15 units @ 1 mw each)' '(amounts are for the total of all 122 units)'
#  '35 units @ 1 mw each)' '(amounts are for the total of all 135 units)'
#  'other gen maint. supervision & engineering'
#  '(amounts are for the total of all 66 units)' '(67 units @ 1.5 mw each)'
#  'power out of salmon creek to 5 mw. installed'
#  'capacity is 8.5 mw. project capacity is 5 mw'
#  'other general ops supervision & engineering' 'project # 2315'
#  '(amounts are for the total of all 131 units)' 'pumping plant:'
#  '(1) directly connected to plant auxiliary load'
#  "rebuilt. rating calculated from 21' head to"
#  '(3) cost of plant is not separated' '(4) ferc licensed project number'
#  'michigamme rerservoir' '(7) sturgeon taken out of service dec. 2004'
#  '* 64% jan - mar; 72% apr - dec' 'diesel generators'
#  '(amounts are for the total of all 145 units)'
#  '(amounts are for the total of all 102 units)' 'hydro-neal shoals'
#  'none.' '(1) directly connected to plant auxillary load'
#  'michigamme reservoir' '(7) sturgeon tanken out of service dec. 2004'
#  'notes:' '(a) ferc licensed project # 2582'
#  '(b) ferc licensed project # 2584' '13 units @ 2.3 mw each)'
#  '(amounts are for the total of all 184 units)'
#  '(amounts are for the total of all 52 units)'
#  '(amounts are for the total of all 45 units)' 'wind turbine plants'
#  'gas plant' 'st. albans #202' '(a) project #2738' '(b) project #2835'
#  '(c) project #2852' 'black start diesel units'
#  '(7) montfort wind farm was purchased dec. 2012.'
#  '(amounts are for the total of all 64 units)' 'solar array'
#  '(b) licensed project number 1218.'
#  '(c) approximately 1928. record of owners inadeq.'
#  '(d) licensed project number 2341.' '(e) licensed project number 2350.'
#  'montauk diesel' 'fuel cell:' 'wind:' 'solar:'
#  '(amounts are for the total of all 214 units)'
#  '(amounts are for the total of all 107 units)' '4 units @ 2.346 mw each)'
#  '(amounts are for the total of all 44 units)'
#  '* generation is recorded as company use' 'other production - solar'
#  '120 units @ 2.30 mw each)' '(amounts are for the total of 134 units)'
#  '91 units @ 2.415 mw each)' '(amounts are for the total of 104 units)'
#  'other' '(amounts are for the total of all 50 units)'
#  '(amounts are for the total of all 76 units)'
#  '(amounts are for the total of all 100 units)'
#  '(amounts are for the total of all 193 units)'
#  '(amounts are for the total of all 87 units)'
#  '(amounts are for the total of all 51 units)'
#  '(amounts are for the total of all 60 units)'
#  '(amounts are for the total of all 82 units)'
#  '(amounts are for the total of all 85 units)' 'hydro plants'
#  '10 units @ 1.62 mw each & 35 units @ 1 mw each)'
#  'and 50 units @ 1.62 mw each)'
#  '34 units @ 1.62 mw & 13 units @ 2.3 mw each)' '5 units @ 2.415 mw each)'
#  '(amounts are for the total of all 134 units)'
#  '(amounts are for the total of all 104 units)'
#  '(amounts are for the total of all 84 units)' '(170 units @ 2.0 mw each)'
#  '(amounts are for the total of all 35 units)' '(100 units @ 2.0 mw each)'
#  '(amounts are for the total of all 170 units)'
#  '(amounts are for the total of all 125 units)'
#  '80 units @ 1.62 mw & 13 units @ 2.3 mw each)' '42 units @ 1.62 mw each)'
#  '76 units @ 1.62 mw each)' '73 units @ 2.52 mw each)'
#  '(amounts are for the total of all 315 units)' '5 units @4.2 mw each)'
#  '64 units @ 2.2 mw each)' '(amounts are for the total of all 244 units)'
#  '(amounts are for the total of all 124 units)'
#  '(amounts are for the total of all 215 units)'
#  '40 units @ 2.15 mw each & 9 units @ 2.2 mw each)'
#  'units @ 2.15 mw each & 156 units @ 2.2 mw each)'
#  '(amounts are for the total of all 142 units)'
#  'palo alto ii wind farm (45 units @ 2.0 mw each)'
#  '11 units @ 2.2 mw each & 1 unit @ 4.2 mw each &'
#  '32 units @ 4.3 mw each & 25 units @2.82 mw each)'
#  '(amounts are for the total of all 77 units)'
#  '& 19 units @ 2.2 mw each & 25 units @4.3 mw each'
#  '& 2 units @ 4.8 mw each)' '(amounts are for the total of all 48 units)'
#  '6 units @ 2.72 mw each & 30 units @2.82 mw each)'
#  '(amounts are for the total of all 41 units)' '(40 units @ 2.0 mw each)'
#  '(amounts are for the total of all 40 units)' 'diesel' 'cherokee'
#  '**license surrendered december 1981' '*license surrendered august 1982'
#  '& 12 units at 3.45 mw each)' '(amounts are for total of all 175 units)']
# NON CLUMP OR HEADER PLANT NAMES:
#
#  ['seneca falls (a)', 'rainbow falls (c)', 'cadyville (b)', 'waterloo (a)', 'keuka (d)', 'mill', 'milliken', 'harris lake', 'allen falls (project no. 10462)', 'bakers falls (project no. 2482)', 'baldwinsville (project no. 5217)', 'belfort (project no. 2645)', 'black river (project no. 2569)', 'chasm (project no. 7320)', 'eagle (project no. 2645)', 'east norfolk (project no. 2330)', 'eel weir (project no. 2713)', 'effley (project no. 2645)', 'niagara-project #2466', 'buck-project #2514', 'total hydro (small plants)', 'childs (1)', 'irving (1)', 'bl england a', 'keystone (1) a', 'conemaugh (1) a', 'salem (1) b', 'medway license #2666', 'milford license #2534', 'veazie license #2403', 'ellsworth license #2727', 'howland license #2721', 'stillwater license #2712', 'orono license #2710', 'total', 'eastport', 'medway', 'bar harbor', 'neil simpson station i', 'kirk plant (#4)', 'neil simpson station ii', 'blackstone (steam)', "martha's vineyard", 'marshall hydro', 'internal combustion auxiliary', 'eagle pass hydro', 'valley diesel', 'appleton', 'ferc licensed project number', 'weyauwega - 2550', 'oconto falls - 2523', 'sturgeon - 2471', 'way - 1759', 'michigamme reservoir - 1759', 'lower paint - 2072', 'lynch diesel', 'androscoggin no. 3', 'bar mills', 'wisconsin rapids', 'biron', 'stevens point', 'wisconsin river', 'dubay', 'beacon', 'conners creek', 'harbor beach', 'st clair', 'manistique', 'bonny eagle', 'middlesex stat. 2', 'marshfield stat. 6', 'vergennes st. 9 c', 'w. danville st 15', 'gorge stat. 18', 'essex stat. 19 b', 'waterbury st 22 a', 'deforge stat. 1 d', 'vergennes stat. 9', 'essex stat. 19', 'clear lakes', 'thousand springs', 'salmon diesel', 'elkart (project no. 2651)', 'buchanan (project no. 2551)', 'berrien springs', 'twin branch (project no. 2579)', 'constantine (project no. 10661)', 'mottville (project no.401)', '4th street (leased from city of fort wayne, in)', 'lawton park (leased from city of fort wayne, in)', 'petersburg', 'e.w. stout', 'h.t pritchard', 'dubuque', 'hills', 'lansing', 'new albin', 'rushford', 'wichita (diesel)', 'east hampton diesel', 'montauk diesel', 'houlton', 'caribou', "flo's inn", 'squa pan', 'reservoir', 'caribou unit #1', 'caribou unit #2', 'w.f. wyman #4', 'lanai city plant', 'l1', 'l2', 'l4', 'l7', 'l8', 'miki basin plant', 'll1', 'll2', 'll3', 'll4', 'll5', 'll6', 'total-lanai city & miki basin plants', 'molokai', 'caterpillar 1', 'caterpillar 2', 'gas turbine', 'cummins diesel #6', 'total-molokai', 'conemaugh station', 'knife falls ferc project no. 2360', 'little falls ferc project no. 2532', 'pillager ferc project no. 2663', 'prairie river ferc project no. 2361', 'scanlon ferc project no. 2360', 'sylvan ferc project no. 2454', 'winton ferc project no. 469', 'hydro no.2 station', 'schuykill', 'cromby', 'delaware', 'keystone', 'conemaugh', 'centerville', 'ames', 'marshalltown', 'total diesel', 'anamosa', 'maquoketa', 'iowa falls', 'total hydro', 'total small plants', 'flint creek', 'madison', 'milltown', 'hebgen', 'madison dike', 'lake', 'old faithful', 'tower falls', 'grant village', 'lower paint diversion canal - 2072', 'twin falls - 19=759', 'kingsford - 2131', 'michigamme falls - 2073', 'hemlock falls - 2074', 'white rapids - 2357', 'chalk hills - 2394', 'brule - 2431', 'pine - 2486', 'blackhawk', 'janesville', 'kilbourn', 'shawano', 'portable generator', 'apple river', 'cedar falls', 'eau claire dells', 'menomonie', 'riverdale', 'trego', 'big falls', 'hayward', 'ladysmith', 'saxon falls', 'superior falls', 'thornapple', 'white river', 'clark', 'faulkton', 'highmore', 'redfield', 'webster', 'mobile a', 'mobile b', 'danbury #1 (old)', 'danbury #2 (new)', 'clam falls #1', 'balsam lake', 'clam river dam', 'black brook dam', 'frederic', 'grantsburg', 'danbury', 'danbury combustion turbine', 'new castle', 'r.e. burger', 'hillburn', 'shoemaker', 'hoot lake', 'wright', 'pisgah', 'dayton hollow', 'taplin gorge', 'bemidji', 'portable 148', 'american fork 696', 'ashton 2381', 'beaver - up ...

# %%
# Now, if you take a look at the total and header rows they are a lot cleaner because we got rid of the notes!
clean_totals = spc3[spc3['row_type']=='total'].plant_name_ferc1.value_counts() # print if you want to see
clean_headers = spc3[spc3['row_type']=='header'].plant_name_ferc1.value_counts() # print if you want to see

# There are some recurring TOTAL rows that contain the plant name "(amounts are for the total of..."
# If you look here, however, only two of them contain any useful information (i.e., they're notes not totals)
num_cols = [x for x in spc3.select_dtypes(include=['float', 'Int64']).columns.tolist() if x not in ['utility_id_ferc1', 'report_year', 'ferc_license_id']]
test = spc3[spc3['plant_name_ferc1'].str.contains('amounts are for')]
print("'AMOUNTS ARE FOR'...ROWS WITH NON ZERO/NA VALUES")
display(test[test[num_cols] > 0].dropna(how='all')) # print this out if you want to see for yourself

# Lets take that one row with helpful information and copy it to the one above (where it should be)
print('\nTOTAL ROW CONTAINS INFORMATION THAT SHOULD BE IN THE ROW ABOVE')
display(spc3.iloc[8293:8295]) # the info from this total row belongs above!
spc3.loc[[8293],num_cols] = spc3.loc[8294][num_cols].values # move the information up
print('\nMOVED TOTAL VALUES TO TOTAL ROW')
display(spc3.iloc[8293:8295]) # look at this to see that both rows now have the same numeric information

# Now we can confidently call all rows with "(amounts are for the total of..." NOTE rather than TOTAL
spc3.loc[spc3['plant_name_ferc1'].str.contains('amounts are for'), 'row_type'] = 'note'
# Out:
# 'AMOUNTS ARE FOR'...ROWS WITH NON ZERO/NA VALUES
#       utility_id_ferc1  report_year plant_name_ferc1 row_type possible_header  \
# 8290               NaN          NaN              NaN      NaN             NaN
# 8294               NaN          NaN              NaN      NaN             NaN
#
#       construction_year  capacity_mw  peak_demand_mw  net_generation_mwh  \
# 8290             1942.0          NaN             NaN                 NaN
# 8294             2004.0        160.5           160.5            704000.0
#
#       total_cost_of_plant  capex_per_mw  opex_total  opex_fuel  \
# 8290                  NaN           NaN         NaN        NaN
# 8294          156897178.0      977553.0    136296.0        NaN
#
#       opex_maintenance fuel_type  fuel_cost_per_mmbtu plant_name_clean  \
# 8290               NaN       NaN                  NaN              NaN
# 8294               NaN       NaN                  NaN              NaN
#
#      plant_type  ferc_license_id record_id
# 8290        NaN              NaN       NaN
# 8294        NaN              NaN       NaN
# TOTAL ROW CONTAINS INFORMATION THAT SHOULD BE IN THE ROW ABOVE
#       utility_id_ferc1  report_year  \
# 8293               210         2004
# 8294               210         2004
#
#                                   plant_name_ferc1 row_type  possible_header  \
# 8293  intrepid wind farm (107 units @ 1.5 mw each)      NaN             True
# 8294  (amounts are for the total of all 107 units)    total            False
#
#       construction_year  capacity_mw  peak_demand_mw  net_generation_mwh  \
# 8293                NaN          0.0             0.0                 NaN
# 8294             2004.0        160.5           160.5            704000.0
#
#       total_cost_of_plant  capex_per_mw  opex_total  opex_fuel  \
# 8293                  NaN           NaN         NaN        NaN
# 8294          156897178.0      977553.0    136296.0        NaN
#
#       opex_maintenance fuel_type  fuel_cost_per_mmbtu  \
# 8293               NaN                            NaN
# 8294               NaN                            NaN
#
#                                   plant_name_clean plant_type  \
# 8293  intrepid wind farm (107 units @ 1.5 mw each)        NaN
# 8294                            intrepid wind farm       wind
#
#       ferc_license_id                      record_id
# 8293              NaN  f1_gnrt_plant_2004_12_210_0_7
# 8294              NaN  f1_gnrt_plant_2004_12_210_0_8
# MOVED TOTAL VALUES TO TOTAL ROW
#       utility_id_ferc1  report_year  \
# 8293               210         2004
# 8294               210         2004
#
#                                   plant_name_ferc1 row_type  possible_header  \
# 8293  intrepid wind farm (107 units @ 1.5 mw each)      NaN             True
# 8294  (amounts are for the total of all 107 units)    total            False
#
#       construction_year  capacity_mw  peak_demand_mw  net_generation_mwh  \
# 8293             2004.0        160.5           160.5            704000.0
# 8294             2004.0        160.5           160.5            704000.0
#
#       total_cost_of_plant  capex_per_mw  opex_total  opex_fuel  \
# 8293          156897178.0      977553.0    136296.0        NaN
# 8294          156897178.0      977553.0    136296.0        NaN
#
#       opex_maintenance fuel_type  fuel_cost_per_mmbtu  \
# 8293               NaN                            NaN
# 8294               NaN                            NaN
#
#                                   plant_name_clean plant_type  \
# 8293  intrepid wind farm (107 units @ 1.5 mw each)        NaN
# 8294                            intrepid wind farm       wind
#
#       ferc_license_id                      record_id
# 8293              NaN  f1_gnrt_plant_2004_12_210_0_7
# 8294              NaN  f1_gnrt_plant_2004_12_210_0_8

# %%
# There are some rows that looks like they could be headers or totals, but this shows that
# they all have information in their respective rows are are therefore correctly designated as TOTALS.
spc3[(spc3['plant_name_ferc1'].str.contains('total')) & (spc3['plant_name_ferc1'].str.contains(':'))]
# Out:
#        utility_id_ferc1  report_year           plant_name_ferc1 row_type  \
# 13267               161         2012               total hydro:    total
# 13285               161         2012  total solar photovoltaic:    total
# 16267               193         2016                     total:    total
# 17052               193         2017                     total:    total
# 18098               193         2018                     total:    total
#
#        possible_header  construction_year  capacity_mw  peak_demand_mw  \
# 13267            False                NaN         74.3            74.0
# 13285            False                NaN         21.0            21.0
# 16267            False                NaN        395.3             0.0
# 17052            False                NaN        398.1             0.0
# 18098            False                NaN        587.2             0.0
#
#        net_generation_mwh  total_cost_of_plant  capex_per_mw  opex_total  \
# 13267        1.983915e+08          164383888.0    61522031.0   8425540.0
# 13285        3.214275e+07          108241238.0    68033111.0   3987417.0
# 16267        1.025813e+09          844115518.0    49347843.0   3830812.0
# 17052        1.089549e+09          839018896.0    60062594.0   4499639.0
# 18098        9.349530e+08          856253120.0    61444114.0   5582861.0
#
#        opex_fuel  opex_maintenance fuel_type  fuel_cost_per_mmbtu  \
# 13267        NaN         3346929.0                            NaN
# 13285        NaN               NaN                            NaN
# 16267        NaN        10384670.0                            NaN
# 17052        NaN         9175033.0                            NaN
# 18098        NaN         9102533.0                            NaN
#
#                 plant_name_clean plant_type  ferc_license_id  \
# 13267               total hydro:        NaN              NaN
# 13285  total solar photovoltaic:   solar_pv              NaN
# 16267                     total:        NaN              NaN
# 17052                     total:        NaN              NaN
# 18098                     total:        NaN              NaN
#
#                             record_id
# 13267  f1_gnrt_plant_2012_12_161_0_36
# 13285   f1_gnrt_plant_2012_12_161_1_7
# 16267  f1_gnrt_plant_2016_12_193_0_20
# 17052  f1_gnrt_plant_2017_12_193_0_21
# 18098  f1_gnrt_plant_2018_12_193_0_20

# %% [markdown]
# ## 4) Apply Header Fuel Type to Relevant Rows

# %%
spc4 = spc3.copy()

# Clean header names
spc4['header_clean'] = np.nan
d = expand_dict(zane_header_labels)

# Map cleaned header names onto df in a new column
spc4.loc[spc4['row_type']=='header', 'header_clean'] = (
    spc4['plant_name_ferc1'].str.extract(fr"({'|'.join(d.keys())})", expand=False).map(d))

# See what wasn't cleaned up
spc4[(spc4['row_type']=='header') & (spc4['header_clean'].isna())].plant_name_ferc1.value_counts()
# Out:
# other                                           25
# hydraulic:                                      15
# other:                                           8
# lewiston canal facilities:                       7
# hydraulic                                        6
# renewables:                                      5
# other general ops. supervision & engineering     3
# other production:                                2
# hydraulic (1):                                   1
# other-leased:                                    1
# renewables                                       1
# Name: plant_name_ferc1, dtype: int64

# %%
# Make groups based on utility, year, and header
header_groups = spc4.groupby(['utility_id_ferc1', 'report_year', (spc4['row_type']=='header').cumsum()])

# Forward fill based on headers
spc4['fuel_type'] = np.nan
spc4.loc[spc4['row_type']!='note', 'fuel_type'] = header_groups.header_clean.ffill()

# %%
## COME UP WITH A WAY TO CHECK FUEL TYPE OVER TIME MAYBE BY PLANT ID?

# %%
# 161	1994
# 29	2000 # forked up....

# Use this to see how well it worked!
util_groups = spc4.groupby(['utility_id_ferc1', 'report_year'])
get_rand_group(util_groups)[['plant_name_ferc1', 'row_type', 'header_clean', 'fuel_type', 'construction_year']]
# Out:
#          plant_name_ferc1 row_type         header_clean            fuel_type  \
# 7328                steam   header           steam_heat           steam_heat
# 7329       kauai, hawaii:      NaN                  NaN           steam_heat
# 7330  internal combustion   header  internal_combustion  internal_combustion
# 7331        kauai, hawaii      NaN                  NaN  internal_combustion
# 7332        kauai, hawaii      NaN                  NaN  internal_combustion
# 7333    newport, vermont:      NaN                  NaN  internal_combustion
# 7334              turbine      NaN                  NaN  internal_combustion
# 7335         valencia, az      NaN                  NaN  internal_combustion
# 7336                hydro   header                hydro                hydro
# 7337  charleston, vermont      NaN                  NaN                hydro
# 7338     newport, vermont      NaN                  NaN                hydro
#
#       construction_year
# 7328                NaN
# 7329             1969.0
# 7330                NaN
# 7331             1964.0
# 7332             1991.0
# 7333             1948.0
# 7334                NaN
# 7335             1989.0
# 7336                NaN
# 7337             1928.0
# 7338             1917.0

# %% [markdown]
# ## 5) Fill-in Obvioius Fuel Types (just hydro for now)

# %%
spc5 = spc4.copy()

# Check for non-labeled hydro in name
non_labeled_hydro = spc5[(spc5['fuel_type']!='hydro') & (spc5['row_type']!='note') & (spc5['plant_name_ferc1'].str.contains('hydro'))].plant_name_ferc1.value_counts()

# Fill in hydro
not_note = spc5['row_type'] != 'note'
contains_hydro = spc5['plant_name_ferc1'].str.contains('hydro')
spc5.loc[not_note & contains_hydro, 'fuel_type'] = 'hydro'

# %%
# THERE ARE STILL LOTS OF KINKS TO WORK OUT SO JUST DOING HYDRO FOR NOW

# # label all "obvious" plant types
# fuel_dict = expand_dict(zane_header_labels)
# not_note = spc5['row_type'] != 'note'
# in_keys = spc5['plant_name_ferc1'].str.contains('|'.join(fuel_dict.keys()), regex=True)
# in_two_fuel_keys = spc5['plant_name_ferc1'].str.contains('|'.join(two_fuel_names_dict.keys()), regex=True)
# not_in_exceptions = ~spc5['plant_name_ferc1'].str.contains('windsor rd|gaston|sc-etwind')

# # replace obvious
# spc5.loc[not_note & in_keys & not_in_exceptions, 'fuel_type'] = (
#     spc5['plant_name_ferc1'].str.extract(fr"({'|'.join(fuel_dict.keys())})", expand=False).map(fuel_dict))

# # replace outliers
# spc5.loc[not_note & in_two_fuel_keys, 'fuel_type'] = (
#     spc5['plant_name_ferc1'].str.extract(fr"({'|'.join(two_fuel_names_dict.keys())})", expand=False).map(two_fuel_names_dict))

# %%
# Take a look
util_groups = spc5.groupby(['utility_id_ferc1', 'report_year'])
get_rand_group(util_groups)[['plant_name_ferc1', 'row_type', 'header_clean', 'fuel_type', 'construction_year']]
# Out:
#                           plant_name_ferc1 row_type header_clean fuel_type  \
# 15936                         solar plants   header     solar_pv  solar_pv
# 15937                     newman pv system      NaN          NaN  solar_pv
# 15938                 rio grande pv system      NaN          NaN  solar_pv
# 15939                  wrangler cpv system      NaN          NaN  solar_pv
# 15940                    stanton pv system      NaN          NaN  solar_pv
# 15941  el paso community college pv system      NaN          NaN  solar_pv
# 15942                   van horn pv system      NaN          NaN  solar_pv
# 15943                          total solar    total          NaN  solar_pv
#
#        construction_year
# 15936                NaN
# 15937             2009.0
# 15938             2009.0
# 15939             2011.0
# 15940             2012.0
# 15941             2012.0
# 15942             2013.0
# 15943                NaN

# %% [markdown]
# ## 6) Associate Notes and Add FERC ID Column

# %%
def extract_ferc_lic_from_name(df):

    """Extract FERC license number from plant_name_ferc1 and make new column.
    
    Many of FERC license numbers are embedded in the plant_name_ferc1 field, whether
    thats a note row or an actual plant name. This function extracts those license 
    numbers and puts them in a new column.
    
    """
    # Extract all numbers greater than 2 digits from plant_name_ferc1 and put then in a new column as integers.
    # Rename manually collected FERC id column to reflect that.
    df = (
        df.assign(
            ferc_license=lambda x: x.plant_name_ferc1.str.extract('(\d{3,})').astype('float').astype('Int64'),
            ferc_license_id=lambda x: x.ferc_license_id.astype('Int64'))
        .rename(columns={'ferc_license_id': 'ferc_license_manual'}))
    
    
    # Not all of these 3+ digit numbers are FERC licenses. Some are dates, dollar amounts, page numbers, or numbers
    # of wind turbines. These next distinctions help to weed out the non-licesnse values and keep the good ones.
    obvious_license = df.plant_name_ferc1.str.contains('no\.|license|ferc|project', regex=True)
    not_license = df.plant_name_ferc1.str.contains('page|pg|\$|wind|nonutility|units|surrendered', regex=True)
    exceptions = df.plant_name_ferc1.str.contains('tomahawk|otter rapids|wausau|alexander|hooksett|north umpqua', regex=True)
    year_vs_num = (df['ferc_license'] > 1900) & (df['ferc_license'] < 2050)
    not_hydro = ~df.plant_type.isin(['hydro', np.nan]) # figure this one out.....
    extracted_license = df.ferc_license.notna()
    
    # Replace all the non-license numbers with nan
    df.loc[extracted_license & not_hydro, 'ferc_license'] = pd.NA # figure this one out.....
    extracted_license = df.ferc_license.notna() # reset
    df.loc[extracted_license & not_license, 'ferc_license'] = pd.NA
    extracted_license = df.ferc_license.notna() #reset
    df.loc[extracted_license & year_vs_num & ~obvious_license & ~exceptions, 'ferc_license'] = pd.NA

    df['ferc_license'] = df.ferc_license.astype('Int64') # figure out how not to do this twice....
    
    return df

# %%
spc6 = extract_ferc_lic_from_name(spc5)

# %% [markdown]
# Now we have to get the license numbers that appear in notes! These values are a few lines below the actual row they apply to.

# %%
def associate_footnotes_and_license_with_values(group):
    """The """
    
    footnote_pattern = r'(\(\d?[a-z]?[A-Z]?\))'
    regular_row = group['row_type'].isna()
    has_note = group['row_type']=='note'
    has_footnote = group.plant_name_ferc1.str.contains(footnote_pattern)
    
    # Create footnote column
    
    
    # Shorten execution time by only looking at groups with discernable footnotes
    if group.footnote.any():
        print('found')
        # Create new footnote column
        group.loc[:, 'footnote'] = group.plant_name_ferc1.str.extract(footnote_pattern, expand=False)

        # Make a df that combines notes and ferc license with the same footnote value.
        footnote_df = (
            group[has_note]
            .groupby('footnote')
            .agg({'plant_name_ferc1': ', '.join,
                  'ferc_license': 'first'})
            .rename(columns={'plant_name_ferc1': 'notes'}))

        # Map these new licnese and note values onto the original df
        updated_ferc_license_col = group.footnote.map(footnote_df['ferc_license'])
        notes_col = group.footnote.map(footnote_df['notes'])
        group.ferc_license.update(updated_ferc_license_col)
        group['notes'] = notes_col

    return group

# %%
# %%time
spc6['notes'] = pd.NA
groups = spc6.groupby(['report_year', 'utility_id_ferc1'])
spc6 = groups.apply(lambda x: associate_footnotes_and_license_with_values(x))
# Out:
# /var/folders/tf/l271ymp92vvbty6j01j580xm0000gn/T/ipykernel_41319/2083082642.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   has_footnote = group.plant_name_ferc1.str.contains(footnote_pattern)
# CPU times: user 3.89 s, sys: 34.1 ms, total: 3.92 s
# Wall time: 3.95 s

# %%
# 57	2020	
test_groups = spc6.groupby(['utility_id_ferc1', 'report_year'])
test = get_rand_group(test_groups)[['utility_id_ferc1', 'report_year', 'plant_name_ferc1', 'row_type', 'ferc_license', 'notes', 'footnote', 'note']]

# %%
spc6
# Out:
#        utility_id_ferc1  report_year   plant_name_ferc1 row_type  \
# 0                   115         1994              hydro   header
# 1                   115         1994   seneca falls (a)      NaN
# 2                   115         1994  rainbow falls (c)      NaN
# 3                   115         1994      cadyville (b)      NaN
# 4                   115         1994       waterloo (a)      NaN
# ...                 ...          ...                ...      ...
# 19837               193         2020    pine - 2486 (4)      NaN
# 19838               193         2020              solar   header
# 19839               193         2020          solar now      NaN
# 19840               193         2020              other   header
# 19841               193         2020  valley diesel (1)      NaN
#
#        possible_header  construction_year  capacity_mw  peak_demand_mw  \
# 0                 True                NaN         0.00             0.0
# 1                False             1917.0         8.00             6.0
# 2                False             1926.0         2.64             2.8
# 3                False             1922.0         5.53             4.9
# 4                False             1915.0         1.92             1.3
# ...                ...                ...          ...             ...
# 19837            False             1922.0         3.20             4.2
# 19838             True                NaN         0.00             0.0
# 19839            False             2019.0        11.00             6.4
# 19840             True                NaN         0.00             0.0
# 19841            False             1968.0         3.00             3.0
#
#        net_generation_mwh  total_cost_of_plant  capex_per_mw  opex_total  \
# 0                     NaN                  NaN           NaN         NaN
# 1              17695840.0            2342818.0         293.0     45573.0
# 2              17108000.0            2666266.0        1010.0     57909.0
# 3              26108906.0           15002778.0        2713.0     55345.0
# 4               5027300.0            1103365.0         575.0     71829.0
# ...                   ...                  ...           ...         ...
# 19837          23517900.0            7081132.0     2212854.0     78338.0
# 19838                 NaN                  NaN           NaN         NaN
# 19839           8325000.0           17649831.0     1604530.0    236831.0
# 19840                 NaN                  NaN           NaN         NaN
# 19841                 NaN                  NaN           NaN         NaN
#
#        opex_fuel  opex_maintenance fuel_type  fuel_cost_per_mmbtu  \
# 0            NaN               NaN     hydro                  NaN
# 1            NaN           33766.0     hydro                  NaN
# 2            NaN           40082.0     hydro                  NaN
# 3            NaN          140692.0     hydro                  NaN
# 4            NaN           13091.0     hydro                  NaN
# ...          ...               ...       ...                  ...
# 19837        NaN          163434.0     hydro                  NaN
# 19838        NaN               NaN  solar_pv                  NaN
# 19839        NaN               NaN  solar_pv                  NaN
# 19840        NaN               NaN       NaN                  NaN
# 19841     4398.0               NaN       NaN                  NaN
#
#         plant_name_clean plant_type  ferc_license_manual  \
# 0                  hydro        NaN                 <NA>
# 1       seneca falls (a)        NaN                 <NA>
# 2      rainbow falls (c)        NaN                 <NA>
# 3          cadyville (b)        NaN                 <NA>
# 4           waterloo (a)        NaN                 <NA>
# ...                  ...        ...                  ...
# 19837    pine - 2486 (4)        NaN                 <NA>
# 19838              solar        NaN                 <NA>
# 19839          solar now        NaN                 <NA>
# 19840              other        NaN                 <NA>
# 19841  valley diesel (1)        NaN                 <NA>
#
#                             record_id header_clean  ferc_license  \
# 0       f1_gnrt_plant_1994_12_115_0_1        hydro          <NA>
# 1       f1_gnrt_plant_1994_12_115_0_2          NaN          2438
# 2       f1_gnrt_plant_1994_12_115_0_3          NaN          2835
# 3       f1_gnrt_plant_1994_12_115_0_4          NaN          2738
# 4       f1_gnrt_plant_1994_12_115_0_5          NaN          2438
# ...                               ...          ...           ...
# 19837  f1_gnrt_plant_2020_12_193_0_14          NaN          2486
# 19838  f1_gnrt_plant_2020_12_193_0_16     solar_pv          <NA>
# 19839  f1_gnrt_plant_2020_12_193_0_17          NaN          <NA>
# 19840  f1_gnrt_plant_2020_12_193_0_19          NaN          <NA>
# 19841  f1_gnrt_plant_2020_12_193_0_20          NaN          <NA>
#
#                    notes footnote               note
# 0                    NaN      NaN                NaN
# 1      (a) project #2438      (a)  (a) project #2438
# 2      (c) project #2835      (c)  (c) project #2835
# 3      (b) project #2738      (b)  (b) project #2738
# 4      (a) project #2438      (a)  (a) project #2438
# ...                  ...      ...                ...
# 19837                NaN      (4)                NaN
# 19838                NaN      NaN                NaN
# 19839                NaN      NaN                NaN
# 19840                NaN      NaN                NaN
# 19841                NaN      (1)                NaN
#
# [19842 rows x 25 columns]
