# %%
import sys
import os
import numpy as np
import pandas as pd
import sqlalchemy as sa
sys.path.append(os.path.abspath(os.path.join('..','..','..')))
from pudl import pudl, ferc1, eia923, settings, constants
from pudl import models, models_ferc1, models_eia923
from pudl import clean_eia923, clean_ferc1, clean_pudl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pudl_engine  = pudl.db_connect_pudl()

# %%
#Pull in the generation table
plants_eia923_tbl = models.PUDLBase.metadata.tables['plants_eia923']
p_select = sa.sql.select([plants_eia923_tbl,]) #creates a sql Select object
p = pd.read_sql(p_select, pudl_engine) #converts sql object to pandas dataframe

# %%
p[p['plant_id'] == 527]
# Out:
#       plant_id plant_name  plant_id_pudl
# 1415       527      Nucla           1516

# %%
#Pull in the generation table
g_tbl = models.PUDLBase.metadata.tables['generation_eia923']
g_select = sa.sql.select([g_tbl,]) #creates a sql Select object
g = pd.read_sql(g_select, pudl_engine) #converts sql object to pandas dataframe

# %%
g[(g['plant_id'] == 602)]# & (g['prime_mover']== 'CA') & (g['generator_id']== '2')]
# Out:
#             id  plant_id prime_mover generator_id report_date  \
# 2652      2653       602          ST            1  2009-01-01
# 2653      2654       602          ST            1  2009-02-01
# 2654      2655       602          ST            1  2009-03-01
# 2655      2656       602          ST            1  2009-04-01
# 2656      2657       602          ST            1  2009-05-01
# 2657      2658       602          ST            1  2009-06-01
# 2658      2659       602          ST            1  2009-07-01
# 2659      2660       602          ST            1  2009-08-01
# 2660      2661       602          ST            1  2009-09-01
# 2661      2662       602          ST            1  2009-10-01
# 2662      2663       602          ST            1  2009-11-01
# 2663      2664       602          ST            1  2009-12-01
# 2664      2665       602          ST            2  2009-01-01
# 2665      2666       602          ST            2  2009-02-01
# 2666      2667       602          ST            2  2009-03-01
# 2667      2668       602          ST            2  2009-04-01
# 2668      2669       602          ST            2  2009-05-01
# 2669      2670       602          ST            2  2009-06-01
# 2670      2671       602          ST            2  2009-07-01
# 2671      2672       602          ST            2  2009-08-01
# 2672      2673       602          ST            2  2009-09-01
# 2673      2674       602          ST            2  2009-10-01
# 2674      2675       602          ST            2  2009-11-01
# 2675      2676       602          ST            2  2009-12-01
# 37884    37885       602          ST            1  2010-01-01
# 37885    37886       602          ST            1  2010-02-01
# 37886    37887       602          ST            1  2010-03-01
# 37887    37888       602          ST            1  2010-04-01
# 37888    37889       602          ST            1  2010-05-01
# 37889    37890       602          ST            1  2010-06-01
# ...        ...       ...         ...          ...         ...
# 240642  240643       602          ST            2  2015-07-01
# 240643  240644       602          ST            2  2015-08-01
# 240644  240645       602          ST            2  2015-09-01
# 240645  240646       602          ST            2  2015-10-01
# 240646  240647       602          ST            2  2015-11-01
# 240647  240648       602          ST            2  2015-12-01
# 290508  290509       602          ST            1  2016-01-01
# 290509  290510       602          ST            1  2016-02-01
# 290510  290511       602          ST            1  2016-03-01
# 290511  290512       602          ST            1  2016-04-01
# 290512  290513       602          ST            1  2016-05-01
# 290513  290514       602          ST            1  2016-06-01
# 290514  290515       602          ST            1  2016-07-01
# 290515  290516       602          ST            1  2016-08-01
# 290516  290517       602          ST            1  2016-09-01
# 290517  290518       602          ST            1  2016-10-01
# 290518  290519       602          ST            1  2016-11-01
# 290519  290520       602          ST            1  2016-12-01
# 290520  290521       602          ST            2  2016-01-01
# 290521  290522       602          ST            2  2016-02-01
# 290522  290523       602          ST            2  2016-03-01
# 290523  290524       602          ST            2  2016-04-01
# 290524  290525       602          ST            2  2016-05-01
# 290525  290526       602          ST            2  2016-06-01
# 290526  290527       602          ST            2  2016-07-01
# 290527  290528       602          ST            2  2016-08-01
# 290528  290529       602          ST            2  2016-09-01
# 290529  290530       602          ST            2  2016-10-01
# 290530  290531       602          ST            2  2016-11-01
# 290531  290532       602          ST            2  2016-12-01
#
#         net_generation_mwh  gen_code gen_boiler_code_2
# 2652              436667.0  602_1_ST            602_ST
# 2653              340491.0  602_1_ST            602_ST
# 2654              348869.0  602_1_ST            602_ST
# 2655              319313.0  602_1_ST            602_ST
# 2656              116343.0  602_1_ST            602_ST
# 2657              321103.0  602_1_ST            602_ST
# 2658              329374.0  602_1_ST            602_ST
# 2659              279907.0  602_1_ST            602_ST
# 2660                6103.0  602_1_ST            602_ST
# 2661                   0.0  602_1_ST            602_ST
# 2662                   0.0  602_1_ST            602_ST
# 2663              304403.0  602_1_ST            602_ST
# 2664              397239.0  602_2_ST            602_ST
# 2665              350686.0  602_2_ST            602_ST
# 2666              351653.0  602_2_ST            602_ST
# 2667              294969.0  602_2_ST            602_ST
# 2668              326496.0  602_2_ST            602_ST
# 2669              271335.0  602_2_ST            602_ST
# 2670              332037.0  602_2_ST            602_ST
# 2671              345979.0  602_2_ST            602_ST
# 2672              253843.0  602_2_ST            602_ST
# 2673              226006.0  602_2_ST            602_ST
# 2674              295078.0  602_2_ST            602_ST
# 2675              396465.0  602_2_ST            602_ST
# 37884             400949.0  602_1_ST            602_ST
# 37885             332040.0  602_1_ST            602_ST
# 37886             320742.0  602_1_ST            602_ST
# 37887             233907.0  602_1_ST            602_ST
# 37888             172776.0  602_1_ST            602_ST
# 37889             305356.0  602_1_ST            602_ST
# ...                    ...       ...               ...
# 240642            344118.0  602_2_ST            602_ST
# 240643            177930.0  602_2_ST            602_ST
# 240644            291186.0  602_2_ST            602_ST
# 240645            211469.0  602_2_ST            602_ST
# 240646            153405.0  602_2_ST            602_ST
# 240647            262980.0  602_2_ST            602_ST
# 290508            159778.0  602_1_ST            602_ST
# 290509            157117.0  602_1_ST            602_ST
# 290510            241995.0  602_1_ST            602_ST
# 290511            268161.0  602_1_ST            602_ST
# 290512                 0.0  602_1_ST            602_ST
# 290513            185949.0  602_1_ST            602_ST
# 290514            279625.0  602_1_ST            602_ST
# 290515            339980.0  602_1_ST            602_ST
# 290516            328028.0  602_1_ST            602_ST
# 290517            136812.0  602_1_ST            602_ST
# 290518            276293.0  602_1_ST            602_ST
# 290519            160603.0  602_1_ST            602_ST
# 290520            163327.0  602_2_ST            602_ST
# 290521            193813.0  602_2_ST            602_ST
# 290522            259051.0  602_2_ST            602_ST
# 290523             54669.0  602_2_ST            602_ST
# 290524             79192.0  602_2_ST            602_ST
# 290525            253854.0  602_2_ST            602_ST
# 290526            293361.0  602_2_ST            602_ST
# 290527            331143.0  602_2_ST            602_ST
# 290528             97819.0  602_2_ST            602_ST
# 290529             90225.0  602_2_ST            602_ST
# 290530             96077.0  602_2_ST            602_ST
# 290531            293874.0  602_2_ST            602_ST
#
# [192 rows x 8 columns]

# %%
g['gen_code'] = g['plant_id'].map(str) + "_" + g['generator_id'] + "_" + g['prime_mover']
g['gen_boiler_code_2'] = g['plant_id'].map(str) + "_" + g['prime_mover']
gen_code = g[['plant_id', 'prime_mover', 'generator_id', 'gen_code', 'gen_boiler_code_2']].copy()
gen_code['gen_boiler_code'] = gen_code['gen_code']
gen_code = gen_code.drop_duplicates()
gen_code = gen_code.rename(columns={'plant_id': 'plant_id_gen',
                         'prime_mover': 'prime_mover_gen'})

# %%
#Pull in the generation table
b_tbl = models.PUDLBase.metadata.tables['boiler_fuel_eia923']
b_select = sa.sql.select([b_tbl,]) #creates a sql Select object
b = pd.read_sql(b_select, pudl_engine) #converts sql object to pandas dataframe

# %%
b[b['plant_id'] == 527].drop_duplicates(subset='boiler_id')
# Out:
#         id  plant_id boiler_id prime_mover fuel_type report_date  \
# 4069  4069       527         1          ST       BIT  2009-01-01
#
#       fuel_qty_consumed  fuel_mmbtu_per_unit  sulfur_content  ash_content
# 4069            30374.0                21.11            0.71         21.2

# %%
b['boiler_code'] = b['plant_id'].map(str) + "_" + b['boiler_id'] + "_" + b['prime_mover']
b['gen_boiler_code_2'] = b['plant_id'].map(str) + "_" + b['prime_mover']
boiler_code = b.copy()
boiler_code['gen_boiler_code'] = boiler_code['boiler_code']
boiler_code = boiler_code.drop_duplicates()
boiler_code = boiler_code.rename(columns={'plant_id': 'plant_id_boiler',
                            'prime_mover': 'prime_mover_boiler'})
boiler_code
# Out:
#       plant_id_boiler boiler_id prime_mover_boiler      boiler_code  \
# 0                   3         1                 ST           3_1_ST
# 1                   3         2                 ST           3_2_ST
# 2                   3         3                 ST           3_3_ST
# 3                   3         4                 ST           3_4_ST
# 4                   3         5                 ST           3_5_ST
# 5                   3        6A                 CA          3_6A_CA
# 6                   3        6B                 CA          3_6B_CA
# 7                   3        7A                 CA          3_7A_CA
# 8                   3        7B                 CA          3_7B_CA
# 9                   7         1                 ST           7_1_ST
# 10                  7         2                 ST           7_2_ST
# 11                  8        10                 ST          8_10_ST
# 12                  8         6                 ST           8_6_ST
# 13                  8         7                 ST           8_7_ST
# 14                  8         8                 ST           8_8_ST
# 15                  8         9                 ST           8_9_ST
# 16                 10         1                 ST          10_1_ST
# 17                 10         2                 ST          10_2_ST
# 18                 26         1                 ST          26_1_ST
# 19                 26         2                 ST          26_2_ST
# 20                 26         3                 ST          26_3_ST
# 21                 26         4                 ST          26_4_ST
# 22                 26         5                 ST          26_5_ST
# 23                 47         1                 ST          47_1_ST
# 24                 47         2                 ST          47_2_ST
# 25                 47         3                 ST          47_3_ST
# 26                 47         4                 ST          47_4_ST
# 27                 47         5                 ST          47_5_ST
# 28                 50         1                 ST          50_1_ST
# 29                 50         2                 ST          50_2_ST
# ...               ...       ...                ...              ...
# 5755             1239     HSG12                 CA    1239_HSG12_CA
# 5756             1378      CTG1                 CT     1378_CTG1_CT
# 5757             1378      CTG2                 CT     1378_CTG2_CT
# 5758             1378      CTG3                 CT     1378_CTG3_CT
# 5759             1378      STG1                 CA     1378_STG1_CA
# 5760            10560     POWB4                 ST   10560_POWB4_ST
# 5761            10560     POWB5                 ST   10560_POWB5_ST
# 5762            56846      GTG1                 CT    56846_GTG1_CT
# 5763            56846      GTG2                 CT    56846_GTG2_CT
# 5764            57759       3PB                 ST     57759_3PB_ST
# 5765            57759       4RF                 ST     57759_4RF_ST
# 5766            57759       5PB                 ST     57759_5PB_ST
# 5767            58260      CT01                 CT    58260_CT01_CT
# 5768            58260      CT02                 CT    58260_CT02_CT
# 5769            58260      CT03                 CT    58260_CT03_CT
# 5770            58260    HRSG1A                 CA  58260_HRSG1A_CA
# 5771            58260    HRSG1B                 CA  58260_HRSG1B_CA
# 5772            58260    HRSG1C                 CA  58260_HRSG1C_CA
# 5773            58420      GEN1                 CS    58420_GEN1_CS
# 5774            58420      GEN2                 CS    58420_GEN2_CS
# 5775            58426      GEN1                 CS    58426_GEN1_CS
# 5776            58426      GEN2                 CS    58426_GEN2_CS
# 5777            58426     HRSG1                 CS   58426_HRSG1_CS
# 5778            58426     HRSG2                 CS   58426_HRSG2_CS
# 5779            58503      GEN1                 CT    58503_GEN1_CT
# 5780            58503      GEN2                 CA    58503_GEN2_CA
# 5781            60768       2 A                 CA     60768_2 A_CA
# 5782            60768       2 B                 CA     60768_2 B_CA
# 5783            60768      CTG3                 CT    60768_CTG3_CT
# 5784            60768      CTG4                 CT    60768_CTG4_CT
#
#      gen_boiler_code_2  gen_boiler_code
# 0                 3_ST           3_1_ST
# 1                 3_ST           3_2_ST
# 2                 3_ST           3_3_ST
# 3                 3_ST           3_4_ST
# 4                 3_ST           3_5_ST
# 5                 3_CA          3_6A_CA
# 6                 3_CA          3_6B_CA
# 7                 3_CA          3_7A_CA
# 8                 3_CA          3_7B_CA
# 9                 7_ST           7_1_ST
# 10                7_ST           7_2_ST
# 11                8_ST          8_10_ST
# 12                8_ST           8_6_ST
# 13                8_ST           8_7_ST
# 14                8_ST           8_8_ST
# 15                8_ST           8_9_ST
# 16               10_ST          10_1_ST
# 17               10_ST          10_2_ST
# 18               26_ST          26_1_ST
# 19               26_ST          26_2_ST
# 20               26_ST          26_3_ST
# 21               26_ST          26_4_ST
# 22               26_ST          26_5_ST
# 23               47_ST          47_1_ST
# 24               47_ST          47_2_ST
# 25               47_ST          47_3_ST
# 26               47_ST          47_4_ST
# 27               47_ST          47_5_ST
# 28               50_ST          50_1_ST
# 29               50_ST          50_2_ST
# ...                ...              ...
# 5755           1239_CA    1239_HSG12_CA
# 5756           1378_CT     1378_CTG1_CT
# 5757           1378_CT     1378_CTG2_CT
# 5758           1378_CT     1378_CTG3_CT
# 5759           1378_CA     1378_STG1_CA
# 5760          10560_ST   10560_POWB4_ST
# 5761          10560_ST   10560_POWB5_ST
# 5762          56846_CT    56846_GTG1_CT
# 5763          56846_CT    56846_GTG2_CT
# 5764          57759_ST     57759_3PB_ST
# 5765          57759_ST     57759_4RF_ST
# 5766          57759_ST     57759_5PB_ST
# 5767          58260_CT    58260_CT01_CT
# 5768          58260_CT    58260_CT02_CT
# 5769          58260_CT    58260_CT03_CT
# 5770          58260_CA  58260_HRSG1A_CA
# 5771          58260_CA  58260_HRSG1B_CA
# 5772          58260_CA  58260_HRSG1C_CA
# 5773          58420_CS    58420_GEN1_CS
# 5774          58420_CS    58420_GEN2_CS
# 5775          58426_CS    58426_GEN1_CS
# 5776          58426_CS    58426_GEN2_CS
# 5777          58426_CS   58426_HRSG1_CS
# 5778          58426_CS   58426_HRSG2_CS
# 5779          58503_CT    58503_GEN1_CT
# 5780          58503_CA    58503_GEN2_CA
# 5781          60768_CA     60768_2 A_CA
# 5782          60768_CA     60768_2 B_CA
# 5783          60768_CT    60768_CTG3_CT
# 5784          60768_CT    60768_CTG4_CT
#
# [5785 rows x 6 columns]

# %%
gen_boiler_map = pd.merge(gen_code, boiler_code, how='outer', on=['gen_boiler_code'])
gen_boiler_map['mapped'] = (gen_boiler_map['gen_code'].notnull() & gen_boiler_map['boiler_code'].notnull())
gen_boiler_map.count()
# Out:
# plant_id_gen           4967
# prime_mover_gen        4967
# generator_id           4967
# gen_code               4967
# gen_boiler_code_2_x    4967
# gen_boiler_code        8249
# plant_id_boiler        5785
# boiler_id              5785
# prime_mover_boiler     5785
# boiler_code            5785
# gen_boiler_code_2_y    5785
# mapped                 8249
# dtype: int64

# %%
mapped_gen_boiler = gen_boiler_map[gen_boiler_map['mapped'] == True]
unmapped_gen_boiler = gen_boiler_map[gen_boiler_map['mapped'] == False]

# %%
mapped_gen_boiler.dtypes
# Out:
# plant_id_gen           float64
# prime_mover_gen         object
# generator_id            object
# gen_code                object
# gen_boiler_code_2_x     object
# gen_boiler_code         object
# plant_id_boiler        float64
# boiler_id               object
# prime_mover_boiler      object
# boiler_code             object
# gen_boiler_code_2_y     object
# mapped                    bool
# dtype: object

# %%
unmapped_gen = unmapped_gen_boiler[['plant_id_gen','prime_mover_gen','generator_id','gen_code','gen_boiler_code_2_x']].copy()
unmapped_gen.dropna(inplace=True)
unmapped_gen = unmapped_gen.rename(columns={'gen_boiler_code_2_x': 'gen_boiler_code_2'})
unmapped_gen
# Out:
#       plant_id_gen prime_mover_gen generator_id        gen_code  \
# 5              3.0              CA         A1ST       3_A1ST_CA
# 6              3.0              CA         A2ST       3_A2ST_CA
# 20            26.0              ST          ST4       26_ST4_ST
# 44           108.0              ST            1        108_1_ST
# 51           117.0              CA         C4-2     117_C4-2_CA
# 52           117.0              CA         C5-3     117_C5-3_CA
# 55           120.0              ST          ST1      120_ST1_ST
# 57           126.0              ST          ST1      126_ST1_ST
# 58           126.0              ST          ST2      126_ST2_ST
# 59           126.0              ST          ST3      126_ST3_ST
# 67           141.0              ST          AF1      141_AF1_ST
# 68           141.0              ST          AF2      141_AF2_ST
# 69           141.0              ST          AF3      141_AF3_ST
# 70           147.0              ST          KY1      147_KY1_ST
# 71           147.0              ST          KY2      147_KY2_ST
# 72           147.0              CA         KY7A     147_KY7A_CA
# 73           160.0              CA          ST1      160_ST1_CA
# 74           160.0              ST          ST2      160_ST2_ST
# 75           160.0              ST          ST3      160_ST3_ST
# 89           173.0              ST            2        173_2_ST
# 90           201.0              CA            1        201_1_CA
# 95           228.0              ST            6        228_6_ST
# 96           228.0              ST            7        228_7_ST
# 97           246.0              ST          ST1      246_ST1_ST
# 98           246.0              ST          ST2      246_ST2_ST
# 99           259.0              ST            1        259_1_ST
# 100          259.0              ST            2        259_2_ST
# 103          260.0              ST            6        260_6_ST
# 104          260.0              ST            7        260_7_ST
# 108          273.0              ST            3        273_3_ST
# ...            ...             ...          ...             ...
# 4894        6474.0              ST          ST1     6474_ST1_ST
# 4896       10025.0              ST         75TG   10025_75TG_ST
# 4897       10486.0              ST        GEN 6  10486_GEN 6_ST
# 4902       10761.0              CA         GEN7   10761_GEN7_CA
# 4903       10761.0              CA         GEN8   10761_GEN8_CA
# 4906       10789.0              CA         ST1A   10789_ST1A_CA
# 4907       50465.0              ST         GEN2   50465_GEN2_ST
# 4909       54335.0              ST         GEN2   54335_GEN2_ST
# 4912       55183.0              CA          ST1    55183_ST1_CA
# 4913       55183.0              CA          ST2    55183_ST2_CA
# 4914       55939.0              CT         CT01   55939_CT01_CT
# 4915       55939.0              CT         CT02   55939_CT02_CT
# 4916       55939.0              CT         CT03   55939_CT03_CT
# 4917       55939.0              CA         ST01   55939_ST01_CA
# 4919       57349.0              CA         STG2   57349_STG2_CA
# 4922       57839.0              CA        ST001  57839_ST001_CA
# 4923       57898.0              ST         GEN2   57898_GEN2_ST
# 4926       58001.0              CA        STG-2  58001_STG-2_CA
# 4929       58079.0              CA        STG-1  58079_STG-1_CA
# 4930       58207.0              CA          G12    58207_G12_CA
# 4933       59658.0              ST         GEN1   59658_GEN1_ST
# 4934       60084.0              ST          TG1    60084_TG1_ST
# 4935       60084.0              ST          TG2    60084_TG2_ST
# 4936       60084.0              ST          TG3    60084_TG3_ST
# 4937       60100.0              ST          G-1    60100_G-1_ST
# 4945        1239.0              CA         12-2    1239_12-2_CA
# 4950       50561.0              CA         STG2   50561_STG2_CA
# 4953       57759.0              ST         STG1   57759_STG1_ST
# 4957       58260.0              CA         ST01   58260_ST01_CA
# 4966       60768.0              CA         ST10   60768_ST10_CA
#
#      gen_boiler_code_2
# 5                 3_CA
# 6                 3_CA
# 20               26_ST
# 44              108_ST
# 51              117_CA
# 52              117_CA
# 55              120_ST
# 57              126_ST
# 58              126_ST
# 59              126_ST
# 67              141_ST
# 68              141_ST
# 69              141_ST
# 70              147_ST
# 71              147_ST
# 72              147_CA
# 73              160_CA
# 74              160_ST
# 75              160_ST
# 89              173_ST
# 90              201_CA
# 95              228_ST
# 96              228_ST
# 97              246_ST
# 98              246_ST
# 99              259_ST
# 100             259_ST
# 103             260_ST
# 104             260_ST
# 108             273_ST
# ...                ...
# 4894           6474_ST
# 4896          10025_ST
# 4897          10486_ST
# 4902          10761_CA
# 4903          10761_CA
# 4906          10789_CA
# 4907          50465_ST
# 4909          54335_ST
# 4912          55183_CA
# 4913          55183_CA
# 4914          55939_CT
# 4915          55939_CT
# 4916          55939_CT
# 4917          55939_CA
# 4919          57349_CA
# 4922          57839_CA
# 4923          57898_ST
# 4926          58001_CA
# 4929          58079_CA
# 4930          58207_CA
# 4933          59658_ST
# 4934          60084_ST
# 4935          60084_ST
# 4936          60084_ST
# 4937          60100_ST
# 4945           1239_CA
# 4950          50561_CA
# 4953          57759_ST
# 4957          58260_CA
# 4966          60768_CA
#
# [2464 rows x 5 columns]

# %%
unmapped_boiler = unmapped_gen_boiler[['plant_id_boiler','boiler_id','prime_mover_boiler','boiler_code','gen_boiler_code_2_y']].copy()
unmapped_boiler.dropna(inplace=True)
unmapped_boiler = unmapped_boiler.rename(columns={'gen_boiler_code_2_y': 'gen_boiler_code_2'})
unmapped_boiler
# Out:
#       plant_id_boiler boiler_id prime_mover_boiler      boiler_code  \
# 4967              3.0        6A                 CA          3_6A_CA
# 4968              3.0        6B                 CA          3_6B_CA
# 4969              3.0        7A                 CA          3_7A_CA
# 4970              3.0        7B                 CA          3_7B_CA
# 4971             26.0         4                 ST          26_4_ST
# 4972             79.0         3                 ST          79_3_ST
# 4973            108.0      SGU1                 ST      108_SGU1_ST
# 4974            117.0       CC4                 CA       117_CC4_CA
# 4975            117.0      CC5A                 CA      117_CC5A_CA
# 4976            117.0      CC5B                 CA      117_CC5B_CA
# 4977            120.0         1                 ST         120_1_ST
# 4978            126.0         1                 ST         126_1_ST
# 4979            126.0         2                 ST         126_2_ST
# 4980            126.0         3                 ST         126_3_ST
# 4981            141.0         1                 ST         141_1_ST
# 4982            141.0         2                 ST         141_2_ST
# 4983            141.0         3                 ST         141_3_ST
# 4984            147.0       K-1                 ST       147_K-1_ST
# 4985            147.0       K-2                 ST       147_K-2_ST
# 4986            147.0       K-7                 CA       147_K-7_CA
# 4987            160.0         1                 CA         160_1_CA
# 4988            160.0         2                 ST         160_2_ST
# 4989            160.0         3                 ST         160_3_ST
# 4990            201.0         2                 CA         201_2_CA
# 4991            202.0        01                 ST        202_01_ST
# 4992            203.0        01                 ST        203_01_ST
# 4993            228.0        10                 ST        228_10_ST
# 4994            228.0         9                 ST         228_9_ST
# 4995            246.0         1                 ST         246_1_ST
# 4996            246.0         2                 ST         246_2_ST
# ...               ...       ...                ...              ...
# 8219          57898.0      BLR5                 ST    57898_BLR5_ST
# 8220          57914.0       CE1                 ST     57914_CE1_ST
# 8221          57914.0       CE2                 ST     57914_CE2_ST
# 8222          57914.0       UI3                 ST     57914_UI3_ST
# 8223          57914.0       UI4                 ST     57914_UI4_ST
# 8224          58001.0     HRSG3                 CA   58001_HRSG3_CA
# 8225          58001.0     HRSG4                 CA   58001_HRSG4_CA
# 8226          58079.0    HRSG-1                 CA  58079_HRSG-1_CA
# 8227          58079.0    HRSG-2                 CA  58079_HRSG-2_CA
# 8228          58207.0     HRSG7                 CA   58207_HRSG7_CA
# 8229          58207.0     HRSG8                 CA   58207_HRSG8_CA
# 8230          59658.0      BLR1                 ST    59658_BLR1_ST
# 8231          60084.0      1005                 ST    60084_1005_ST
# 8232          60084.0      1006                 ST    60084_1006_ST
# 8233          60084.0     7020A                 ST   60084_7020A_ST
# 8234          60084.0      7040                 ST    60084_7040_ST
# 8235          60100.0       B-1                 ST     60100_B-1_ST
# 8236           1239.0     HSG12                 CA    1239_HSG12_CA
# 8237          10560.0     POWB4                 ST   10560_POWB4_ST
# 8238          10560.0     POWB5                 ST   10560_POWB5_ST
# 8239          57759.0       3PB                 ST     57759_3PB_ST
# 8240          57759.0       4RF                 ST     57759_4RF_ST
# 8241          57759.0       5PB                 ST     57759_5PB_ST
# 8242          58260.0    HRSG1A                 CA  58260_HRSG1A_CA
# 8243          58260.0    HRSG1B                 CA  58260_HRSG1B_CA
# 8244          58260.0    HRSG1C                 CA  58260_HRSG1C_CA
# 8245          58426.0     HRSG1                 CS   58426_HRSG1_CS
# 8246          58426.0     HRSG2                 CS   58426_HRSG2_CS
# 8247          60768.0       2 A                 CA     60768_2 A_CA
# 8248          60768.0       2 B                 CA     60768_2 B_CA
#
#      gen_boiler_code_2
# 4967              3_CA
# 4968              3_CA
# 4969              3_CA
# 4970              3_CA
# 4971             26_ST
# 4972             79_ST
# 4973            108_ST
# 4974            117_CA
# 4975            117_CA
# 4976            117_CA
# 4977            120_ST
# 4978            126_ST
# 4979            126_ST
# 4980            126_ST
# 4981            141_ST
# 4982            141_ST
# 4983            141_ST
# 4984            147_ST
# 4985            147_ST
# 4986            147_CA
# 4987            160_CA
# 4988            160_ST
# 4989            160_ST
# 4990            201_CA
# 4991            202_ST
# 4992            203_ST
# 4993            228_ST
# 4994            228_ST
# 4995            246_ST
# 4996            246_ST
# ...                ...
# 8219          57898_ST
# 8220          57914_ST
# 8221          57914_ST
# 8222          57914_ST
# 8223          57914_ST
# 8224          58001_CA
# 8225          58001_CA
# 8226          58079_CA
# 8227          58079_CA
# 8228          58207_CA
# 8229          58207_CA
# 8230          59658_ST
# 8231          60084_ST
# 8232          60084_ST
# 8233          60084_ST
# 8234          60084_ST
# 8235          60100_ST
# 8236           1239_CA
# 8237          10560_ST
# 8238          10560_ST
# 8239          57759_ST
# 8240          57759_ST
# 8241          57759_ST
# 8242          58260_CA
# 8243          58260_CA
# 8244          58260_CA
# 8245          58426_CS
# 8246          58426_CS
# 8247          60768_CA
# 8248          60768_CA
#
# [3282 rows x 5 columns]

# %%
gen_boiler_map_2 = pd.merge(unmapped_gen, unmapped_boiler, how='outer', on=['gen_boiler_code_2'])
gen_boiler_map_2['mapped'] = (gen_boiler_map_2['plant_id_gen'].notnull() & 
                              gen_boiler_map_2['plant_id_boiler'].notnull() &
                              ~gen_boiler_map_2.duplicated(subset='gen_boiler_code_2',keep=False))
#gen_boiler_map_2
mapped_gen_boiler_2 = gen_boiler_map_2[gen_boiler_map_2['mapped'] == True]
unmapped_gen_boiler_2 = gen_boiler_map_2[gen_boiler_map_2['mapped'] == False]

# %%
mapped_gen_boiler = mapped_gen_boiler.append(mapped_gen_boiler_2)
mapped_gen_boiler
# Out:
#           boiler_code boiler_id gen_boiler_code gen_boiler_code_2  \
# 0              3_1_ST         1          3_1_ST               NaN
# 1              3_2_ST         2          3_2_ST               NaN
# 2              3_3_ST         3          3_3_ST               NaN
# 3              3_4_ST         4          3_4_ST               NaN
# 4              3_5_ST         5          3_5_ST               NaN
# 7              7_1_ST         1          7_1_ST               NaN
# 8              7_2_ST         2          7_2_ST               NaN
# 9             8_10_ST        10         8_10_ST               NaN
# 10             8_6_ST         6          8_6_ST               NaN
# 11             8_7_ST         7          8_7_ST               NaN
# 12             8_8_ST         8          8_8_ST               NaN
# 13             8_9_ST         9          8_9_ST               NaN
# 14            10_1_ST         1         10_1_ST               NaN
# 15            10_2_ST         2         10_2_ST               NaN
# 16            26_1_ST         1         26_1_ST               NaN
# 17            26_2_ST         2         26_2_ST               NaN
# 18            26_3_ST         3         26_3_ST               NaN
# 19            26_5_ST         5         26_5_ST               NaN
# 21            47_1_ST         1         47_1_ST               NaN
# 22            47_2_ST         2         47_2_ST               NaN
# 23            47_3_ST         3         47_3_ST               NaN
# 24            47_4_ST         4         47_4_ST               NaN
# 25            47_5_ST         5         47_5_ST               NaN
# 26            50_1_ST         1         50_1_ST               NaN
# 27            50_2_ST         2         50_2_ST               NaN
# 28            50_3_ST         3         50_3_ST               NaN
# 29            50_4_ST         4         50_4_ST               NaN
# 30            50_5_ST         5         50_5_ST               NaN
# 31            50_6_ST         6         50_6_ST               NaN
# 32            50_7_ST         7         50_7_ST               NaN
# ...               ...       ...             ...               ...
# 7165     58310_B-1_ST       B-1             NaN          58310_ST
# 7190  10030_DOVCC1_CA    DOVCC1             NaN          10030_CA
# 7225    10319_HRSG_ST      HRSG             NaN          10319_ST
# 7246      10697_RB_ST        RB             NaN          10697_ST
# 7389    55966_HRSG_CA      HRSG             NaN          55966_CA
# 7412       57103_2_ST         2             NaN          57103_ST
# 7414    57241_BLR1_ST      BLR1             NaN          57241_ST
# 7421       57684_1_ST         1             NaN          57684_ST
# 7430    57909_BLR1_ST      BLR1             NaN          57909_ST
# 7459    58083_HRSG_CA      HRSG             NaN          58083_CA
# 7460   58084_HRSG1_CA     HRSG1             NaN          58084_CA
# 7472   58198_HRSG1_CA     HRSG1             NaN          58198_CA
# 7477    58352_B-11_ST      B-11             NaN          58352_ST
# 7483    58560_BLR1_ST      BLR1             NaN          58560_ST
# 7484      58595_B1_ST        B1             NaN          58595_ST
# 7485    58613_2000_ST      2000             NaN          58613_ST
# 7490    58706_B001_ST      B001             NaN          58706_ST
# 7491    58707_B001_ST      B001             NaN          58707_ST
# 7495   59254_HRSG1_CA     HRSG1             NaN          59254_CA
# 7527         609_3_CA         3             NaN            609_CA
# 7534         619_1_CA         1             NaN            619_CA
# 7604       55210_3_CT         3             NaN          55210_CT
# 7621    57073_BLR1_ST      BLR1             NaN          57073_ST
# 7622    57074_BLR1_ST      BLR1             NaN          57074_ST
# 7623    57075_BLR1_ST      BLR1             NaN          57075_ST
# 7638    58944_2771_ST      2771             NaN          58944_ST
# 7669   57349_HRSG1_CA     HRSG1             NaN          57349_CA
# 7679    59658_BLR1_ST      BLR1             NaN          59658_ST
# 7692     60100_B-1_ST       B-1             NaN          60100_ST
# 7693    1239_HSG12_CA     HSG12             NaN           1239_CA
#
#      gen_boiler_code_2_x gen_boiler_code_2_y        gen_code generator_id  \
# 0                   3_ST                3_ST          3_1_ST            1
# 1                   3_ST                3_ST          3_2_ST            2
# 2                   3_ST                3_ST          3_3_ST            3
# 3                   3_ST                3_ST          3_4_ST            4
# 4                   3_ST                3_ST          3_5_ST            5
# 7                   7_ST                7_ST          7_1_ST            1
# 8                   7_ST                7_ST          7_2_ST            2
# 9                   8_ST                8_ST         8_10_ST           10
# 10                  8_ST                8_ST          8_6_ST            6
# 11                  8_ST                8_ST          8_7_ST            7
# 12                  8_ST                8_ST          8_8_ST            8
# 13                  8_ST                8_ST          8_9_ST            9
# 14                 10_ST               10_ST         10_1_ST            1
# 15                 10_ST               10_ST         10_2_ST            2
# 16                 26_ST               26_ST         26_1_ST            1
# 17                 26_ST               26_ST         26_2_ST            2
# 18                 26_ST               26_ST         26_3_ST            3
# 19                 26_ST               26_ST         26_5_ST            5
# 21                 47_ST               47_ST         47_1_ST            1
# 22                 47_ST               47_ST         47_2_ST            2
# 23                 47_ST               47_ST         47_3_ST            3
# 24                 47_ST               47_ST         47_4_ST            4
# 25                 47_ST               47_ST         47_5_ST            5
# 26                 50_ST               50_ST         50_1_ST            1
# 27                 50_ST               50_ST         50_2_ST            2
# 28                 50_ST               50_ST         50_3_ST            3
# 29                 50_ST               50_ST         50_4_ST            4
# 30                 50_ST               50_ST         50_5_ST            5
# 31                 50_ST               50_ST         50_6_ST            6
# 32                 50_ST               50_ST         50_7_ST            7
# ...                  ...                 ...             ...          ...
# 7165                 NaN                 NaN    58310_G-1_ST          G-1
# 7190                 NaN                 NaN   10030_COG1_CA         COG1
# 7225                 NaN                 NaN   10319_GEN3_ST         GEN3
# 7246                 NaN                 NaN   10697_GEN2_ST         GEN2
# 7389                 NaN                 NaN    55966_ST1_CA          ST1
# 7412                 NaN                 NaN      57103_1_ST            1
# 7414                 NaN                 NaN      57241_1_ST            1
# 7421                 NaN                 NaN    57684_HR1_ST          HR1
# 7430                 NaN                 NaN   57909_GEN1_ST         GEN1
# 7459                 NaN                 NaN   58083_STG1_CA         STG1
# 7460                 NaN                 NaN  58084_GT300_CA        GT300
# 7472                 NaN                 NaN   58198_STG1_CA         STG1
# 7477                 NaN                 NaN   58352_G-11_ST         G-11
# 7483                 NaN                 NaN   58560_STG1_ST         STG1
# 7484                 NaN                 NaN   58595_GEN1_ST         GEN1
# 7485                 NaN                 NaN    58613_STG_ST          STG
# 7490                 NaN                 NaN   58706_GEN1_ST         GEN1
# 7491                 NaN                 NaN   58707_GEN1_ST         GEN1
# 7495                 NaN                 NaN  59254_GENS1_CA        GENS1
# 7527                 NaN                 NaN      609_3ST_CA          3ST
# 7534                 NaN                 NaN      619_5ST_CA          5ST
# 7604                 NaN                 NaN      55210_1_CT            1
# 7621                 NaN                 NaN    57073_ST1_ST          ST1
# 7622                 NaN                 NaN    57074_ST1_ST          ST1
# 7623                 NaN                 NaN    57075_ST1_ST          ST1
# 7638                 NaN                 NaN     58944_G1_ST           G1
# 7669                 NaN                 NaN   57349_STG2_CA         STG2
# 7679                 NaN                 NaN   59658_GEN1_ST         GEN1
# 7692                 NaN                 NaN    60100_G-1_ST          G-1
# 7693                 NaN                 NaN    1239_12-2_CA         12-2
#
#      mapped  plant_id_boiler  plant_id_gen prime_mover_boiler prime_mover_gen
# 0      True              3.0           3.0                 ST              ST
# 1      True              3.0           3.0                 ST              ST
# 2      True              3.0           3.0                 ST              ST
# 3      True              3.0           3.0                 ST              ST
# 4      True              3.0           3.0                 ST              ST
# 7      True              7.0           7.0                 ST              ST
# 8      True              7.0           7.0                 ST              ST
# 9      True              8.0           8.0                 ST              ST
# 10     True              8.0           8.0                 ST              ST
# 11     True              8.0           8.0                 ST              ST
# 12     True              8.0           8.0                 ST              ST
# 13     True              8.0           8.0                 ST              ST
# 14     True             10.0          10.0                 ST              ST
# 15     True             10.0          10.0                 ST              ST
# 16     True             26.0          26.0                 ST              ST
# 17     True             26.0          26.0                 ST              ST
# 18     True             26.0          26.0                 ST              ST
# 19     True             26.0          26.0                 ST              ST
# 21     True             47.0          47.0                 ST              ST
# 22     True             47.0          47.0                 ST              ST
# 23     True             47.0          47.0                 ST              ST
# 24     True             47.0          47.0                 ST              ST
# 25     True             47.0          47.0                 ST              ST
# 26     True             50.0          50.0                 ST              ST
# 27     True             50.0          50.0                 ST              ST
# 28     True             50.0          50.0                 ST              ST
# 29     True             50.0          50.0                 ST              ST
# 30     True             50.0          50.0                 ST              ST
# 31     True             50.0          50.0                 ST              ST
# 32     True             50.0          50.0                 ST              ST
# ...     ...              ...           ...                ...             ...
# 7165   True          58310.0       58310.0                 ST              ST
# 7190   True          10030.0       10030.0                 CA              CA
# 7225   True          10319.0       10319.0                 ST              ST
# 7246   True          10697.0       10697.0                 ST              ST
# 7389   True          55966.0       55966.0                 CA              CA
# 7412   True          57103.0       57103.0                 ST              ST
# 7414   True          57241.0       57241.0                 ST              ST
# 7421   True          57684.0       57684.0                 ST              ST
# 7430   True          57909.0       57909.0                 ST              ST
# 7459   True          58083.0       58083.0                 CA              CA
# 7460   True          58084.0       58084.0                 CA              CA
# 7472   True          58198.0       58198.0                 CA              CA
# 7477   True          58352.0       58352.0                 ST              ST
# 7483   True          58560.0       58560.0                 ST              ST
# 7484   True          58595.0       58595.0                 ST              ST
# 7485   True          58613.0       58613.0                 ST              ST
# 7490   True          58706.0       58706.0                 ST              ST
# 7491   True          58707.0       58707.0                 ST              ST
# 7495   True          59254.0       59254.0                 CA              CA
# 7527   True            609.0         609.0                 CA              CA
# 7534   True            619.0         619.0                 CA              CA
# 7604   True          55210.0       55210.0                 CT              CT
# 7621   True          57073.0       57073.0                 ST              ST
# 7622   True          57074.0       57074.0                 ST              ST
# 7623   True          57075.0       57075.0                 ST              ST
# 7638   True          58944.0       58944.0                 ST              ST
# 7669   True          57349.0       57349.0                 CA              CA
# 7679   True          59658.0       59658.0                 ST              ST
# 7692   True          60100.0       60100.0                 ST              ST
# 7693   True           1239.0        1239.0                 CA              CA
#
# [2828 rows x 13 columns]

# %%
unmapped_gen_2 = unmapped_gen.merge(gen_boiler_map_2[['plant_id_gen',
                                     'prime_mover_gen',
                                     'generator_id',
                                     'gen_code',
                                     'gen_boiler_code_2',
                                     'mapped']],
                   on=['plant_id_gen',
                       'prime_mover_gen',
                       'generator_id',
                       'gen_code',
                       'gen_boiler_code_2'])
unmapped_gen_2 = unmapped_gen_2[unmapped_gen_2['mapped'] == False].drop_duplicates()
unmapped_gen_2.dtypes
# Out:
# plant_id_gen         float64
# prime_mover_gen       object
# generator_id          object
# gen_code              object
# gen_boiler_code_2     object
# mapped                  bool
# dtype: object

# %%
unmapped_boiler_2 = unmapped_boiler.merge(gen_boiler_map_2[['plant_id_boiler',
                                                            'boiler_id',
                                                            'prime_mover_boiler',
                                                            'boiler_code',
                                                            'gen_boiler_code_2',
                                                            'mapped']],
                   on=['plant_id_boiler',
                        'boiler_id',
                        'prime_mover_boiler',
                        'boiler_code',
                        'gen_boiler_code_2'])
unmapped_boiler_2 = unmapped_boiler_2[unmapped_boiler_2['mapped'] == False].drop_duplicates()
unmapped_boiler_2
# Out:
#       plant_id_boiler boiler_id prime_mover_boiler      boiler_code  \
# 4967              3.0        6A                 CA          3_6A_CA
# 4968              3.0        6B                 CA          3_6B_CA
# 4969              3.0        7A                 CA          3_7A_CA
# 4970              3.0        7B                 CA          3_7B_CA
# 4971             26.0         4                 ST          26_4_ST
# 4972             79.0         3                 ST          79_3_ST
# 4973            108.0      SGU1                 ST      108_SGU1_ST
# 4974            117.0       CC4                 CA       117_CC4_CA
# 4975            117.0      CC5A                 CA      117_CC5A_CA
# 4976            117.0      CC5B                 CA      117_CC5B_CA
# 4977            120.0         1                 ST         120_1_ST
# 4978            126.0         1                 ST         126_1_ST
# 4979            126.0         2                 ST         126_2_ST
# 4980            126.0         3                 ST         126_3_ST
# 4981            141.0         1                 ST         141_1_ST
# 4982            141.0         2                 ST         141_2_ST
# 4983            141.0         3                 ST         141_3_ST
# 4984            147.0       K-1                 ST       147_K-1_ST
# 4985            147.0       K-2                 ST       147_K-2_ST
# 4986            147.0       K-7                 CA       147_K-7_CA
# 4987            160.0         1                 CA         160_1_CA
# 4988            160.0         2                 ST         160_2_ST
# 4989            160.0         3                 ST         160_3_ST
# 4990            201.0         2                 CA         201_2_CA
# 4991            202.0        01                 ST        202_01_ST
# 4992            203.0        01                 ST        203_01_ST
# 4993            228.0        10                 ST        228_10_ST
# 4994            228.0         9                 ST         228_9_ST
# 4995            246.0         1                 ST         246_1_ST
# 4996            246.0         2                 ST         246_2_ST
# ...               ...       ...                ...              ...
# 8219          57898.0      BLR5                 ST    57898_BLR5_ST
# 8220          57914.0       CE1                 ST     57914_CE1_ST
# 8221          57914.0       CE2                 ST     57914_CE2_ST
# 8222          57914.0       UI3                 ST     57914_UI3_ST
# 8223          57914.0       UI4                 ST     57914_UI4_ST
# 8224          58001.0     HRSG3                 CA   58001_HRSG3_CA
# 8225          58001.0     HRSG4                 CA   58001_HRSG4_CA
# 8226          58079.0    HRSG-1                 CA  58079_HRSG-1_CA
# 8227          58079.0    HRSG-2                 CA  58079_HRSG-2_CA
# 8228          58207.0     HRSG7                 CA   58207_HRSG7_CA
# 8229          58207.0     HRSG8                 CA   58207_HRSG8_CA
# 8230          59658.0      BLR1                 ST    59658_BLR1_ST
# 8231          60084.0      1005                 ST    60084_1005_ST
# 8232          60084.0      1006                 ST    60084_1006_ST
# 8233          60084.0     7020A                 ST   60084_7020A_ST
# 8234          60084.0      7040                 ST    60084_7040_ST
# 8235          60100.0       B-1                 ST     60100_B-1_ST
# 8236           1239.0     HSG12                 CA    1239_HSG12_CA
# 8237          10560.0     POWB4                 ST   10560_POWB4_ST
# 8238          10560.0     POWB5                 ST   10560_POWB5_ST
# 8239          57759.0       3PB                 ST     57759_3PB_ST
# 8240          57759.0       4RF                 ST     57759_4RF_ST
# 8241          57759.0       5PB                 ST     57759_5PB_ST
# 8242          58260.0    HRSG1A                 CA  58260_HRSG1A_CA
# 8243          58260.0    HRSG1B                 CA  58260_HRSG1B_CA
# 8244          58260.0    HRSG1C                 CA  58260_HRSG1C_CA
# 8245          58426.0     HRSG1                 CS   58426_HRSG1_CS
# 8246          58426.0     HRSG2                 CS   58426_HRSG2_CS
# 8247          60768.0       2 A                 CA     60768_2 A_CA
# 8248          60768.0       2 B                 CA     60768_2 B_CA
#
#      gen_boiler_code_2
# 4967              3_CA
# 4968              3_CA
# 4969              3_CA
# 4970              3_CA
# 4971             26_ST
# 4972             79_ST
# 4973            108_ST
# 4974            117_CA
# 4975            117_CA
# 4976            117_CA
# 4977            120_ST
# 4978            126_ST
# 4979            126_ST
# 4980            126_ST
# 4981            141_ST
# 4982            141_ST
# 4983            141_ST
# 4984            147_ST
# 4985            147_ST
# 4986            147_CA
# 4987            160_CA
# 4988            160_ST
# 4989            160_ST
# 4990            201_CA
# 4991            202_ST
# 4992            203_ST
# 4993            228_ST
# 4994            228_ST
# 4995            246_ST
# 4996            246_ST
# ...                ...
# 8219          57898_ST
# 8220          57914_ST
# 8221          57914_ST
# 8222          57914_ST
# 8223          57914_ST
# 8224          58001_CA
# 8225          58001_CA
# 8226          58079_CA
# 8227          58079_CA
# 8228          58207_CA
# 8229          58207_CA
# 8230          59658_ST
# 8231          60084_ST
# 8232          60084_ST
# 8233          60084_ST
# 8234          60084_ST
# 8235          60100_ST
# 8236           1239_CA
# 8237          10560_ST
# 8238          10560_ST
# 8239          57759_ST
# 8240          57759_ST
# 8241          57759_ST
# 8242          58260_CA
# 8243          58260_CA
# 8244          58260_CA
# 8245          58426_CS
# 8246          58426_CS
# 8247          60768_CA
# 8248          60768_CA
#
# [3282 rows x 5 columns]

# %%
# either boiler codes or generator codes include ST/CC/ boiler: FB
#

# %%
unmapped_gen_2['generator_id_stripped'] = unmapped_gen_2['generator_id']
unmapped_gen_2['generator_id_stripped'] = unmapped_gen_2['generator_id'].str.strip('STCTGENCCKABCLIMBLRHRSGUIPOWPBRF-')
unmapped_gen_2['plant_id_gen'] = unmapped_gen_2['plant_id_gen'].astype(np.int64)

unmapped_gen_2['gen_boiler_code_3'] = unmapped_gen_2['plant_id_gen'].map(str) + "_" +\
                                      unmapped_gen_2['generator_id_stripped'] + "_" +\
                                      unmapped_gen_2['prime_mover_gen']

# %%
unmapped_gen_2
# Out:
#       plant_id_gen prime_mover_gen generator_id        gen_code  \
# 0                3              CA         A1ST       3_A1ST_CA
# 4                3              CA         A2ST       3_A2ST_CA
# 10             117              CA         C4-2     117_C4-2_CA
# 13             117              CA         C5-3     117_C5-3_CA
# 17             126              ST          ST1      126_ST1_ST
# 20             126              ST          ST2      126_ST2_ST
# 23             126              ST          ST3      126_ST3_ST
# 26             141              ST          AF1      141_AF1_ST
# 29             141              ST          AF2      141_AF2_ST
# 32             141              ST          AF3      141_AF3_ST
# 35             147              ST          KY1      147_KY1_ST
# 37             147              ST          KY2      147_KY2_ST
# 41             160              ST          ST2      160_ST2_ST
# 43             160              ST          ST3      160_ST3_ST
# 45             173              ST            2        173_2_ST
# 47             228              ST            6        228_6_ST
# 49             228              ST            7        228_7_ST
# 51             246              ST          ST1      246_ST1_ST
# 53             246              ST          ST2      246_ST2_ST
# 55             259              ST            1        259_1_ST
# 56             259              ST            2        259_2_ST
# 57             260              ST            6        260_6_ST
# 59             260              ST            7        260_7_ST
# 62             298              ST            1        298_1_ST
# 64             298              ST            2        298_2_ST
# 68             329              CA           30       329_30_CA
# 72             329              CA           40       329_40_CA
# 76             335              ST            3        335_3_ST
# 78             335              ST            4        335_4_ST
# 80             358              CA         MV3C     358_MV3C_CA
# ...            ...             ...          ...             ...
# 7614          1363              CA           7S      1363_7S_CA
# 7615          4937              CT         CT-1    4937_CT-1_CT
# 7616          4937              CT         CT-2    4937_CT-2_CT
# 7617          4937              CA          STG     4937_STG_CA
# 7619          6474              ST          ST1     6474_ST1_ST
# 7620         10025              ST         75TG   10025_75TG_ST
# 7631         10486              ST        GEN 6  10486_GEN 6_ST
# 7635         10761              CA         GEN7   10761_GEN7_CA
# 7639         10761              CA         GEN8   10761_GEN8_CA
# 7643         10789              CA         ST1A   10789_ST1A_CA
# 7646         50465              ST         GEN2   50465_GEN2_ST
# 7648         54335              ST         GEN2   54335_GEN2_ST
# 7651         55183              CA          ST1    55183_ST1_CA
# 7653         55183              CA          ST2    55183_ST2_CA
# 7655         55939              CT         CT01   55939_CT01_CT
# 7656         55939              CT         CT02   55939_CT02_CT
# 7657         55939              CT         CT03   55939_CT03_CT
# 7658         55939              CA         ST01   55939_ST01_CA
# 7662         57839              CA        ST001  57839_ST001_CA
# 7664         57898              ST         GEN2   57898_GEN2_ST
# 7667         58001              CA        STG-2  58001_STG-2_CA
# 7671         58079              CA        STG-1  58079_STG-1_CA
# 7673         58207              CA          G12    58207_G12_CA
# 7676         60084              ST          TG1    60084_TG1_ST
# 7680         60084              ST          TG2    60084_TG2_ST
# 7684         60084              ST          TG3    60084_TG3_ST
# 7690         50561              CA         STG2   50561_STG2_CA
# 7694         57759              ST         STG1   57759_STG1_ST
# 7697         58260              CA         ST01   58260_ST01_CA
# 7700         60768              CA         ST10   60768_ST10_CA
#
#      gen_boiler_code_2 mapped generator_id_stripped gen_boiler_code_3
# 0                 3_CA  False                     1            3_1_CA
# 4                 3_CA  False                     2            3_2_CA
# 10              117_CA  False                   4-2        117_4-2_CA
# 13              117_CA  False                   5-3        117_5-3_CA
# 17              126_ST  False                     1          126_1_ST
# 20              126_ST  False                     2          126_2_ST
# 23              126_ST  False                     3          126_3_ST
# 26              141_ST  False                     1          141_1_ST
# 29              141_ST  False                     2          141_2_ST
# 32              141_ST  False                     3          141_3_ST
# 35              147_ST  False                    Y1         147_Y1_ST
# 37              147_ST  False                    Y2         147_Y2_ST
# 41              160_ST  False                     2          160_2_ST
# 43              160_ST  False                     3          160_3_ST
# 45              173_ST  False                     2          173_2_ST
# 47              228_ST  False                     6          228_6_ST
# 49              228_ST  False                     7          228_7_ST
# 51              246_ST  False                     1          246_1_ST
# 53              246_ST  False                     2          246_2_ST
# 55              259_ST  False                     1          259_1_ST
# 56              259_ST  False                     2          259_2_ST
# 57              260_ST  False                     6          260_6_ST
# 59              260_ST  False                     7          260_7_ST
# 62              298_ST  False                     1          298_1_ST
# 64              298_ST  False                     2          298_2_ST
# 68              329_CA  False                    30         329_30_CA
# 72              329_CA  False                    40         329_40_CA
# 76              335_ST  False                     3          335_3_ST
# 78              335_ST  False                     4          335_4_ST
# 80              358_CA  False                    V3         358_V3_CA
# ...                ...    ...                   ...               ...
# 7614           1363_CA  False                     7         1363_7_CA
# 7615           4937_CT  False                     1         4937_1_CT
# 7616           4937_CT  False                     2         4937_2_CT
# 7617           4937_CA  False                                4937__CA
# 7619           6474_ST  False                     1         6474_1_ST
# 7620          10025_ST  False                    75       10025_75_ST
# 7631          10486_ST  False                     6       10486_ 6_ST
# 7635          10761_CA  False                     7        10761_7_CA
# 7639          10761_CA  False                     8        10761_8_CA
# 7643          10789_CA  False                     1        10789_1_CA
# 7646          50465_ST  False                     2        50465_2_ST
# 7648          54335_ST  False                     2        54335_2_ST
# 7651          55183_CA  False                     1        55183_1_CA
# 7653          55183_CA  False                     2        55183_2_CA
# 7655          55939_CT  False                    01       55939_01_CT
# 7656          55939_CT  False                    02       55939_02_CT
# 7657          55939_CT  False                    03       55939_03_CT
# 7658          55939_CA  False                    01       55939_01_CA
# 7662          57839_CA  False                   001      57839_001_CA
# 7664          57898_ST  False                     2        57898_2_ST
# 7667          58001_CA  False                     2        58001_2_CA
# 7671          58079_CA  False                     1        58079_1_CA
# 7673          58207_CA  False                    12       58207_12_CA
# 7676          60084_ST  False                     1        60084_1_ST
# 7680          60084_ST  False                     2        60084_2_ST
# 7684          60084_ST  False                     3        60084_3_ST
# 7690          50561_CA  False                     2        50561_2_CA
# 7694          57759_ST  False                     1        57759_1_ST
# 7697          58260_CA  False                    01       58260_01_CA
# 7700          60768_CA  False                    10       60768_10_CA
#
# [2139 rows x 8 columns]

# %%
unmapped_boiler_2['boiler_id_stripped'] = unmapped_boiler_2['boiler_id']
unmapped_boiler_2['boiler_id_stripped'] = unmapped_boiler_2['boiler_id'].str.strip('STCTGENCCKABCLIMBLRHRSGUIPOWPBRF-')
unmapped_boiler_2['plant_id_boiler'] = unmapped_boiler_2['plant_id_boiler'].astype(np.int64)

unmapped_boiler_2['gen_boiler_code_3'] = unmapped_boiler_2['plant_id_boiler'].map(str) + "_" +\
                                         unmapped_boiler_2['boiler_id_stripped'] + "_" +\
                                         unmapped_boiler_2['prime_mover_boiler']

# %%
unmapped_boiler_2
# Out:
#       plant_id_boiler boiler_id prime_mover_boiler      boiler_code  \
# 0                   3        6A                 CA          3_6A_CA
# 2                   3        6B                 CA          3_6B_CA
# 4                   3        7A                 CA          3_7A_CA
# 6                   3        7B                 CA          3_7B_CA
# 9                  79         3                 ST          79_3_ST
# 11                117       CC4                 CA       117_CC4_CA
# 13                117      CC5A                 CA      117_CC5A_CA
# 15                117      CC5B                 CA      117_CC5B_CA
# 18                126         1                 ST         126_1_ST
# 21                126         2                 ST         126_2_ST
# 24                126         3                 ST         126_3_ST
# 27                141         1                 ST         141_1_ST
# 30                141         2                 ST         141_2_ST
# 33                141         3                 ST         141_3_ST
# 36                147       K-1                 ST       147_K-1_ST
# 38                147       K-2                 ST       147_K-2_ST
# 42                160         2                 ST         160_2_ST
# 45                160         3                 ST         160_3_ST
# 49                202        01                 ST        202_01_ST
# 50                203        01                 ST        203_01_ST
# 51                228        10                 ST        228_10_ST
# 53                228         9                 ST         228_9_ST
# 55                246         1                 ST         246_1_ST
# 57                246         2                 ST         246_2_ST
# 59                260       6-1                 ST       260_6-1_ST
# 61                260       7-1                 ST       260_7-1_ST
# 64                298      LIM1                 ST      298_LIM1_ST
# 66                298      LIM2                 ST      298_LIM2_ST
# 70                329        31                 CA        329_31_CA
# 72                329        32                 CA        329_32_CA
# ...               ...       ...                ...              ...
# 7401            57839    HRSG1B                 CA  57839_HRSG1B_CA
# 7402            57898      BLR3                 ST    57898_BLR3_ST
# 7403            57898      BLR4                 ST    57898_BLR4_ST
# 7404            57898      BLR5                 ST    57898_BLR5_ST
# 7405            57914       CE1                 ST     57914_CE1_ST
# 7407            57914       CE2                 ST     57914_CE2_ST
# 7409            57914       UI3                 ST     57914_UI3_ST
# 7411            57914       UI4                 ST     57914_UI4_ST
# 7413            58001     HRSG3                 CA   58001_HRSG3_CA
# 7415            58001     HRSG4                 CA   58001_HRSG4_CA
# 7417            58079    HRSG-1                 CA  58079_HRSG-1_CA
# 7418            58079    HRSG-2                 CA  58079_HRSG-2_CA
# 7419            58207     HRSG7                 CA   58207_HRSG7_CA
# 7420            58207     HRSG8                 CA   58207_HRSG8_CA
# 7422            60084      1005                 ST    60084_1005_ST
# 7425            60084      1006                 ST    60084_1006_ST
# 7428            60084     7020A                 ST   60084_7020A_ST
# 7431            60084      7040                 ST    60084_7040_ST
# 7436            10560     POWB4                 ST   10560_POWB4_ST
# 7442            10560     POWB5                 ST   10560_POWB5_ST
# 7448            57759       3PB                 ST     57759_3PB_ST
# 7449            57759       4RF                 ST     57759_4RF_ST
# 7450            57759       5PB                 ST     57759_5PB_ST
# 7451            58260    HRSG1A                 CA  58260_HRSG1A_CA
# 7452            58260    HRSG1B                 CA  58260_HRSG1B_CA
# 7453            58260    HRSG1C                 CA  58260_HRSG1C_CA
# 7454            58426     HRSG1                 CS   58426_HRSG1_CS
# 7455            58426     HRSG2                 CS   58426_HRSG2_CS
# 7456            60768       2 A                 CA     60768_2 A_CA
# 7457            60768       2 B                 CA     60768_2 B_CA
#
#      gen_boiler_code_2 mapped boiler_id_stripped gen_boiler_code_3
# 0                 3_CA  False                  6            3_6_CA
# 2                 3_CA  False                  6            3_6_CA
# 4                 3_CA  False                  7            3_7_CA
# 6                 3_CA  False                  7            3_7_CA
# 9                79_ST  False                  3           79_3_ST
# 11              117_CA  False                  4          117_4_CA
# 13              117_CA  False                  5          117_5_CA
# 15              117_CA  False                  5          117_5_CA
# 18              126_ST  False                  1          126_1_ST
# 21              126_ST  False                  2          126_2_ST
# 24              126_ST  False                  3          126_3_ST
# 27              141_ST  False                  1          141_1_ST
# 30              141_ST  False                  2          141_2_ST
# 33              141_ST  False                  3          141_3_ST
# 36              147_ST  False                  1          147_1_ST
# 38              147_ST  False                  2          147_2_ST
# 42              160_ST  False                  2          160_2_ST
# 45              160_ST  False                  3          160_3_ST
# 49              202_ST  False                 01         202_01_ST
# 50              203_ST  False                 01         203_01_ST
# 51              228_ST  False                 10         228_10_ST
# 53              228_ST  False                  9          228_9_ST
# 55              246_ST  False                  1          246_1_ST
# 57              246_ST  False                  2          246_2_ST
# 59              260_ST  False                6-1        260_6-1_ST
# 61              260_ST  False                7-1        260_7-1_ST
# 64              298_ST  False                  1          298_1_ST
# 66              298_ST  False                  2          298_2_ST
# 70              329_CA  False                 31         329_31_CA
# 72              329_CA  False                 32         329_32_CA
# ...                ...    ...                ...               ...
# 7401          57839_CA  False                  1        57839_1_CA
# 7402          57898_ST  False                  3        57898_3_ST
# 7403          57898_ST  False                  4        57898_4_ST
# 7404          57898_ST  False                  5        57898_5_ST
# 7405          57914_ST  False                  1        57914_1_ST
# 7407          57914_ST  False                  2        57914_2_ST
# 7409          57914_ST  False                  3        57914_3_ST
# 7411          57914_ST  False                  4        57914_4_ST
# 7413          58001_CA  False                  3        58001_3_CA
# 7415          58001_CA  False                  4        58001_4_CA
# 7417          58079_CA  False                  1        58079_1_CA
# 7418          58079_CA  False                  2        58079_2_CA
# 7419          58207_CA  False                  7        58207_7_CA
# 7420          58207_CA  False                  8        58207_8_CA
# 7422          60084_ST  False               1005     60084_1005_ST
# 7425          60084_ST  False               1006     60084_1006_ST
# 7428          60084_ST  False               7020     60084_7020_ST
# 7431          60084_ST  False               7040     60084_7040_ST
# 7436          10560_ST  False                  4        10560_4_ST
# 7442          10560_ST  False                  5        10560_5_ST
# 7448          57759_ST  False                  3        57759_3_ST
# 7449          57759_ST  False                  4        57759_4_ST
# 7450          57759_ST  False                  5        57759_5_ST
# 7451          58260_CA  False                  1        58260_1_CA
# 7452          58260_CA  False                  1        58260_1_CA
# 7453          58260_CA  False                  1        58260_1_CA
# 7454          58426_CS  False                  1        58426_1_CS
# 7455          58426_CS  False                  2        58426_2_CS
# 7456          60768_CA  False                 2        60768_2 _CA
# 7457          60768_CA  False                 2        60768_2 _CA
#
# [2957 rows x 8 columns]

# %%
gen_boiler_map_3 = pd.merge(unmapped_gen_2, unmapped_boiler_2, how='outer', on=['gen_boiler_code_3'])
gen_boiler_map_3['mapped'] = (gen_boiler_map_3['plant_id_gen'].notnull() & 
                              gen_boiler_map_3['plant_id_boiler'].notnull() &
                              ~gen_boiler_map_3.duplicated(subset='gen_boiler_code_3',keep=False))

# %%
gen_boiler_map_3[gen_boiler_map_3['mapped'] == True].drop_duplicates(subset='gen_boiler_code_3')
# Out:
#       plant_id_gen prime_mover_gen generator_id        gen_code  \
# 4            126.0              ST          ST1      126_ST1_ST
# 5            126.0              ST          ST2      126_ST2_ST
# 6            126.0              ST          ST3      126_ST3_ST
# 7            141.0              ST          AF1      141_AF1_ST
# 8            141.0              ST          AF2      141_AF2_ST
# 9            141.0              ST          AF3      141_AF3_ST
# 12           160.0              ST          ST2      160_ST2_ST
# 13           160.0              ST          ST3      160_ST3_ST
# 17           246.0              ST          ST1      246_ST1_ST
# 18           246.0              ST          ST2      246_ST2_ST
# 23           298.0              ST            1        298_1_ST
# 24           298.0              ST            2        298_2_ST
# 27           335.0              ST            3        335_3_ST
# 28           335.0              ST            4        335_4_ST
# 41           525.0              ST            1        525_1_ST
# 42           525.0              ST            2        525_2_ST
# 46           533.0              CA            1        533_1_CA
# 49           568.0              ST            2        568_2_ST
# 50           568.0              ST            3        568_3_ST
# 51           609.0              ST            1        609_1_ST
# 52           609.0              ST            2        609_2_ST
# 53           610.0              ST            5        610_5_ST
# 54           610.0              ST            6        610_6_ST
# 55           617.0              ST          ST1      617_ST1_ST
# 56           617.0              ST          ST2      617_ST2_ST
# 57           617.0              ST          ST3      617_ST3_ST
# 58           617.0              ST          ST4      617_ST4_ST
# 62           620.0              CA            4        620_4_CA
# 63           620.0              CA            5        620_5_CA
# 64           621.0              ST          ST1      621_ST1_ST
# ...            ...             ...          ...             ...
# 1885       58200.0              ST         GEN2   58200_GEN2_ST
# 1886       58200.0              ST         GEN3   58200_GEN3_ST
# 1897        2465.0              CA            1       2465_1_CA
# 1911       10039.0              ST         GEN7   10039_GEN7_ST
# 1927       10334.0              ST         GEN2   10334_GEN2_ST
# 1933       10521.0              CA          TG4    10521_TG4_CA
# 1936       10700.0              ST          TG2    10700_TG2_ST
# 1969       50473.0              ST          SRC    50473_SRC_ST
# 1984       50858.0              ST         GEN2   50858_GEN2_ST
# 1985       50872.0              ST         GEN1   50872_GEN1_ST
# 1987       50900.0              ST         GEN6   50900_GEN6_ST
# 2088       56467.0              CA         STG1   56467_STG1_CA
# 2091       56847.0              ST          STG    56847_STG_ST
# 2106       57914.0              ST            1      57914_1_ST
# 2107       57914.0              ST            2      57914_2_ST
# 2144       58557.0              CA          ST1    58557_ST1_CA
# 2146       58697.0              CA          CA1    58697_CA1_CA
# 2231       50188.0              ST          TG2    50188_TG2_ST
# 2236       50900.0              ST         GEN7   50900_GEN7_ST
# 2248       55230.0              CA          ST2    55230_ST2_CA
# 2262       58001.0              CA        STG-1  58001_STG-1_CA
# 2263       58005.0              CA        STG-1  58005_STG-1_CA
# 2270       59884.0              ST        STG-1  59884_STG-1_ST
# 2271       59884.0              ST        STG-2  59884_STG-2_ST
# 2285       55183.0              CA          ST1    55183_ST1_CA
# 2286       55183.0              CA          ST2    55183_ST2_CA
# 2290       55939.0              CA         ST01   55939_ST01_CA
# 2293       58001.0              CA        STG-2  58001_STG-2_CA
# 2294       58079.0              CA        STG-1  58079_STG-1_CA
# 2299       50561.0              CA         STG2   50561_STG2_CA
#
#      gen_boiler_code_2_x mapped_x generator_id_stripped gen_boiler_code_3  \
# 4                 126_ST    False                     1          126_1_ST
# 5                 126_ST    False                     2          126_2_ST
# 6                 126_ST    False                     3          126_3_ST
# 7                 141_ST    False                     1          141_1_ST
# 8                 141_ST    False                     2          141_2_ST
# 9                 141_ST    False                     3          141_3_ST
# 12                160_ST    False                     2          160_2_ST
# 13                160_ST    False                     3          160_3_ST
# 17                246_ST    False                     1          246_1_ST
# 18                246_ST    False                     2          246_2_ST
# 23                298_ST    False                     1          298_1_ST
# 24                298_ST    False                     2          298_2_ST
# 27                335_ST    False                     3          335_3_ST
# 28                335_ST    False                     4          335_4_ST
# 41                525_ST    False                     1          525_1_ST
# 42                525_ST    False                     2          525_2_ST
# 46                533_CA    False                     1          533_1_CA
# 49                568_ST    False                     2          568_2_ST
# 50                568_ST    False                     3          568_3_ST
# 51                609_ST    False                     1          609_1_ST
# 52                609_ST    False                     2          609_2_ST
# 53                610_ST    False                     5          610_5_ST
# 54                610_ST    False                     6          610_6_ST
# 55                617_ST    False                     1          617_1_ST
# 56                617_ST    False                     2          617_2_ST
# 57                617_ST    False                     3          617_3_ST
# 58                617_ST    False                     4          617_4_ST
# 62                620_CA    False                     4          620_4_CA
# 63                620_CA    False                     5          620_5_CA
# 64                621_ST    False                     1          621_1_ST
# ...                  ...      ...                   ...               ...
# 1885            58200_ST    False                     2        58200_2_ST
# 1886            58200_ST    False                     3        58200_3_ST
# 1897             2465_CA    False                     1         2465_1_CA
# 1911            10039_ST    False                     7        10039_7_ST
# 1927            10334_ST    False                     2        10334_2_ST
# 1933            10521_CA    False                     4        10521_4_CA
# 1936            10700_ST    False                     2        10700_2_ST
# 1969            50473_ST    False                               50473__ST
# 1984            50858_ST    False                     2        50858_2_ST
# 1985            50872_ST    False                     1        50872_1_ST
# 1987            50900_ST    False                     6        50900_6_ST
# 2088            56467_CA    False                     1        56467_1_CA
# 2091            56847_ST    False                               56847__ST
# 2106            57914_ST    False                     1        57914_1_ST
# 2107            57914_ST    False                     2        57914_2_ST
# 2144            58557_CA    False                     1        58557_1_CA
# 2146            58697_CA    False                     1        58697_1_CA
# 2231            50188_ST    False                     2        50188_2_ST
# 2236            50900_ST    False                     7        50900_7_ST
# 2248            55230_CA    False                     2        55230_2_CA
# 2262            58001_CA    False                     1        58001_1_CA
# 2263            58005_CA    False                     1        58005_1_CA
# 2270            59884_ST    False                     1        59884_1_ST
# 2271            59884_ST    False                     2        59884_2_ST
# 2285            55183_CA    False                     1        55183_1_CA
# 2286            55183_CA    False                     2        55183_2_CA
# 2290            55939_CA    False                    01       55939_01_CA
# 2293            58001_CA    False                     2        58001_2_CA
# 2294            58079_CA    False                     1        58079_1_CA
# 2299            50561_CA    False                     2        50561_2_CA
#
#       plant_id_boiler boiler_id prime_mover_boiler      boiler_code  \
# 4               126.0         1                 ST         126_1_ST
# 5               126.0         2                 ST         126_2_ST
# 6               126.0         3                 ST         126_3_ST
# 7               141.0         1                 ST         141_1_ST
# 8               141.0         2                 ST         141_2_ST
# 9               141.0         3                 ST         141_3_ST
# 12              160.0         2                 ST         160_2_ST
# 13              160.0         3                 ST         160_3_ST
# 17              246.0         1                 ST         246_1_ST
# 18              246.0         2                 ST         246_2_ST
# 23              298.0      LIM1                 ST      298_LIM1_ST
# 24              298.0      LIM2                 ST      298_LIM2_ST
# 27              335.0        3A                 ST        335_3A_ST
# 28              335.0        4A                 ST        335_4A_ST
# 41              525.0        H1                 ST        525_H1_ST
# 42              525.0        H2                 ST        525_H2_ST
# 46              533.0     HRSG1                 CA     533_HRSG1_CA
# 49              568.0      BHB2                 ST      568_BHB2_ST
# 50              568.0      BHB3                 ST      568_BHB3_ST
# 51              609.0      PCC1                 ST      609_PCC1_ST
# 52              609.0      PCC2                 ST      609_PCC2_ST
# 53              610.0      PCU5                 ST      610_PCU5_ST
# 54              610.0      PCU6                 ST      610_PCU6_ST
# 55              617.0      PPE1                 ST      617_PPE1_ST
# 56              617.0      PPE2                 ST      617_PPE2_ST
# 57              617.0      PPE3                 ST      617_PPE3_ST
# 58              617.0      PPE4                 ST      617_PPE4_ST
# 62              620.0      PSN4                 CA      620_PSN4_CA
# 63              620.0      PSN5                 CA      620_PSN5_CA
# 64              621.0      PTP1                 ST      621_PTP1_ST
# ...               ...       ...                ...              ...
# 1885          58200.0      BLR2                 ST    58200_BLR2_ST
# 1886          58200.0      BLR3                 ST    58200_BLR3_ST
# 1897           2465.0     HRSG1                 CA    2465_HRSG1_CA
# 1911          10039.0         7                 ST       10039_7_ST
# 1927          10334.0         2                 ST       10334_2_ST
# 1933          10521.0      BLR4                 CA    10521_BLR4_CA
# 1936          10700.0      BLR2                 ST    10700_BLR2_ST
# 1969          50473.0         C                 ST       50473_C_ST
# 1984          50858.0     MWC2C                 ST   50858_MWC2C_ST
# 1985          50872.0        B1                 ST      50872_B1_ST
# 1987          50900.0       6PB                 ST     50900_6PB_ST
# 2088          56467.0     HRSG1                 CA   56467_HRSG1_CA
# 2091          56847.0      BOIL                 ST    56847_BOIL_ST
# 2106          57914.0       CE1                 ST     57914_CE1_ST
# 2107          57914.0       CE2                 ST     57914_CE2_ST
# 2144          58557.0         1                 CA       58557_1_CA
# 2146          58697.0     HRSG1                 CA   58697_HRSG1_CA
# 2231          50188.0       PB2                 ST     50188_PB2_ST
# 2236          50900.0       7PB                 ST     50900_7PB_ST
# 2248          55230.0     HRSG2                 CA   55230_HRSG2_CA
# 2262          58001.0     HRSG1                 CA   58001_HRSG1_CA
# 2263          58005.0     HRSG1                 CA   58005_HRSG1_CA
# 2270          59884.0    HRSG-1                 ST  59884_HRSG-1_ST
# 2271          59884.0    HRSG-2                 ST  59884_HRSG-2_ST
# 2285          55183.0     HRSG1                 CA   55183_HRSG1_CA
# 2286          55183.0     HRSG2                 CA   55183_HRSG2_CA
# 2290          55939.0      CT01                 CA    55939_CT01_CA
# 2293          58001.0     HRSG2                 CA   58001_HRSG2_CA
# 2294          58079.0    HRSG-1                 CA  58079_HRSG-1_CA
# 2299          50561.0         2                 CA       50561_2_CA
#
#      gen_boiler_code_2_y mapped_y boiler_id_stripped mapped
# 4                 126_ST    False                  1   True
# 5                 126_ST    False                  2   True
# 6                 126_ST    False                  3   True
# 7                 141_ST    False                  1   True
# 8                 141_ST    False                  2   True
# 9                 141_ST    False                  3   True
# 12                160_ST    False                  2   True
# 13                160_ST    False                  3   True
# 17                246_ST    False                  1   True
# 18                246_ST    False                  2   True
# 23                298_ST    False                  1   True
# 24                298_ST    False                  2   True
# 27                335_ST    False                  3   True
# 28                335_ST    False                  4   True
# 41                525_ST    False                  1   True
# 42                525_ST    False                  2   True
# 46                533_CA    False                  1   True
# 49                568_ST    False                  2   True
# 50                568_ST    False                  3   True
# 51                609_ST    False                  1   True
# 52                609_ST    False                  2   True
# 53                610_ST    False                  5   True
# 54                610_ST    False                  6   True
# 55                617_ST    False                  1   True
# 56                617_ST    False                  2   True
# 57                617_ST    False                  3   True
# 58                617_ST    False                  4   True
# 62                620_CA    False                  4   True
# 63                620_CA    False                  5   True
# 64                621_ST    False                  1   True
# ...                  ...      ...                ...    ...
# 1885            58200_ST    False                  2   True
# 1886            58200_ST    False                  3   True
# 1897             2465_CA    False                  1   True
# 1911            10039_ST    False                  7   True
# 1927            10334_ST    False                  2   True
# 1933            10521_CA    False                  4   True
# 1936            10700_ST    False                  2   True
# 1969            50473_ST    False                      True
# 1984            50858_ST    False                  2   True
# 1985            50872_ST    False                  1   True
# 1987            50900_ST    False                  6   True
# 2088            56467_CA    False                  1   True
# 2091            56847_ST    False                      True
# 2106            57914_ST    False                  1   True
# 2107            57914_ST    False                  2   True
# 2144            58557_CA    False                  1   True
# 2146            58697_CA    False                  1   True
# 2231            50188_ST    False                  2   True
# 2236            50900_ST    False                  7   True
# 2248            55230_CA    False                  2   True
# 2262            58001_CA    False                  1   True
# 2263            58005_CA    False                  1   True
# 2270            59884_ST    False                  1   True
# 2271            59884_ST    False                  2   True
# 2285            55183_CA    False                  1   True
# 2286            55183_CA    False                  2   True
# 2290            55939_CA    False                 01   True
# 2293            58001_CA    False                  2   True
# 2294            58079_CA    False                  1   True
# 2299            50561_CA    False                  2   True
#
# [726 rows x 16 columns]

# %%
unmapped_gen_boiler_2[(unmapped_gen_boiler_2['plant_id_gen'] == 1391.0) | (unmapped_gen_boiler_2['plant_id_boiler'] == 1391.0)]
# Out:
#       plant_id_gen prime_mover_gen generator_id    gen_code gen_boiler_code_2  \
# 7176        1391.0              ST           1A  1391_1A_ST           1391_ST
# 7177        1391.0              ST           2A  1391_2A_ST           1391_ST
# 7178        1391.0              ST           3A  1391_3A_ST           1391_ST
# 7726           NaN             NaN          NaN         NaN           1391_CA
# 7727           NaN             NaN          NaN         NaN           1391_CA
# 7728           NaN             NaN          NaN         NaN           1391_CA
#
#       plant_id_boiler boiler_id prime_mover_boiler boiler_code mapped
# 7176              NaN       NaN                NaN         NaN  False
# 7177              NaN       NaN                NaN         NaN  False
# 7178              NaN       NaN                NaN         NaN  False
# 7726           1391.0         9                 CA   1391_9_CA  False
# 7727           1391.0        4A                 CA  1391_4A_CA  False
# 7728           1391.0        5A                 CA  1391_5A_CA  False

# %%
unmapped_gen_boiler_2[(unmapped_gen_boiler_2['plant_id_gen'] == 50392.0) | (unmapped_gen_boiler_2['plant_id_boiler'] == 50392.0)]
# Out:
#       plant_id_gen prime_mover_gen generator_id      gen_code  \
# 3299       50392.0              ST          TG1  50392_TG1_ST
# 3300       50392.0              ST          TG1  50392_TG1_ST
# 3301       50392.0              ST          TG1  50392_TG1_ST
# 3302       50392.0              ST          TG1  50392_TG1_ST
# 3303       50392.0              ST          TG1  50392_TG1_ST
# 3304       50392.0              ST          TG1  50392_TG1_ST
# 3305       50392.0              ST          TG1  50392_TG1_ST
# 3306       50392.0              ST          TG2  50392_TG2_ST
# 3307       50392.0              ST          TG2  50392_TG2_ST
# 3308       50392.0              ST          TG2  50392_TG2_ST
# 3309       50392.0              ST          TG2  50392_TG2_ST
# 3310       50392.0              ST          TG2  50392_TG2_ST
# 3311       50392.0              ST          TG2  50392_TG2_ST
# 3312       50392.0              ST          TG2  50392_TG2_ST
# 3313       50392.0              ST          TG3  50392_TG3_ST
# 3314       50392.0              ST          TG3  50392_TG3_ST
# 3315       50392.0              ST          TG3  50392_TG3_ST
# 3316       50392.0              ST          TG3  50392_TG3_ST
# 3317       50392.0              ST          TG3  50392_TG3_ST
# 3318       50392.0              ST          TG3  50392_TG3_ST
# 3319       50392.0              ST          TG3  50392_TG3_ST
# 3320       50392.0              ST          TG4  50392_TG4_ST
# 3321       50392.0              ST          TG4  50392_TG4_ST
# 3322       50392.0              ST          TG4  50392_TG4_ST
# 3323       50392.0              ST          TG4  50392_TG4_ST
# 3324       50392.0              ST          TG4  50392_TG4_ST
# 3325       50392.0              ST          TG4  50392_TG4_ST
# 3326       50392.0              ST          TG4  50392_TG4_ST
# 3327       50392.0              ST          TG5  50392_TG5_ST
# 3328       50392.0              ST          TG5  50392_TG5_ST
# 3329       50392.0              ST          TG5  50392_TG5_ST
# 3330       50392.0              ST          TG5  50392_TG5_ST
# 3331       50392.0              ST          TG5  50392_TG5_ST
# 3332       50392.0              ST          TG5  50392_TG5_ST
# 3333       50392.0              ST          TG5  50392_TG5_ST
#
#      gen_boiler_code_2  plant_id_boiler boiler_id prime_mover_boiler  \
# 3299          50392_ST          50392.0         1                 ST
# 3300          50392_ST          50392.0         2                 ST
# 3301          50392_ST          50392.0         3                 ST
# 3302          50392_ST          50392.0         4                 ST
# 3303          50392_ST          50392.0         5                 ST
# 3304          50392_ST          50392.0         6                 ST
# 3305          50392_ST          50392.0        6A                 ST
# 3306          50392_ST          50392.0         1                 ST
# 3307          50392_ST          50392.0         2                 ST
# 3308          50392_ST          50392.0         3                 ST
# 3309          50392_ST          50392.0         4                 ST
# 3310          50392_ST          50392.0         5                 ST
# 3311          50392_ST          50392.0         6                 ST
# 3312          50392_ST          50392.0        6A                 ST
# 3313          50392_ST          50392.0         1                 ST
# 3314          50392_ST          50392.0         2                 ST
# 3315          50392_ST          50392.0         3                 ST
# 3316          50392_ST          50392.0         4                 ST
# 3317          50392_ST          50392.0         5                 ST
# 3318          50392_ST          50392.0         6                 ST
# 3319          50392_ST          50392.0        6A                 ST
# 3320          50392_ST          50392.0         1                 ST
# 3321          50392_ST          50392.0         2                 ST
# 3322          50392_ST          50392.0         3                 ST
# 3323          50392_ST          50392.0         4                 ST
# 3324          50392_ST          50392.0         5                 ST
# 3325          50392_ST          50392.0         6                 ST
# 3326          50392_ST          50392.0        6A                 ST
# 3327          50392_ST          50392.0         1                 ST
# 3328          50392_ST          50392.0         2                 ST
# 3329          50392_ST          50392.0         3                 ST
# 3330          50392_ST          50392.0         4                 ST
# 3331          50392_ST          50392.0         5                 ST
# 3332          50392_ST          50392.0         6                 ST
# 3333          50392_ST          50392.0        6A                 ST
#
#       boiler_code mapped
# 3299   50392_1_ST  False
# 3300   50392_2_ST  False
# 3301   50392_3_ST  False
# 3302   50392_4_ST  False
# 3303   50392_5_ST  False
# 3304   50392_6_ST  False
# 3305  50392_6A_ST  False
# 3306   50392_1_ST  False
# 3307   50392_2_ST  False
# 3308   50392_3_ST  False
# 3309   50392_4_ST  False
# 3310   50392_5_ST  False
# 3311   50392_6_ST  False
# 3312  50392_6A_ST  False
# 3313   50392_1_ST  False
# 3314   50392_2_ST  False
# 3315   50392_3_ST  False
# 3316   50392_4_ST  False
# 3317   50392_5_ST  False
# 3318   50392_6_ST  False
# 3319  50392_6A_ST  False
# 3320   50392_1_ST  False
# 3321   50392_2_ST  False
# 3322   50392_3_ST  False
# 3323   50392_4_ST  False
# 3324   50392_5_ST  False
# 3325   50392_6_ST  False
# 3326  50392_6A_ST  False
# 3327   50392_1_ST  False
# 3328   50392_2_ST  False
# 3329   50392_3_ST  False
# 3330   50392_4_ST  False
# 3331   50392_5_ST  False
# 3332   50392_6_ST  False
# 3333  50392_6A_ST  False

# %%
unmapped_gen_boiler_2[(unmapped_gen_boiler_2['plant_id_gen'] == 55358.0) | (unmapped_gen_boiler_2['plant_id_boiler'] == 55358.0)]

# %%
unmapped_gen_boiler_2[unmapped_gen_boiler_2['plant_id_.*'] == 54512.0]

# %%
unmapped_gen_boiler_2[unmapped_gen_boiler_2['plant_id_gen'] == 54780].drop_duplicates('boiler_id')

# %%
unmapped_gen_boiler_2[unmapped_gen_boiler_2['plant_id_gen'] == 54780].drop_duplicates('generator_id')

# %%
unmapped_gen_boiler_2.sample(20)

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /Users/christinagosnell/anaconda/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
boiler_code['prime_mover_boiler'].drop_duplicates()
# Out:
# 0       ST
# 5       CA
# 4260    CT
# 4271    CS
# Name: prime_mover_boiler, dtype: object

# %%
prime_movers = gen_code['prime_mover_gen'].drop_duplicates().values
prime_movers
# Out:
# array(['ST', 'CA', 'CT', 'CS'], dtype=object)

# %%
plant_ids = gen_code['plant_id_gen'].drop_duplicates().head(100).values
plant_ids
# Out:
# array([  3,   7,   8,  10,  26,  47,  50,  51,  56,  59,  60,  79,  87,
#        108, 113, 116, 117, 118, 120, 126, 127, 130, 136, 141, 147, 160,
#        165, 167, 168, 169, 170, 173, 201, 202, 203, 207, 228, 246, 259,
#        260, 271, 273, 298, 302, 310, 315, 329, 330, 331, 335, 345, 350,
#        356, 358, 377, 384, 389, 400, 404, 408, 420, 460, 462, 465, 468,
#        469, 470, 477, 478, 492, 493, 525, 527, 533, 546, 548, 550, 562,
#        564, 568, 589, 593, 594, 599, 602, 603, 609, 610, 617, 619, 620,
#        621, 628, 634, 638, 641, 642, 643, 645, 663])

# %%
plant_prime_mover = gen_code[['plant_id_gen','prime_mover_gen']].drop_duplicates().head(100).values
plant_prime_mover
# Out:
# array([[3, 'ST'],
#        [3, 'CA'],
#        [7, 'ST'],
#        [8, 'ST'],
#        [10, 'ST'],
#        [26, 'ST'],
#        [47, 'ST'],
#        [50, 'ST'],
#        [51, 'ST'],
#        [56, 'ST'],
#        [59, 'ST'],
#        [60, 'ST'],
#        [79, 'ST'],
#        [87, 'ST'],
#        [108, 'ST'],
#        [113, 'ST'],
#        [116, 'ST'],
#        [117, 'CA'],
#        [118, 'ST'],
#        [120, 'ST'],
#        [126, 'ST'],
#        [127, 'ST'],
#        [130, 'ST'],
#        [136, 'ST'],
#        [141, 'ST'],
#        [147, 'ST'],
#        [147, 'CA'],
#        [160, 'CA'],
#        [160, 'ST'],
#        [165, 'ST'],
#        [167, 'ST'],
#        [168, 'ST'],
#        [169, 'ST'],
#        [170, 'ST'],
#        [173, 'ST'],
#        [201, 'CA'],
#        [202, 'ST'],
#        [203, 'ST'],
#        [207, 'ST'],
#        [228, 'ST'],
#        [246, 'ST'],
#        [259, 'ST'],
#        [260, 'ST'],
#        [271, 'ST'],
#        [273, 'ST'],
#        [298, 'ST'],
#        [302, 'ST'],
#        [310, 'ST'],
#        [315, 'ST'],
#        [329, 'ST'],
#        [329, 'CA'],
#        [330, 'ST'],
#        [331, 'ST'],
#        [335, 'ST'],
#        [345, 'ST'],
#        [350, 'ST'],
#        [356, 'ST'],
#        [358, 'CA'],
#        [377, 'ST'],
#        [384, 'ST'],
#        [389, 'ST'],
#        [400, 'ST'],
#        [400, 'CA'],
#        [404, 'ST'],
#        [408, 'CA'],
#        [420, 'ST'],
#        [460, 'ST'],
#        [462, 'ST'],
#        [465, 'ST'],
#        [468, 'ST'],
#        [469, 'ST'],
#        [470, 'ST'],
#        [477, 'ST'],
#        [478, 'ST'],
#        [492, 'ST'],
#        [493, 'ST'],
#        [525, 'ST'],
#        [527, 'ST'],
#        [533, 'CA'],
#        [546, 'ST'],
#        [548, 'ST'],
#        [550, 'ST'],
#        [562, 'ST'],
#        [564, 'ST'],
#        [568, 'ST'],
#        [589, 'ST'],
#        [593, 'ST'],
#        [594, 'ST'],
#        [599, 'ST'],
#        [602, 'ST'],
#        [603, 'ST'],
#        [609, 'ST'],
#        [610, 'ST'],
#        [617, 'ST'],
#        [619, 'ST'],
#        [620, 'ST'],
#        [620, 'CA'],
#        [621, 'ST'],
#        [628, 'ST'],
#        [634, 'CA']], dtype=object)

# %%
plant_prime_mover = [ (x[0], x[1]) for x in plant_prime_mover]

# %%
gen_gb = gen_code.groupby(by=['plant_id_gen','prime_mover_gen'])
gen_gb.get_group((3,'CA'))
# Out:
#     plant_id_gen prime_mover_gen generator_id   gen_code gen_boiler_code_2  \
# 60             3              CA         A1ST  3_A1ST_CA              3_CA
# 72             3              CA         A2ST  3_A2ST_CA              3_CA
#
#    gen_boiler_code
# 60       3_A1ST_CA
# 72       3_A2ST_CA

# %%
index = zip(gen_gb.first().index)
index

# %%
boiler_gb = boiler_code.groupby(by=['plant_id_boiler','prime_mover_boiler'])
boiler_gb.get_group((3,'CA'))
# Out:
#    plant_id_boiler boiler_id prime_mover_boiler boiler_code gen_boiler_code_2  \
# 5                3        6A                 CA     3_6A_CA              3_CA
# 6                3        6B                 CA     3_6B_CA              3_CA
# 7                3        7A                 CA     3_7A_CA              3_CA
# 8                3        7B                 CA     3_7B_CA              3_CA
#
#   gen_boiler_code
# 5         3_6A_CA
# 6         3_6B_CA
# 7         3_7A_CA
# 8         3_7B_CA

# %%
for plant_pm in plant_prime_mover:
    boiler_gb = boiler_code.groupby(by=['plant_id_boiler','prime_mover_boiler'])
    boiler_ids = boiler_gb.get_group(plant_pm)['boiler_id'].values
    gen_gb = gen_code.groupby(by=['plant_id_gen','prime_mover_gen'])
    gen_ids = gen_gb.get_group(plant_pm)
    for g_id in gen_ids['generator_id']:
        print(plant_pm[0],plant_pm[1], g_id)
        print(process.extract(g_id, boiler_ids))
# Out:
# 3 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0), ('5', 0)]
# 3 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0), ('5', 0)]
# 3 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0), ('5', 0)]
# 3 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0), ('5', 0)]
# 3 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 3 CA A1ST
# [('6A', 45), ('7A', 45), ('6B', 0), ('7B', 0)]
# 3 CA A2ST
# [('6A', 45), ('7A', 45), ('6B', 0), ('7B', 0)]
# 7 ST 1
# [('1', 100), ('2', 0)]
# 7 ST 2
# [('2', 100), ('1', 0)]
# 8 ST 10
# [('10', 100), ('6', 0), ('7', 0), ('8', 0), ('9', 0)]
# 8 ST 6
# [('6', 100), ('10', 0), ('7', 0), ('8', 0), ('9', 0)]
# 8 ST 7
# [('7', 100), ('10', 0), ('6', 0), ('8', 0), ('9', 0)]
# 8 ST 8
# [('8', 100), ('10', 0), ('6', 0), ('7', 0), ('9', 0)]
# 8 ST 9
# [('9', 100), ('10', 0), ('6', 0), ('7', 0), ('8', 0)]
# 10 ST 1
# [('1', 100), ('2', 0)]
# 10 ST 2
# [('2', 100), ('1', 0)]
# 26 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0), ('5', 0)]
# 26 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0), ('5', 0)]
# 26 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0), ('5', 0)]
# 26 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 26 ST ST4
# [('4', 90), ('1', 0), ('2', 0), ('3', 0), ('5', 0)]
# 47 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0), ('5', 0)]
# 47 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0), ('5', 0)]
# 47 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0), ('5', 0)]
# 47 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0), ('5', 0)]
# 47 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 50 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0), ('5', 0)]
# 50 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0), ('5', 0)]
# 50 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0), ('5', 0)]
# 50 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0), ('5', 0)]
# 50 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 50 ST 6
# [('6', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 50 ST 7
# [('7', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 50 ST 8
# [('8', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 51 ST 1
# [('1', 100)]
# 56 ST 1
# [('1', 100), ('2', 0), ('3', 0)]
# 56 ST 2
# [('2', 100), ('1', 0), ('3', 0)]
# 56 ST 3
# [('3', 100), ('1', 0), ('2', 0)]
# 59 ST 1
# [('1', 100)]
# 60 ST 1
# [('1', 100), ('2', 0)]
# 60 ST 2
# [('2', 100), ('1', 0)]
# 79 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('5', 0)]
# 79 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('5', 0)]
# 79 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('3', 0)]
# 87 ST 1
# [('1', 100)]
# 108 ST 1
# [('SGU1', 90)]
# 113 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0)]
# 113 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0)]
# 113 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0)]
# 113 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0)]
# 116 ST 1
# [('1', 100), ('2', 0)]
# 116 ST 2
# [('2', 100), ('1', 0)]
# 117 CA C4-2
# [('CC4', 57), ('CC5A', 25), ('CC5B', 25)]
# 117 CA C5-3
# [('CC5A', 50), ('CC5B', 50), ('CC4', 29)]
# 118 ST 1
# [('1', 100), ('2', 0)]
# 118 ST 2
# [('2', 100), ('1', 0)]
# 120 ST ST1
# [('1', 90)]
# 126 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0)]
# 126 ST ST1
# [('1', 90), ('2', 0), ('3', 0), ('4', 0)]
# 126 ST ST2
# [('2', 90), ('1', 0), ('3', 0), ('4', 0)]
# 126 ST ST3
# [('3', 90), ('1', 0), ('2', 0), ('4', 0)]
# 127 ST 1
# [('1', 100)]
# 130 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0)]
# 130 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0)]
# 130 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0)]
# 130 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0)]
# 136 ST 1
# [('1', 100), ('2', 0)]
# 136 ST 2
# [('2', 100), ('1', 0)]
# 141 ST AF1
# [('1', 90), ('2', 0), ('3', 0)]
# 141 ST AF2
# [('2', 90), ('1', 0), ('3', 0)]
# 141 ST AF3
# [('3', 90), ('1', 0), ('2', 0)]
# 147 ST KY1
# [('K-1', 67), ('K-2', 33)]
# 147 ST KY2
# [('K-2', 67), ('K-1', 33)]
# 147 CA KY7A
# [('K-7', 57)]
# 160 CA ST1
# [('1', 90)]
# 160 ST ST2
# [('2', 90), ('3', 0)]
# 160 ST ST3
# [('3', 90), ('2', 0)]
# 160 ST ST1
# [('2', 0), ('3', 0)]
# 165 ST 1
# [('1', 100), ('2', 0)]
# 165 ST 2
# [('2', 100), ('1', 0)]
# 167 ST 2
# [('2', 100), ('3', 0)]
# 167 ST 3
# [('3', 100), ('2', 0)]
# 168 ST 1
# [('1', 100), ('2', 0)]
# 168 ST 2
# [('2', 100), ('1', 0)]
# 169 ST 1
# [('1', 100), ('2', 0)]
# 169 ST 2
# [('2', 100), ('1', 0)]
# 170 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0)]
# 170 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0)]
# 170 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0)]
# 170 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0)]
# 173 ST 1
# [('1', 100)]
# 173 ST 2
# [('1', 0)]
# 201 CA 1
# [('2', 0)]
# 202 ST 1
# [('1', 100), ('01', 90)]
# 203 ST 1
# [('1', 100), ('01', 90)]
# 207 ST 1
# [('1', 100), ('2', 0)]
# 207 ST 2
# [('2', 100), ('1', 0)]
# 228 ST 6
# [('10', 0), ('9', 0)]
# 228 ST 7
# [('10', 0), ('9', 0)]
# 246 ST ST1
# [('1', 90), ('2', 0)]
# 246 ST ST2
# [('2', 90), ('1', 0)]
# 259 ST 1
# [('3', 0), ('4', 0)]
# 259 ST 2
# [('3', 0), ('4', 0)]
# 259 ST 3
# [('3', 100), ('4', 0)]
# 259 ST 4
# [('4', 100), ('3', 0)]
# 260 ST 6
# [('6-1', 90), ('7-1', 0)]
# 260 ST 7
# [('7-1', 90), ('6-1', 0)]
# 271 ST 5
# [('5', 100), ('6', 0), ('7', 0)]
# 271 ST 6
# [('6', 100), ('5', 0), ('7', 0)]
# 271 ST 7
# [('7', 100), ('5', 0), ('6', 0)]
# 273 ST 3
# [('3-1', 90)]
# 298 ST 1
# [('LIM1', 90), ('LIM2', 0)]
# 298 ST 2
# [('LIM2', 90), ('LIM1', 0)]
# 302 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0), ('5', 0)]
# 302 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0), ('5', 0)]
# 302 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0), ('5', 0)]
# 302 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 302 ST ST1
# [('1', 90), ('2', 0), ('3', 0), ('4', 0), ('5', 0)]
# 310 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0)]
# 310 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0)]
# 310 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0)]
# 310 ST ST1
# [('1', 90), ('2', 0), ('3', 0), ('4', 0)]
# 315 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0), ('5', 0)]
# 315 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0), ('5', 0)]
# 315 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0), ('5', 0)]
# 315 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0), ('5', 0)]
# 315 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 315 ST 6
# [('6', 100), ('1', 0), ('2', 0), ('3', 0), ('4', 0)]
# 329 ST 1
# [('1', 100), ('2', 0)]
# 329 ST 2
# [('2', 100), ('1', 0)]
# 329 CA 30
# [('31', 50), ('32', 50), ('41', 0), ('42', 0)]
# 329 CA 40
# [('41', 50), ('42', 50), ('31', 0), ('32', 0)]
# 330 ST 3
# [('3', 100), ('4', 0)]
# 330 ST 4
# [('4', 100), ('3', 0)]
# 331 ST 3
# [('3', 100), ('4', 0)]
# 331 ST 4
# [('4', 100), ('3', 0)]
# 335 ST 1
# [('1', 100), ('2', 0), ('3A', 0), ('4A', 0)]
# 335 ST 2
# [('2', 100), ('1', 0), ('3A', 0), ('4A', 0)]
# 335 ST 3
# [('3A', 90), ('1', 0), ('2', 0), ('4A', 0)]
# 335 ST 4
# [('4A', 90), ('1', 0), ('2', 0), ('3A', 0)]
# 345 ST 1
# [('1', 100), ('2', 0)]
# 345 ST 2
# [('2', 100), ('1', 0)]
# 350 ST 1
# [('1', 100), ('2', 0)]
# 350 ST 2
# [('2', 100), ('1', 0)]
# 356 ST 5
# [('5', 100), ('6', 0), ('7', 0), ('8', 0)]
# 356 ST 6
# [('6', 100), ('5', 0), ('7', 0), ('8', 0)]
# 356 ST 7
# [('7', 100), ('5', 0), ('6', 0), ('8', 0)]
# 356 ST 8
# [('8', 100), ('5', 0), ('6', 0), ('7', 0)]
# 358 CA MV3C
# [('MV3A', 75), ('MV3B', 75), ('MV4A', 50), ('MV4B', 50)]
# 358 CA MV4C
# [('MV4A', 75), ('MV4B', 75), ('MV3A', 50), ('MV3B', 50)]
# 377 ST 3
# [('3', 100), ('4', 0), ('5', 0)]
# 377 ST 4
# [('4', 100), ('3', 0), ('5', 0)]
# 377 ST 5
# [('5', 100), ('3', 0), ('4', 0)]
# 384 ST 7
# [('71', 90), ('72', 90), ('81', 0), ('82', 0)]
# 384 ST 8
# [('81', 90), ('82', 90), ('71', 0), ('72', 0)]
# 389 ST 3
# [('3', 100), ('4', 0)]
# 389 ST 4
# [('4', 100), ('3', 0)]
# 400 ST 1
# [('1', 100), ('2', 0), ('5', 0), ('6', 0)]
# 400 ST 2
# [('2', 100), ('1', 0), ('5', 0), ('6', 0)]
# 400 ST 5
# [('5', 100), ('1', 0), ('2', 0), ('6', 0)]
# 400 ST 6
# [('6', 100), ('1', 0), ('2', 0), ('5', 0)]
# 400 CA 8
# [('HRSG10', 0), ('HRSG9', 0)]
# 404 ST 1
# [('1', 100), ('2', 0), ('3', 0)]
# 404 ST 2
# [('2', 100), ('1', 0), ('3', 0)]
# 404 ST 3
# [('3', 100), ('1', 0), ('2', 0)]
# 408 CA 8
# [('6', 0), ('7', 0)]
# 420 ST B3
# [('B3', 100)]
# 460 ST 5
# [('41', 0), ('49', 0)]
# 460 ST 6
# [('41', 0), ('49', 0)]
# 462 ST 1
# [('55', 0), ('59', 0)]
# 462 ST 2
# [('55', 0), ('59', 0)]
# 465 ST 3
# [('3', 100), ('4', 0)]
# 465 ST 4
# [('4', 100), ('3', 0)]
# 468 ST 1
# [('1', 100), ('2', 0)]
# 468 ST 2
# [('2', 100), ('1', 0)]
# 469 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0)]
# 469 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0)]
# 469 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0)]
# 469 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0)]
# 470 ST 1
# [('1', 100), ('2', 0), ('3', 0)]
# 470 ST 2
# [('2', 100), ('1', 0), ('3', 0)]
# 470 ST 3
# [('3', 100), ('1', 0), ('2', 0)]
# 477 ST 5
# [('5', 100)]
# 478 ST 1
# [('1', 100), ('2', 0), ('3', 0)]
# 478 ST 2
# [('2', 100), ('1', 0), ('3', 0)]
# 492 ST 5
# [('5', 100), ('6', 0), ('7', 0)]
# 492 ST 6
# [('6', 100), ('5', 0), ('7', 0)]
# 492 ST 7
# [('7', 100), ('5', 0), ('6', 0)]
# 493 ST 1
# [('1', 100), ('2', 0), ('3', 0)]
# 493 ST 2
# [('2', 100), ('1', 0), ('3', 0)]
# 493 ST 3
# [('3', 100), ('1', 0), ('2', 0)]
# 525 ST 1
# [('H1', 90), ('H2', 0)]
# 525 ST 2
# [('H2', 90), ('H1', 0)]
# 527 ST 1
# [('1', 100)]
# 527 ST 2
# [('1', 0)]
# 527 ST 3
# [('1', 0)]
# 527 ST ST4
# [('1', 0)]
# 533 CA 1
# [('HRSG1', 90), ('HRSGV1', 90), ('HRSGV2', 0)]
# 533 CA 2
# [('HRSGV2', 90), ('HRSG1', 0), ('HRSGV1', 0)]
# 533 CA 3
# [('HRSG1', 0), ('HRSGV1', 0), ('HRSGV2', 0)]
# 533 CA VAN3
# [('HRSGV1', 30), ('HRSGV2', 30), ('HRSG1', 0)]
# 546 ST 5
# [('5', 100), ('6', 0)]
# 546 ST 6
# [('6', 100), ('5', 0)]
# 548 ST 1
# [('1', 100), ('2', 0)]
# 548 ST 2
# [('2', 100), ('1', 0)]
# 550 ST 1
# [('1', 100)]
# 562 ST 2
# [('2', 100), ('3', 0), ('4', 0)]
# 562 ST 3
# [('3', 100), ('2', 0), ('4', 0)]
# 562 ST 4
# [('4', 100), ('2', 0), ('3', 0)]
# 564 ST 1
# [('1', 100), ('2', 0)]
# 564 ST 2
# [('2', 100), ('1', 0)]
# 568 ST 2
# [('BHB2', 90), ('BHB3', 0)]
# 568 ST 3
# [('BHB3', 90), ('BHB2', 0)]
# 589 ST 1
# [('1', 100)]
# 593 ST 3
# [('3', 100), ('4', 0), ('5', 0)]
# 593 ST 4
# [('4', 100), ('3', 0), ('5', 0)]
# 593 ST 5
# [('5', 100), ('3', 0), ('4', 0)]
# 594 ST 1
# [('1', 100), ('2', 0), ('3', 0), ('4', 0)]
# 594 ST 2
# [('2', 100), ('1', 0), ('3', 0), ('4', 0)]
# 594 ST 3
# [('3', 100), ('1', 0), ('2', 0), ('4', 0)]
# 594 ST 4
# [('4', 100), ('1', 0), ('2', 0), ('3', 0)]
# 599 ST 1
# [('1', 100), ('2', 0), ('3', 0)]
# 599 ST 2
# [('2', 100), ('1', 0), ('3', 0)]
# 599 ST 3
# [('3', 100), ('1', 0), ('2', 0)]
# 602 ST 1
# [('1', 100), ('2', 0)]
# 602 ST 2
# [('2', 100), ('1', 0)]
# 603 ST 15
# [('15', 100), ('16', 50)]
# 603 ST 16
# [('16', 100), ('15', 50)]
# 609 ST 1
# [('PCC1', 90), ('PCC2', 0)]
# 609 ST 2
# [('PCC2', 90), ('PCC1', 0)]
# 610 ST 5
# [('PCU5', 90), ('PCU6', 0)]
# 610 ST 6
# [('PCU6', 90), ('PCU5', 0)]
# 617 ST ST1
# [('PPE1', 29), ('PPE2', 0), ('PPE3', 0), ('PPE4', 0)]
# 617 ST ST2
# [('PPE2', 29), ('PPE1', 0), ('PPE3', 0), ('PPE4', 0)]
# 617 ST ST3
# [('PPE3', 29), ('PPE1', 0), ('PPE2', 0), ('PPE4', 0)]
# 617 ST ST4
# [('PPE4', 29), ('PPE1', 0), ('PPE2', 0), ('PPE3', 0)]
# 619 ST 3
# [('PRV3', 90), ('PRV4', 0)]
# 619 ST 4
# [('PRV4', 90), ('PRV3', 0)]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-282-c5931a8ff5f0> in <module>()
#       1 for plant_pm in plant_prime_mover:
#       2     boiler_gb = boiler_code.groupby(by=['plant_id_boiler','prime_mover_boiler'])
# ----> 3     boiler_ids = boiler_gb.get_group(plant_pm)['boiler_id'].values
#       4     gen_gb = gen_code.groupby(by=['plant_id_gen','prime_mover_gen'])
#       5     gen_ids = gen_gb.get_group(plant_pm)
#
# /Users/christinagosnell/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in get_group(self, name, obj)
#     616         inds = self._get_index(name)
#     617         if not len(inds):
# --> 618             raise KeyError(name)
#     619
#     620         return obj.take(inds, axis=self.axis, convert=False)
#
# KeyError: (620, 'ST')

# %%
#gen_input = gen_gb['generator_id'].first()
gen_gb.get_group((3,'ST'))
# Out:
#    gen_boiler_code gen_boiler_code_2 gen_code generator_id
# 0           3_1_ST              3_ST   3_1_ST            1
# 12          3_2_ST              3_ST   3_2_ST            2
# 24          3_3_ST              3_ST   3_3_ST            3
# 36          3_4_ST              3_ST   3_4_ST            4
# 48          3_5_ST              3_ST   3_5_ST            5

# %%
gen_code_input = gen_code[(gen_code['plant_id_gen'] == 3) & (gen_code['prime_mover_gen'] == 'CA')]
boiler_code_input = boiler_code[(boiler_code['plant_id_boiler'] == 3) & (boiler_code['prime_mover_boiler'] == 'CA')]

# %%
gen_code_input
# Out:
#     plant_id_gen prime_mover_gen generator_id   gen_code gen_boiler_code_2  \
# 60             3              CA         A1ST  3_A1ST_CA              3_CA
# 72             3              CA         A2ST  3_A2ST_CA              3_CA
#
#    gen_boiler_code
# 60       3_A1ST_CA
# 72       3_A2ST_CA

# %%
boiler_code_input
# Out:
#    plant_id_boiler boiler_id prime_mover_boiler boiler_code gen_boiler_code_2  \
# 5                3        6A                 CA     3_6A_CA              3_CA
# 6                3        6B                 CA     3_6B_CA              3_CA
# 7                3        7A                 CA     3_7A_CA              3_CA
# 8                3        7B                 CA     3_7B_CA              3_CA
#
#   gen_boiler_code
# 5         3_6A_CA
# 6         3_6B_CA
# 7         3_7A_CA
# 8         3_7B_CA

# %%
choices = boiler_code_input['boiler_id'].values

# %%
choices
# Out:
# array(['6A', '6B', '7A', '7B'], dtype=object)

# %%
for g_id in gen_code_input['generator_id']:
    print(g_id)
    print(process.extract(g_id, choices))
# Out:
# A1ST
# [('6A', 45), ('7A', 45), ('6B', 0), ('7B', 0)]
# A2ST
# [('6A', 45), ('7A', 45), ('6B', 0), ('7B', 0)]

# %%
fuzz.ratio('1391_CA', '1391_5A_CA')
# Out:
# 82

# %%
gen_boiler_map[gen_boiler_map['gen_boiler_code'].str.contains("^10784_")]
