# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
import numpy as np
import pandas as pd
import sqlalchemy as sa
import networkx as nx
sys.path.append(os.path.abspath(os.path.join('..','..','..')))
from pudl import init, mcoe, analysis, constants, settings, outputs
from scipy import stats
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
# What is this chained_assignment thing all about?
pd.options.mode.chained_assignment = None
# %matplotlib inline
plt.style.use('ggplot')
mpl.rcParams['figure.figsize'] = (10,6)
mpl.rcParams['figure.dpi'] = 150
pd.options.display.max_columns = 56

# %%
hwe_out = outputs.PudlOutput(freq=None,
                              start_date='2009-01-01',
                              end_date='2016-12-31',
                              testing=False)
hwe_out.frc_eia923().to_csv(os.path.join(settings.PUDL_DIR, 'results', 'notebooks', 'headwaters', 'HWE_frc_eia923.csv'),index=False)
hwe_out.gens_eia860().to_csv(os.path.join(settings.PUDL_DIR, 'results', 'notebooks', 'headwaters', 'HWE_gens_eia860.csv'), index=False)

# %%
nx.__version__
# Out:
# '2.1'

# %%
len(hwe_out.plants_eia860().operator_name.unique())
# Out:
# 5194

# %%
# Setup the initial inputs:
start_date = '2009-01-01'
end_date = '2016-12-31'
freq = 'MS'
testing = False
debug = True
min_heat_rate = 5.5
min_cap_fact = 0.0
max_cap_fact = 1.5

pudl_out = outputs.PudlOutput(freq=freq,
                              start_date=start_date,
                              end_date=end_date,
                              testing=testing)

mcoe_out = pudl_out.mcoe(min_heat_rate=min_heat_rate,
                         min_cap_fact=min_cap_fact,
                         max_cap_fact=max_cap_fact,
                         min_fuel_cost_per_mwh=None, update=True)
# Out:
# WARNING: multiple EIA unit codes found in these PUDL units:
# plant_id_eia  unit_id_pudl
# 1004          3                         [1, CT1]
# 1904          1                     [HBR0, BDS0]
# 1927          2                     [RIV0, HBR0]
# 4040          1                     [PWG1, PWG2]
# 10725         1                     [F801, F802]
# 50973         1               [BLK1, BLK2, BLK3]
# 55153         1                     [STG1, STG2]
# 55309         1                     [SMR1, SMR2]
# 55502         1                 [CC1, G801, CC2]
# 56041         1                       [NGS, MGS]
# 56350         1                      [BLK1, 115]
#               2                      [BLK2, 116]
# 56998         1                        [43, PB4]
#               2                        [53, PB5]
# Name: unit_code, dtype: object

# %%
mcoe_out[mcoe_out.plant_name.str.match('Pawnee')]
# Out:
#        report_date  plant_id_eia  plant_id_pudl  unit_id_pudl generator_id  \
# 150276  2009-01-01          6248            443             1            1
# 150277  2009-02-01          6248            443             1            1
# 150280  2009-05-01          6248            443             1            1
# 150281  2009-06-01          6248            443             1            1
# 150282  2009-07-01          6248            443             1            1
# 150283  2009-08-01          6248            443             1            1
# 150284  2009-09-01          6248            443             1            1
# 150285  2009-10-01          6248            443             1            1
# 150286  2009-11-01          6248            443             1            1
# 150287  2009-12-01          6248            443             1            1
# 150288  2010-01-01          6248            443             1            1
# 150289  2010-02-01          6248            443             1            1
# 150290  2010-03-01          6248            443             1            1
# 150291  2010-04-01          6248            443             1            1
# 150292  2010-05-01          6248            443             1            1
# 150293  2010-06-01          6248            443             1            1
# 150294  2010-07-01          6248            443             1            1
# 150295  2010-08-01          6248            443             1            1
# 150277                    True         None             SUB            None
# 150280                    True         None             SUB            None
# 150281                    True         None             SUB            None
# 150282                    True         None             SUB            None
# 150283                    True         None             SUB            None
# 150284                    True         None             SUB            None
# 150285                    True         None             SUB            None
# 150286                    True         None             SUB            None
# 150287                    True         None             SUB            None
# 150288                    True         None             SUB            None
# 150289                    True         None             SUB            None
# 150290                    True         None             SUB            None
# 150291                    True         None             SUB            None
# 150292                    True         None             SUB            None
# 150293                    True         None             SUB            None
# 150294                    True         None             SUB            None
# 150295                    True         None             SUB            None
# 150296                    True         None             SUB            None
# 150297                    True         None             SUB            None
# 150298                    True         None             SUB            None
# 150299                    True         None             SUB            None
# 150300                    True         None             SUB            None
# 150301                    True         None             SUB            None
# 150302                    True         None             SUB            None
# 150303                    True         None             SUB            None
# 150304                    True         None             SUB            None
# 150305                    True         None             SUB            None
# 150306                    True         None             SUB            None
# 150307                    True         None             SUB            None
# ...                        ...          ...             ...             ...
# 150340                    None        False             SUB            None
# 150341                    None        False             SUB            None
# 150342                    None        False             SUB            None
# 150343                    None        False             SUB            None
# 150344                    None        False             SUB            None
# 150345                    None        False             SUB            None
# 150346                    None        False             SUB            None
# 150347                    None        False             SUB            None
# 150348                    None        False             SUB            None
# 150349                    None        False             SUB            None
# 150350                    None        False             SUB            None
# 150351                    None        False             SUB            None
# 150352                    None        False             SUB            None
# 150353                    None        False             SUB            None
# 150354                    None        False             SUB            None
# 150355                    None        False             SUB            None
# 150356                    None        False             SUB            None
# 150357                    None        False             SUB            None
# 150358                    None        False             SUB            None
# 150359                    None        False             SUB            None
# 150360                    None        False             SUB              NG
# 150361                    None        False             SUB              NG
# 150364                    None        False             SUB              NG
# 150365                    None        False             SUB              NG
# 150366                    None        False             SUB              NG
# 150367                    None        False             SUB              NG
# 150368                    None        False             SUB              NG
# 150369                    None        False             SUB              NG
# 150370                    None        False             SUB              NG
# 150371                    None        False             SUB              NG
#
#        energy_source_3 energy_source_4 energy_source_5 energy_source_6  \
# 150276            None            None            None            None
# 150277            None            None            None            None
# 150280            None            None            None            None
# 150281            None            None            None            None
# 150282            None            None            None            None
# 150283            None            None            None            None
# 150284            None            None            None            None
# 150285            None            None            None            None
# 150286            None            None            None            None
# 150287            None            None            None            None
# 150288            None            None            None            None
# 150289            None            None            None            None
# 150290            None            None            None            None
# 150291            None            None            None            None
# 150292            None            None            None            None
# 150293            None            None            None            None
# 150294            None            None            None            None
# 150295            None            None            None            None
# 150296            None            None            None            None
# 150297            None            None            None            None
# 150298            None            None            None            None
# 150299            None            None            None            None
# 150300            None            None            None            None
# 150301            None            None            None            None
# 150302            None            None            None            None
# 150303            None            None            None            None
# 150304            None            None            None            None
# 150305            None            None            None            None
# 150306            None            None            None            None
# 150307            None            None            None            None
# ...                ...             ...             ...             ...
# 150340            None            None            None            None
# 150341            None            None            None            None
# 150342            None            None            None            None
# 150343            None            None            None            None
# 150344            None            None            None            None
# 150345            None            None            None            None
# 150346            None            None            None            None
# 150347            None            None            None            None
# 150348            None            None            None            None
# 150291                1           coal              ...
# 150292                1           coal              ...
# 150293                1           coal              ...
# 150294                1           coal              ...
# 150295                1           coal              ...
# 150296                1           coal              ...
# 150297                1           coal              ...
# 150298                1           coal              ...
# 150299                1           coal              ...
# 150300                1           coal              ...
# 150301                1           coal              ...
# 150302                1           coal              ...
# 150303                1           coal              ...
# 150304                1           coal              ...
# 150305                1           coal              ...
# 150306                1           coal              ...
# 150307                1           coal              ...
# ...                 ...            ...              ...
# 150340                1           coal              ...
# 150341                1           coal              ...
# 150342                1           coal              ...
# 150343                1           coal              ...
# 150344                1           coal              ...
# 150345                1           coal              ...
# 150346                1           coal              ...
# 150347                1           coal              ...
# 150348                1           coal              ...
# 150349                1           coal              ...
# 150350                1           coal              ...
# 150351                1           coal              ...
# 150352                1           coal              ...
# 150353                1           coal              ...
# 150354                1           coal              ...
# 150355                1           coal              ...
# 150356                1           coal              ...
# 150357                1           coal              ...
# 150358                1           coal              ...
# 150359                1           coal              ...
# 150360                1           coal              ...
# 150361                1           coal              ...
# 150364                1           coal              ...
# 150365                1           coal              ...
# 150366                1           coal              ...
# 150367                1           coal              ...
# 150368                1           coal              ...
# 150369                1           coal              ...
# 150370                1           coal              ...
# 150371                1           coal              ...
#
#              sector_name  solid_fuel_gasification  startup_source_1  \
# 150276  Electric Utility                    False                NG
# 150277  Electric Utility                    False                NG
# 150280  Electric Utility                    False                NG
# 150281  Electric Utility                    False                NG
# 150282  Electric Utility                    False                NG
# 150283  Electric Utility                    False                NG
# 150284  Electric Utility                    False                NG
# 150285  Electric Utility                    False                NG
# 150286  Electric Utility                    False                NG
# 150287  Electric Utility                    False                NG
# 150288  Electric Utility                    False                NG
# 150289  Electric Utility                    False                NG
# 150290  Electric Utility                    False                NG
# 150291  Electric Utility                    False                NG
# 150292  Electric Utility                    False                NG
# 150293  Electric Utility                    False                NG
# 150294  Electric Utility                    False                NG
# 150295  Electric Utility                    False                NG
# 150296  Electric Utility                    False                NG
# 150297  Electric Utility                    False                NG
# 150298  Electric Utility                    False                NG
# 150299  Electric Utility                    False                NG
# 150300  Electric Utility                    False                NG
# 150301  Electric Utility                    False                NG
# 150302  Electric Utility                    False                NG
# 150303  Electric Utility                    False                NG
# 150304  Electric Utility                    False                NG
# 150305  Electric Utility                    False                NG
# 150306  Electric Utility                    False                NG
# 150307  Electric Utility                    False                NG
# ...                  ...                      ...               ...
# 150340  Electric Utility                    False                NG
# 150341  Electric Utility                    False                NG
# 150342  Electric Utility                    False                NG
# 150343  Electric Utility                    False                NG
# 150344  Electric Utility                    False                NG
# 150345  Electric Utility                    False                NG
# 150346  Electric Utility                    False                NG
# 150347  Electric Utility                    False                NG
# 150348  Electric Utility                    False                NG
# 150349  Electric Utility                    False                NG
# 150350  Electric Utility                    False                NG
# 150351  Electric Utility                    False                NG
# 150352  Electric Utility                    False                NG
# 150353  Electric Utility                    False                NG
# 150354  Electric Utility                    False                NG
# 150355  Electric Utility                    False                NG
# 150356  Electric Utility                    False                NG
# 150357  Electric Utility                    False                NG
# 150358  Electric Utility                    False                NG
# 150359  Electric Utility                    False                NG
# 150360  Electric Utility                    False                NG
# 150361  Electric Utility                    False                NG
# 150364  Electric Utility                    False                NG
# 150365  Electric Utility                    False                NG
# 150366  Electric Utility                    False                NG
# 150367  Electric Utility                    False                NG
# 150368  Electric Utility                    False                NG
# 150369  Electric Utility                    False                NG
# 150370  Electric Utility                    False                NG
# 150371  Electric Utility                    False                NG
#
#         startup_source_2  startup_source_3 startup_source_4  state    status  \
# 150276              None              None             None     CO  existing
# 150277              None              None             None     CO  existing
# 150280              None              None             None     CO  existing
# 150281              None              None             None     CO  existing
# 150282              None              None             None     CO  existing
# 150283              None              None             None     CO  existing
# 150284              None              None             None     CO  existing
# 150285              None              None             None     CO  existing
# 150286              None              None             None     CO  existing
# 150287              None              None             None     CO  existing
# 150288              None              None             None     CO  existing
# 150289              None              None             None     CO  existing
# 150290              None              None             None     CO  existing
# 150291              None              None             None     CO  existing
# 150292              None              None             None     CO  existing
# 150293              None              None             None     CO  existing
# 150294              None              None             None     CO  existing
# 150295              None              None             None     CO  existing
# 150296              None              None             None     CO  existing
# 150297              None              None             None     CO  existing
# 150298              None              None             None     CO  existing
# 150299              None              None             None     CO  existing
# 150300              None              None             None     CO  existing
# 150301              None              None             None     CO  existing
# 150302              None              None             None     CO  existing
# 150303              None              None             None     CO  existing
# 150304              None              None             None     CO  existing
# 150305              None              None             None     CO  existing
# 150306              None              None             None     CO  existing
# 150307              None              None             None     CO  existing
# ...                  ...               ...              ...    ...       ...
# 150340              None              None             None     CO  existing
# 150341              None              None             None     CO  existing
# 150342              None              None             None     CO  existing
# 150343              None              None             None     CO  existing
# 150344              None              None             None     CO  existing
# 150345              None              None             None     CO  existing
# 150346              None              None             None     CO  existing
# 150347              None              None             None     CO  existing
# 150348              None              None             None     CO  existing
# 150349              None              None             None     CO  existing
# 150350              None              None             None     CO  existing
# 150351              None              None             None     CO  existing
# 150352              None              None             None     CO  existing
# 150353              None              None             None     CO  existing
# 150354              None              None             None     CO  existing
# 150355              None              None             None     CO  existing
# 150356              None              None             None     CO  existing
# 150357              None              None             None     CO  existing
# 150358              None              None             None     CO  existing
# 150359              None              None             None     CO  existing
# 150360              None              None             None     CO  existing
# 150361              None              None             None     CO  existing
# 150364              None              None             None     CO  existing
# 150365              None              None             None     CO  existing
# 150366              None              None             None     CO  existing
# 150367              None              None             None     CO  existing
# 150368              None              None             None     CO  existing
# 150369              None              None             None     CO  existing
# 150370              None              None             None     CO  existing
# 150371              None              None             None     CO  existing
#
#         stoker_tech subcritical_tech summer_capacity_mw  \
# 150276         None             None              505.0
# 150277         None             None              505.0
# 150280         None             None              505.0
# 150281         None             None              505.0
# 150282         None             None              505.0
# 150283         None             None              505.0
# 150284         None             None              505.0
# 150285         None             None              505.0
# 150286         None             None              505.0
# 150287         None             None              505.0
# 150288         None             None              505.0
# 150289         None             None              505.0
# 150290         None             None              505.0
# 150291         None             None              505.0
# 150292         None             None              505.0
# 150357  3461756.714       NaN                              None
# 150358  3625952.032       NaN                              None
# 150359  3533729.165       NaN                              None
# 150360  2460277.656       NaN                              None
# 150361  2720453.246       NaN                              None
# 150364  1436983.820       NaN                              None
# 150365  3257684.564       NaN                              None
# 150366  3411359.592       NaN                              None
# 150367  3095988.084       NaN                              None
# 150368  2677530.924       NaN                              None
# 150369  3280819.428       NaN                              None
# 150370  3046130.612       NaN                              None
# 150371  3423119.696       NaN                              None
#
#         ultrasupercritical_tech  unit_code uprate_derate_completed_date  \
# 150276                     None       None                         None
# 150277                     None       None                         None
# 150280                     None       None                         None
# 150281                     None       None                         None
# 150282                     None       None                         None
# 150283                     None       None                         None
# 150284                     None       None                         None
# 150285                     None       None                         None
# 150286                     None       None                         None
# 150287                     None       None                         None
# 150288                     None       None                         None
# 150289                     None       None                         None
# 150290                     None       None                         None
# 150291                     None       None                         None
# 150292                     None       None                         None
# 150293                     None       None                         None
# 150294                     None       None                         None
# 150295                     None       None                         None
# 150296                     None       None                         None
# 150297                     None       None                         None
# 150298                     None       None                         None
# 150299                     None       None                         None
# 150300                     None       None                         None
# 150301                     None       None                         None
# 150302                     None       None                         None
# 150303                     None       None                         None
# 150304                     None       None                         None
# 150305                     None       None                         None
# 150306                     None       None                         None
# 150307                     None       None                         None
# ...                         ...        ...                          ...
# 150340                     None       None                         None
# 150341                     None       None                         None
# 150342                     None       None                         None
# 150343                     None       None                         None
# 150344                     None       None                         None
# 150345                     None       None                         None
# 150346                     None       None                         None
# 150347                     None       None                         None
# 150348                     None       None                         None
# 150349                     None       None                         None
# 150350                     None       None                         None
# 150351                     None       None                         None
# 150352                     None       None                         None
# 150353                     None       None                         None
# 150354                     None       None                         None
# 150355                     None       None                         None
# 150356                     None       None                         None
# 150357                     None       None                         None
# 150358                     None       None                         None
# 150359                     None       None                         None
# 150360                     None       None                         None
# 150361                     None       None                         None
# 150364                     None       None                         None
# 150365                     None       None                         None
# 150366                     None       None                         None
# 150367                     None       None                         None
# 150368                     None       None                         None
# 150369                     None       None                         None
# 150370                     None       None                         None
# 150371                     None       None                         None
#
#        uprate_derate_during_year winter_capacity_mw  \
# 150276                      None              505.0
# 150277                      None              505.0
# 150280                      None              505.0
# 150281                      None              505.0
# 150282                      None              505.0
# 150283                      None              505.0
# 150284                      None              505.0
# 150285                      None              505.0
# 150286                      None              505.0
# 150287                      None              505.0
# 150288                      None              505.0
# 150289                      None              505.0
# 150290                      None              505.0
# 150291                      None              505.0
# 150292                      None              505.0
# 150293                      None              505.0
# 150294                      None              505.0
# 150295                      None              505.0
# 150296                      None              505.0
# 150297                      None              505.0
# 150298                      None              505.0
# 150299                      None              505.0
# 150300                      None              505.0
# 150301                      None              505.0
# 150302                      None              505.0
# 150303                      None              505.0
# 150304                      None              505.0
# 150305                      None              505.0
# 150306                      None              505.0
# 150307                      None              505.0
# ...                          ...                ...
# 150340                     False              505.0
# 150341                     False              505.0
# 150342                     False              505.0
# 150343                     False              505.0
# 150344                     False              505.0
# 150345                     False              505.0
# 150346                     False              505.0
# 150347                     False              505.0
# 150348                     False              505.0
# 150349                     False              505.0
# 150350                     False              505.0
# 150351                     False              505.0
# 150352                     False              505.0
# 150353                     False              505.0
# 150354                     False              505.0
# 150355                     False              505.0
# 150356                     False              505.0
# 150357                     False              505.0
# 150358                     False              505.0
# 150359                     False              505.0
# 150360                     False              505.0
# 150361                     False              505.0
# 150364                     False              505.0
# 150365                     False              505.0
# 150366                     False              505.0
# 150367                     False              505.0
# 150368                     False              505.0
# 150369                     False              505.0
# 150370                     False              505.0
# 150371                     False              505.0
#
#        winter_estimated_capability_mw
# 150276                           None
# 150277                           None
# 150280                           None
# 150281                           None
# 150282                           None
# 150283                           None
# 150284                           None
# 150285                           None
# 150286                           None
# 150287                           None
# 150288                           None
# 150289                           None
# 150290                           None
# 150291                           None
# 150292                           None
# 150293                           None
# 150294                           None
# 150295                           None
# 150296                           None
# 150297                           None
# 150298                           None
# 150299                           None
# 150300                           None
# 150301                           None
# 150302                           None
# 150303                           None
# 150304                           None
# 150305                           None
# 150306                           None
# 150307                           None
# ...                               ...
# 150340                           None
# 150341                           None
# 150342                           None
# 150343                           None
# 150344                           None
# 150345                           None
# 150346                           None
# 150347                           None
# 150348                           None
# 150349                           None
# 150350                           None
# 150351                           None
# 150352                           None
# 150353                           None
# 150354                           None
# 150355                           None
# 150356                           None
# 150357                           None
# 150358                           None
# 150359                           None
# 150360                           None
# 150361                           None
# 150364                           None
# 150365                           None
# 150366                           None
# 150367                           None
# 150368                           None
# 150369                           None
# 150370                           None
# 150371                           None
#
# [90 rows x 91 columns]

# %%
cols = ['report_date', 'fuel_cost_per_mwh','capacity_factor']

comanche_1 = mcoe_out[(mcoe_out.plant_id_eia==470) & (mcoe_out.generator_id=='1')][cols]
comanche_2 = mcoe_out[(mcoe_out.plant_id_eia==470) & (mcoe_out.generator_id=='2')][cols]
comanche_3 = mcoe_out[(mcoe_out.plant_id_eia==470) & (mcoe_out.generator_id=='3')][cols]
hayden_1 = mcoe_out[(mcoe_out.plant_id_eia==525) & (mcoe_out.generator_id=='1')][cols]
hayden_2 = mcoe_out[(mcoe_out.plant_id_eia==525) & (mcoe_out.generator_id=='2')][cols]
pawnee = mcoe_out[(mcoe_out.plant_id_eia==6248)][cols]

comanche_ferc1 = pudl_out.plants_steam_ferc1()[(pf1.plant_name=='Comanche') & (pf1.respondent_id==145)]
hayden_ferc1 = pudl_out.plants_steam_ferc1()[(pf1.plant_name=='Hayden') & (pf1.respondent_id==145)]
pawnee_ferc1= pudl_out.plants_steam_ferc1()[(pf1.plant_name=='Pawnee') & (pf1.respondent_id==145)]

comanche_eia = mcoe_out[mcoe_out.plant_id_eia==470]
hayden_eia = mcoe_out[mcoe_out.plant_id_eia==525]
pawnee_eia = mcoe_out[mcoe_out.plant_id_eia==6248]

# %%
lwg_writer = pd.ExcelWriter('../leslie_glustrom/comanche_costs_for_lwg.xlsx')
comanche_ferc1.to_excel(lwg_writer, index=False, sheet_name='FERC Form 1')
comanche_eia.to_excel(lwg_writer, index=False, sheet_name='EIA Form 923')
lwg_writer.save()

# %%
plt.plot(pawnee.report_date, pawnee.capacity_factor, label='Pawnee')
plt.legend()
plt.show();

# %%
plt.plot(hayden_1.report_date, hayden_1.capacity_factor, label='Hayden 1')
plt.plot(hayden_2.report_date, hayden_2.capacity_factor, label='Hayden 2')
plt.legend()
plt.show();

# %%
plt.plot(comanche_1.report_date, comanche_1.capacity_factor, label='Comanche 1')
plt.plot(comanche_2.report_date, comanche_2.capacity_factor, label='Comanche 2')
plt.plot(comanche_3.report_date, comanche_3.capacity_factor, label='Comanche 3')
plt.legend()
plt.show();

# %%
plt.plot(pawnee.report_date, pawnee.fuel_cost_per_mwh, label='Pawnee')
#plt.ylim(12.5,25)
plt.legend()
plt.show()

# %%
plt.plot(hayden_1.report_date, hayden_1.fuel_cost_per_mwh, label='Hayden 1')
plt.plot(hayden_2.report_date, hayden_2.fuel_cost_per_mwh, label='Hayden 2')
#plt.ylim(12.5,25)
plt.legend()
plt.show()

# %%
plt.plot(comanche_1.report_date, comanche_1.fuel_cost_per_mwh, label='Comanche 1')
plt.plot(comanche_2.report_date, comanche_2.fuel_cost_per_mwh, label='Comanche 2')
plt.plot(comanche_3.report_date, comanche_3.fuel_cost_per_mwh, label='Comanche 3')
plt.ylim(12.5,25)
plt.legend()
plt.show()

# %%
comanche_ferc1.columns
# Out:
# Index(['report_year', 'respondent_id', 'util_id_pudl', 'respondent_name',
#        'plant_id_pudl', 'plant_name', 'asset_retirement_cost',
#        'avg_num_employees', 'construction_type', 'cost_equipment', 'cost_land',
#        'cost_per_mw', 'cost_structure', 'expns_allowances', 'expns_boiler',
#        'expns_coolants', 'expns_electric', 'expns_engineering', 'expns_fuel',
#        'expns_misc_power', 'expns_misc_steam', 'expns_operations',
#        'expns_per_mwh', 'expns_plants', 'expns_production_total',
#        'expns_rents', 'expns_steam', 'expns_steam_other', 'expns_structures',
#        'expns_transfer', 'id', 'net_generation_mwh', 'not_water_limited_mw',
#        'peak_demand_mw', 'plant_capability_mw', 'plant_hours', 'plant_kind',
#        'total_capacity_mw', 'total_cost_of_plant', 'water_limited_mw',
#        'year_constructed', 'year_installed'],
#       dtype='object')

# %%
plt.plot(hayden_ferc1.report_year, hayden_ferc1.expns_fuel/hayden_ferc1.net_generation_mwh, label="Hayden")
plt.plot(comanche_ferc1.report_year, comanche_ferc1.expns_fuel/comanche_ferc1.net_generation_mwh, label="Comanche")
plt.plot(pawnee_ferc1.report_year, pawnee_ferc1.expns_fuel/pawnee_ferc1.net_generation_mwh, label="Pawnee")
plt.legend()
plt.title("Reported FERC Form 1 Fuel Costs")
plt.ylim(0,30)
plt.ylabel('$ / MWh')
plt.xlabel('Year')
plt.show();

# %%
def hr_hist(mcoe_out, start_date, end_date,
            min_heat_rate=5.5, min_cap_fact=0.0, max_cap_fact=1.5):
    hr_good = mcoe_out[(mcoe_out.heat_rate_mmbtu_mwh >= min_heat_rate) &
                       (mcoe_out.report_date >= pd.to_datetime(start_date)) &
                       (mcoe_out.report_date < pd.to_datetime(end_date)) &
                       (mcoe_out.capacity_factor >= min_cap_fact) &
                       (mcoe_out.capacity_factor <= max_cap_fact)]
    hr_coal = hr_good[(hr_good.fuel_type_pudl=='coal')]
    hr_gas = hr_good[(hr_good.fuel_type_pudl=='gas')]
    plt.figure(figsize=(10,6))
    #plt.hist(hr_coal.heat_rate_mmbtu_mwh, weights=hr_coal.net_generation_mwh, bins=200, range=(5,15), label='Coal')
    #plt.hist(hr_gas.heat_rate_mmbtu_mwh, weights=hr_gas.net_generation_mwh, bins=200, range=(5,15), label='Gas', alpha=0.7)
    plt.hist(hr_coal.heat_rate_mmbtu_mwh, bins=200, range=(5,15), label='Coal')
    plt.hist(hr_gas.heat_rate_mmbtu_mwh, bins=200, range=(5,15), label='Gas', alpha=0.7)
    plt.legend()
    plt.xlabel('Heat rate (mmBTU / MWh)')
    plt.ylabel('MWh Generated')
    min_yr = hr_good.report_date.dt.year.min()
    max_yr = hr_good.report_date.dt.year.max()
    plt.title('Heat Rate by Generator ({}-{})'.format(min_yr, max_yr))
    plt.show();

# %%
hr_hist(mcoe_out, start_date=start_date, end_date=end_date,
        min_heat_rate=min_heat_rate, min_cap_fact=min_cap_fact, max_cap_fact=max_cap_fact)

# %%
int(3.5)
# Out:
# 3

# %%
def weight_array(ar, weights):
     zipped = zip(ar, weights)
     weighted = []
     for i in zipped:
         for j in range(int(i[1])):
             weighted.append(i[0])
     return weighted

# %%
np.percentile(weight_array(ar, weights), 25)

# %%
hr_gas = mcoe_out[mcoe_out.fuel_type_pudl=='gas']
hr_gas_weighted = weight_array(hr_gas.heat_rate_mmbtu_mwh, hr_gas.net_generation_mwh)
hr_coal = mcoe_out[mcoe_out.fuel_type_pudl=='coal']
hr_coal_weighted = weight_array(hr_coal.heat_rate_mmbtu_mwh, hr_coal.net_generation_mwh)
print('Gas, lower: {}'.format(stats.percentileofscore(hr_gas_weighted, 6.5)))
print('Gas, upper: {}'.format(stats.percentileofscore(hr_gas_weighted, 10.0)))
print('Coal, lower: {}'.format(stats.percentileofscore(hr_coal_weighted, 9.0)))
print('Coal, upper: {}'.format(stats.percentileofscore(hr_coal_weighted, 12.0)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-249-7d664709efc3> in <module>()
#       1 hr_gas = mcoe_out[mcoe_out.fuel_type_pudl=='gas']
# ----> 2 hr_gas_weighted = weight_array(hr_gas.heat_rate_mmbtu_mwh, hr_gas.net_generation_mwh)
#       3 hr_coal = mcoe_out[mcoe_out.fuel_type_pudl=='coal']
#       4 hr_coal_weighted = weight_array(hr_coal.heat_rate_mmbtu_mwh, hr_coal.net_generation_mwh)
#       5 print('Gas, lower: {}'.format(stats.percentileofscore(hr_gas_weighted, 6.5)))
#
# <ipython-input-248-08a65f6b9488> in weight_array(ar, weights)
#       4      for i in zipped:
#       5          for j in range(int(i[1])):
# ----> 6              weighted.append(i[0])
#       7      return weighted
#
# KeyboardInterrupt:

# %%
stats.percentileofscore()

# %%
fc_good = mcoe_out.dropna(subset=['fuel_cost_per_mwh','net_generation_mwh'])
fc_good = fc_good[fc_good.heat_rate_mmbtu_mwh >= min_heat_rate]
fc_good = fc_good[fc_good.capacity_factor >= 0.0]
#fc_good = fc_good[fc_good.fuel_cost_per_mwh > 0.0]
fc_coal = fc_good[(fc_good.fuel_type_pudl=='coal')]
fc_gas = fc_good[(fc_good.fuel_type_pudl=='gas')]
plt.figure(figsize=(10,6))
plt.hist(fc_coal.fuel_cost_per_mwh, weights=fc_coal.net_generation_mwh, range=(0,75), bins=150, label='Coal')
plt.hist(fc_gas.fuel_cost_per_mwh, weights=fc_gas.net_generation_mwh, range=(0,75), bins=150, label='Gas', alpha=0.7)
plt.legend()
plt.xlabel('($/MWh)')
plt.ylabel('MWh Generated')
min_yr = fc_good.report_date.dt.year.min()
max_yr = fc_good.report_date.dt.year.max()
plt.title('Fuel Cost by Generator ({}-{})'.format(min_yr, max_yr))
plt.show();

# %%
cf_good = mcoe_out[['report_date', 'plant_id_eia', 'generator_id', 'fuel_type_pudl', 'capacity_factor']]
cf_good = cf_good.dropna()
cf_coal = cf_good[(cf_good.fuel_type_pudl=='coal')]
cf_gas = cf_good[(cf_good.fuel_type_pudl=='gas')]
plt.figure(figsize=(10,6))
#plt.hist([cf_gas.capacity_factor, cf_coal.capacity_factor], range=(0.01,1.26), bins=125, stacked=True, label=["Gas","Coal"])
plt.hist(cf_coal.capacity_factor, range=(0.01,1.26), bins=125, label="Coal")
plt.hist(cf_gas.capacity_factor, range=(0.01,1.26), bins=125, alpha=0.7, label="Gas")
plt.ylabel('Generator Records')
plt.xlabel('Capacity Factor')
min_yr = cf_good.report_date.dt.year.min()
max_yr = cf_good.report_date.dt.year.max()
plt.title('Capacity Factor by Generator ({}-{})'.format(min_yr, max_yr))
plt.legend()
plt.show();

# %%
simple_cols = [
    'report_date',
    'plant_id_eia',
    'unit_id_pudl',
    'generator_id',
    'operator_name',
    'plant_name',
    'capacity_factor',
    'fuel_cost_per_mmbtu',
    'fuel_cost_per_mwh',
    'fuel_type_count',
    'fuel_type_pudl',
    'heat_rate_mmbtu_mwh',
    'nameplate_capacity_mw',
    'capacity_factor',
    'total_mmbtu',
]
mcoe_simple = mcoe_out[simple_cols]

# %%
len(mcoe_simple)
# Out:
# 37975

# %% [markdown]
# ##  Refine our base dataframes
# * Make sure all the dataframes have `unit_id_pudl` & `fuel_type_pudl`
# * Filter out boilers & generators that are not gas or coal fired for simplicity.

# %%
gens_simple = pudl_out.gens_eia860()[['report_date','plant_id_eia','generator_id','fuel_type_pudl']]
bga_gens = pudl_out.bga().drop(['boiler_id','unit_code','bga_source'], axis=1).drop_duplicates()
bga_boils = pudl_out.bga().drop(['generator_id','unit_code','bga_source'], axis=1).drop_duplicates()
gens_simple = pd.merge(gens_simple, bga_gens,
                       on=['report_date','plant_id_eia','generator_id'],
                       validate='one_to_one')

gen_eia923_cg = analysis.merge_on_date_year(pudl_out.gen_eia923(), gens_simple,
                                            on=['plant_id_eia','generator_id'],
                                            how='left')
gen_eia923_cg = gen_eia923_cg[gen_eia923_cg.fuel_type_pudl.isin(['gas','coal'])]

bf_eia923_cg = analysis.merge_on_date_year(pudl_out.bf_eia923(), bga_boils,
                                           on=['plant_id_eia','boiler_id'])
bf_eia923_cg = bf_eia923_cg[bf_eia923_cg.fuel_type_pudl.isin(['gas','coal'])]

frc_eia923_cg = pudl_out.frc_eia923()[pudl_out.frc_eia923().fuel_type_pudl.isin(['gas','coal'])]

mcoe_cg = mcoe_out[mcoe_out.fuel_type_pudl.isin(['gas','coal'])]

# %%
def mcoe_corr(before, after, x_max, y_max, r_max,
              xlabel='', ylabel='', title='', labels=[],
              alpha=0.5, s=3, loghist=True):
    
    plt.figure(figsize=(8,8))
    
    for b, a, l in zip(before, after, labels):
        plt.scatter(b, a, s=s, alpha=alpha, label=l)
    
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.xlim(-x_max/20,x_max)
    plt.ylim(-y_max/20,y_max)
    plt.legend()
    plt.show()
    
    plt.figure(figsize=(8,2))
    for b, a in zip(before, after):
        ratio = a/b
        plt.hist(ratio.dropna(), range=(0,r_max), bins=200, log=loghist, alpha=0.5)
    plt.xlim(0,r_max)
    plt.title('Ratio of reported to MCOE values')
    plt.show()

# %% [markdown]
# ## Net Generation: EIA923 vs. MCOE
# Net generation is reported on a per-generator basis, and we never transform it, so the quantities that show up in the MCOE output should match the inputs exactly.

# %%
gen_generator_compare = pd.merge(
    mcoe_cg[['report_date','plant_id_eia','generator_id','net_generation_mwh']],
    gen_eia923_cg[['report_date','plant_id_eia','generator_id','net_generation_mwh']],
    on=['report_date','plant_id_eia','generator_id'],
    suffixes=['_mcoe','_eia923'],
    validate='one_to_one'
)

mcoe_corr([gen_generator_compare.net_generation_mwh_eia923],
          [gen_generator_compare.net_generation_mwh_mcoe],
          x_max=1e6, y_max=1e6, r_max=1.1, alpha=0.25, s=5, loghist=True,
          xlabel='Net generation (MWh), gen_eia923',
          ylabel='Net generation (MWh), MCOE',
          title='Net generation: Reported vs. MCOE, by Generator',
          labels=['All fuels'])

# %% [markdown]
# ## Net Generation: EIA923 vs. MCOE (by Generation Unit)
# In calculating the net generation on a per generation unit basis, all we're doing is adding up all the generation from the individual generators that make up a unit.  So long as the unit-to-generator mapping is self consistent, this should also match up exactly, since we're not transforming the net generation.

# %%
before = gen_eia923_cg.groupby(['report_date', 'plant_id_eia', 'unit_id_pudl'])['net_generation_mwh'].sum().reset_index()
after = mcoe_cg.groupby(['report_date', 'plant_id_eia', 'unit_id_pudl'])['net_generation_mwh'].sum().reset_index()

gen_unit_compare = pd.merge(
    before[['report_date','plant_id_eia','unit_id_pudl','net_generation_mwh']],
    after[['report_date','plant_id_eia','unit_id_pudl','net_generation_mwh']],
    on=['report_date','plant_id_eia','unit_id_pudl'],
    suffixes=['_eia923','_mcoe'],
    validate='one_to_one'
)

mcoe_corr([gen_unit_compare.net_generation_mwh_eia923],
          [gen_unit_compare.net_generation_mwh_mcoe],
          x_max=1e6, y_max=1e6, r_max=1.5, s=5, alpha=0.25, loghist=True,
          xlabel='Net generation (MWh), gen_eia923',
          ylabel='Net generation (MWh), MCOE',
          title='Net generation: Reported vs. MCOE, by Unit',
          labels=['All fuels'])

# %% [markdown]
# ## Net Generation, EIA923 vs. MCOE (by Plant)
# When we aggregate the net generation at the plant level, we end up with a tiny mismatch. I suspect this is because there are some plants in which there are bad units or generator records within the MCOE output, so the plant level data gets kept, but only a portion of the generator or unit level net generation shows up in the MCOE output.

# %%
before = gen_eia923_cg.groupby(['report_date', 'plant_id_eia'])['net_generation_mwh'].sum().reset_index()
after = mcoe_cg.groupby(['report_date', 'plant_id_eia'])['net_generation_mwh'].sum().reset_index()

gen_plant_compare = pd.merge(
    before[['report_date','plant_id_eia','net_generation_mwh']],
    after[['report_date','plant_id_eia','net_generation_mwh']],
    on=['report_date','plant_id_eia'],
    suffixes=['_eia923','_mcoe'],
    validate='one_to_one'
)

mcoe_corr([gen_plant_compare.net_generation_mwh_eia923],
          [gen_plant_compare.net_generation_mwh_mcoe],
          x_max=2.5e6, y_max=2.5e6, r_max=2, alpha=0.05, s=5, loghist=True,
          xlabel='Net generation (MWh), gen_eia923',
          ylabel='Net generation (MWh), MCOE',
          title='Net generation: Reported vs. MCOE, by Plant',
          labels=['All fuels'])

# %% [markdown]
# ## Fuel consumed: EIA923 vs. MCOE (by Unit)
# Aggregating the original boiler fuel consumption data by generation unit and comparing that to the calculated fuel consumption in the MCOE output gives us a bigger spread. The per-unit fuel consumption in the MCOE output is derived from the calctulated per-unit heat rate and the per-unit net generation.  Because the reported boiler fuel consumption is gross -- the total fuel consumed -- and the electricity generation is net output, after parasitic loads of the plant are accounted for, these end up being a little bit of a mismatch.
#
# In theory, we could account for this parasitic fuel consumption at the plant level by using data from the generation_fuel_eia923 table, which indicates how much fuel was consumed for generation vs. non-generation, but in practice we care more about the effective heat rate and gross fuel consumption per net unit of electricity delivered to the grid, so for now we're not using the generation_fuel_eia923 information.

# %%
years = [2009,2010,2011,2012,2013,2014,2015,2016]
#years = [2009,2010,2011,2012,2013,2014]
#years = [2013,2014,2015,2016]
before = bf_eia923_cg.groupby(['report_date', 'plant_id_eia', 'unit_id_pudl', 'fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
before = before.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
before = before[before.report_date.dt.year.isin(years)]
after = mcoe_cg.groupby(['report_date', 'plant_id_eia', 'unit_id_pudl','fuel_type_pudl'])['total_mmbtu'].sum().reset_index()
after = after[after.report_date.dt.year.isin(years)]

mmbtu_unit_compare = pd.merge(
    before[['report_date','plant_id_eia','unit_id_pudl','fuel_type_pudl','total_mmbtu']],
    after[['report_date','plant_id_eia','unit_id_pudl','fuel_type_pudl','total_mmbtu']],
    on=['report_date','plant_id_eia','unit_id_pudl', 'fuel_type_pudl'],
    suffixes=['_eia923','_mcoe'],
    validate='one_to_one'
)

mcoe_corr([mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='coal'].total_mmbtu_eia923,
           mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_eia923],
          [mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='coal'].total_mmbtu_mcoe,
           mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_mcoe],
          x_max=1.0e7, y_max=1.0e7, r_max=3, alpha=0.05, s=10, loghist=True,
          xlabel='Fuel Consumed (mmBTU), bf_eia923',
          ylabel='Fuel Consumed (mmBTU), MCOE',
          title='Fuel consumed (mmBTU): Reported vs. MCOE, by Unit',
          labels=['Coal','Gas'])

# %%
years = [2009,2010,2011,2012,2013,2014,2015,2016]
#years = [2009,2010,2011,2012]
#years = [2015,2016]
before = bf_eia923_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
before = before.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
before = before[before.report_date.dt.year.isin(years)]
after = mcoe_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_mmbtu'].sum().reset_index()
after = after[after.report_date.dt.year.isin(years)]

mmbtu_plant_compare = pd.merge(
    before[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    after[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    on=['report_date','plant_id_eia','fuel_type_pudl'],
    suffixes=['_eia923','_mcoe'],
    validate='one_to_one'
)

mcoe_corr([mmbtu_plant_compare[mmbtu_plant_compare.fuel_type_pudl=='coal'].total_mmbtu_eia923,
           mmbtu_plant_compare[mmbtu_plant_compare.fuel_type_pudl=='gas'].total_mmbtu_eia923],
          [mmbtu_plant_compare[mmbtu_plant_compare.fuel_type_pudl=='coal'].total_mmbtu_mcoe,
           mmbtu_plant_compare[mmbtu_plant_compare.fuel_type_pudl=='gas'].total_mmbtu_mcoe],
          x_max=2.5e7, y_max=2.5e7, r_max=3, alpha=0.1, s=10, loghist=True,
          xlabel='Fuel Consumed (mmBTU), bf_eia923',
          ylabel='Fuel Consumed (mmBTU), MCOE',
          title='Fuel consumed (mmBTU): Reported vs. MCOE, by Plant',
          labels=['Coal','Gas'])

# %% [markdown]
# ## Delivered vs. Consumed Fuel in EIA923, by Plant
# The fuel_receipts_costs_eia923 data reports when fuel is delivered, and how much.  The boiler_fuel_eia923 data reports when fuel is consumed, and how much.  However, before 2015, the combustion turbine portion of combined cycle plants were not reporting their fuel consumption.  At the same time, their fuel deliveries were being reported.  This results in the lobe of gas near the x-axis in the plot below -- where the fuel is reported delivered, but no corresponding (or little corresponding) boiler consumption is reported.
#
# There's also a lag between fuel delivery and consumption, much moreseo for coal than for gas, so we see a big spread in the ratios of the coal, but not so much in the gas.

# %%
years = [2009,2010,2011,2012,2013,2014,2015,2016]
#years = [2015,2016]
before = frc_eia923_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
before = before.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
before = before[before.report_date.dt.year.isin(years)]
after = bf_eia923_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
after = after.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
after = after[after.report_date.dt.year.isin(years)]

mmbtu_unit_compare = pd.merge(
    before[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    after[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    on=['report_date','plant_id_eia','fuel_type_pudl'],
    suffixes=['_frc','_bf'],
    validate='one_to_one'
)

mcoe_corr([mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='coal'].total_mmbtu_frc,
           mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_frc],
          [mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='coal'].total_mmbtu_bf,
           mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_bf],
          x_max=2.5e7, y_max=2.5e7, r_max=2, alpha=0.03, s=10, loghist=True,
          xlabel='Fuel Delivered (mmBTU), frc_eia923',
          ylabel='Fuel Consumed (mmBTU), bf_eia923',
          title='Fuel (mmBTU): Delivered vs. Consumed, by Plant',
          labels=['Coal','Gas'])

# %% [markdown]
# ## Recent Gas consumed vs. delivered (Plant Level)
# Looking just at the 2015-2016 data, which includes all the combined cycle combustion turbine gas consumption, we get a much cleaner correspondence between delivered and consumed gas.

# %%
#years = [2009,2010,2011,2012,2013,2014,2015,2016]
years = [2015,2016]
before = frc_eia923_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
before = before.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
before = before[before.report_date.dt.year.isin(years)]
after = bf_eia923_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
after = after.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
after = after[after.report_date.dt.year.isin(years)]

mmbtu_unit_compare = pd.merge(
    before[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    after[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    on=['report_date','plant_id_eia','fuel_type_pudl'],
    suffixes=['_frc','_bf'],
    validate='one_to_one'
)

mcoe_corr([mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_frc],
          [mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_bf],
          x_max=1.0e7, y_max=1.0e7, r_max=2, alpha=0.03, s=10, loghist=True,
          xlabel='Fuel Delivered (mmBTU), frc_eia923',
          ylabel='Fuel Consumed (mmBTU), bf_eia923',
          title='Fuel (mmBTU): Delivered vs. Consumed, by Plant',
          labels=['Gas'])

# %% [markdown]
# ## EIA923 Fuel Delivered vs. MCOE Fuel Consumed, by Plant
# In order to calculate the fuel costs, we need to use the fuel deliveries, but we're attributing those costs based on the fuel consumed by each generation unit, as implied by its heat rate and net generation.  Both the lag between delivery and consumption, and the bad older combined cycle combustion turbine data make this a little messy.
#
# We can only use 2015-2016 data for combined cycle plants, and for coal really need to annualize the data to get a good correspondence between delivered and consumed fuel.

# %%
years = [2009,2010,2011,2012,2013,2014,2015,2016]
#years = [2015,2016]
before = frc_eia923_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
before = before.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
before = before[before.report_date.dt.year.isin(years)]
after = mcoe_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_mmbtu'].sum().reset_index()
after = after[after.report_date.dt.year.isin(years)]

mmbtu_unit_compare = pd.merge(
    before[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    after[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    on=['report_date','plant_id_eia','fuel_type_pudl'],
    suffixes=['_eia923','_mcoe'],
    validate='one_to_one'
)

mcoe_corr([mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='coal'].total_mmbtu_eia923,
           mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_eia923],
          [mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='coal'].total_mmbtu_mcoe,
           mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_mcoe],
          x_max=2.5e7, y_max=2.5e7, r_max=2, alpha=0.1, s=10, loghist=True,
          xlabel='Fuel Delivered (mmBTU), frc_eia923',
          ylabel='Fuel Consumed (mmBTU), MCOE',
          title='Fuel consumed (mmBTU): Delivered vs. MCOE, by Plant',
          labels=['Coal','Gas'])

# %% [markdown]
# ## Delivered (EIA923) vs. Consumed (MCOE) Fuel, 2015-2016 gas only
# Looking at just the recent gas data, we get a good correspondence between the delivered and consumed quantities, since there's not much of a time lag between delivery and consumption for gas, and all of the combined cycle gas is included for those most recent years.

# %%
#years = [2009,2010,2011,2012,2013,2014,2015,2016]
years = [2015,2016]
before = frc_eia923_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_heat_content_mmbtu'].sum().reset_index()
before = before.rename(columns={'total_heat_content_mmbtu': 'total_mmbtu'})
before = before[before.report_date.dt.year.isin(years)]
after = mcoe_cg.groupby(['report_date', 'plant_id_eia','fuel_type_pudl'])['total_mmbtu'].sum().reset_index()
after = after[after.report_date.dt.year.isin(years)]

mmbtu_unit_compare = pd.merge(
    before[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    after[['report_date','plant_id_eia','fuel_type_pudl','total_mmbtu']],
    on=['report_date','plant_id_eia','fuel_type_pudl'],
    suffixes=['_eia923','_mcoe'],
    validate='one_to_one'
)

mcoe_corr([mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_eia923],
          [mmbtu_unit_compare[mmbtu_unit_compare.fuel_type_pudl=='gas'].total_mmbtu_mcoe],
          x_max=1.0e7, y_max=1.0e7, r_max=2, alpha=0.1, s=10, loghist=True,
          xlabel='Fuel Delivered (mmBTU), frc_eia923',
          ylabel='Fuel Consumed (mmBTU), MCOE',
          title='Fuel consumed (mmBTU): Delivered vs. MCOE, by Plant',
          labels=['Gas'])

# %% [markdown]
# ## Fuel Costs, Delivered (EIA923) vs. Consumed (MCOE) by Fuel and Plant
# The cost of each fuel within each plant should be identical to the per-fuel, per-plant fuel costs reported in the fuel receipts and costs data, since that's the only source of cost data, and it's not being transformed.

# %%
years = [2009,2010,2011,2012,2013,2014,2015,2016]
#years = [2015,2016]

before = frc_eia923_cg.groupby(['report_date', 'plant_id_eia', 'fuel_type_pudl'])['total_fuel_cost'].sum().reset_index()
before = before[before.report_date.dt.year.isin(years)]

after = mcoe_cg.groupby(['report_date', 'plant_id_eia', 'fuel_type_pudl'])['total_fuel_cost'].sum().reset_index()
after = after[after.report_date.dt.year.isin(years)]

cost_compare= pd.merge(
    before[['report_date','plant_id_eia','total_fuel_cost','fuel_type_pudl']],
    after[['report_date','plant_id_eia','total_fuel_cost','fuel_type_pudl']],
    on=['report_date','plant_id_eia','fuel_type_pudl'],
    suffixes=['_eia923','_mcoe'],
    validate='one_to_one'
)

mcoe_corr([cost_compare[cost_compare.fuel_type_pudl=='coal'].total_fuel_cost_eia923,
           cost_compare[cost_compare.fuel_type_pudl=='gas'].total_fuel_cost_mcoe],
          [cost_compare[cost_compare.fuel_type_pudl=='coal'].total_fuel_cost_eia923,
           cost_compare[cost_compare.fuel_type_pudl=='gas'].total_fuel_cost_mcoe],
          x_max=6e7, y_max=6e7, r_max=2, alpha=0.05, s=10, loghist=True,
          xlabel='Delivered Fuel Cost (USD), frc_eia923',
          ylabel='Cosumed Fuel Cost (USD), MCOE',
          title='Fuel Costs Delivered vs. Consumed, by Plant',
          labels=['Coal','Gas'])

# %%
mcoe_out.columns.tolist()
# Out:
# ['report_date',
#  'plant_id_eia',
#  'plant_id_pudl',
#  'unit_id_pudl',
#  'generator_id',
#  'plant_name',
#  'operator_id',
#  'util_id_pudl',
#  'operator_name',
#  'associated_combined_heat_power',
#  'capacity_factor',
#  'carbon_capture',
#  'cofire_fuels',
#  'county',
#  'current_planned_operating_date',
#  'deliver_power_transgrid',
#  'duct_burners',
#  'energy_source_1',
#  'energy_source_2',
#  'energy_source_3',
#  'energy_source_4',
#  'energy_source_5',
#  'energy_source_6',
#  'fluidized_bed_tech',
#  'fuel_cost_per_mmbtu',
#  'fuel_cost_per_mwh',
#  'fuel_type_count',
#  'fuel_type_pudl',
#  'heat_bypass_recovery',
#  'heat_rate_mmbtu_mwh',
#  'latitude',
#  'longitude',
#  'minimum_load_mw',
#  'multiple_fuels',
#  'nameplate_capacity_mw',
#  'nameplate_power_factor',
#  'net_generation_mwh',
#  'operating_date',
#  'operating_switch',
#  'original_planned_operating_date',
#  'other_combustion_tech',
#  'other_modifications_date',
#  'other_planned_modifications',
#  'ownership',
#  'planned_derate_date',
#  'planned_energy_source_1',
#  'planned_modifications',
#  'planned_net_summer_capacity_derate_mw',
#  'planned_net_summer_capacity_uprate_mw',
#  'planned_net_winter_capacity_derate_mw',
#  'planned_net_winter_capacity_uprate_mw',
#  'planned_new_nameplate_capacity_mw',
#  'planned_new_prime_mover',
#  'planned_repower_date',
#  'planned_retirement_date',
#  'planned_uprate_date',
#  'previously_canceled',
#  'prime_mover',
#  'pulverized_coal_tech',
#  'retirement_date',
#  'rto_iso_lmp_node',
#  'rto_iso_location_wholesale_reporting',
#  'sector',
#  'sector_name',
#  'solid_fuel_gasification',
#  'startup_source_1',
#  'startup_source_2',
#  'startup_source_3',
#  'startup_source_4',
#  'state',
#  'status',
#  'stoker_tech',
#  'subcritical_tech',
#  'summer_capacity_mw',
#  'summer_estimated_capability_mw',
#  'supercritical_tech',
#  'switch_oil_gas',
#  'syncronized_transmission_grid',
#  'technology',
#  'time_cold_shutdown_full_load',
#  'topping_bottoming',
#  'total_fuel_cost',
#  'total_mmbtu',
#  'turbines',
#  'turbines_inverters_hydrokinetics',
#  'ultrasupercritical_tech',
#  'unit_code',
#  'uprate_derate_completed_date',
#  'uprate_derate_during_year',
#  'winter_capacity_mw',
#  'winter_estimated_capability_mw']

# %%
mcoe_simple_cols = [
    'report_date',
    'plant_id_eia',
    'plant_id_pudl',
    'unit_id_pudl',
    'generator_id',
    'plant_name',
    'operator_id',
    'util_id_pudl',
    'operator_name',
    'county',
    'state',
    'capacity_factor',
    'fuel_cost_per_mmbtu',
    'fuel_cost_per_mwh',
    'fuel_type_pudl',
    'net_generation_mwh',
    'heat_rate_mmbtu_mwh',
    'latitude',
    'longitude',
# 227740  2016-05-01         50707           3787             1          STB
# 227741  2016-06-01         50707           3787             1          STB
# 227742  2016-07-01         50707           3787             1          STB
# 227743  2016-08-01         50707           3787             1          STB
# 227744  2016-09-01         50707           3787             1          STB
# 227745  2016-10-01         50707           3787             1          STB
# 227746  2016-11-01         50707           3787             1          STB
# 227747  2016-12-01         50707           3787             1          STB
#
#                           plant_name  operator_id  util_id_pudl  \
# 4116                       Escalante        30151          3515
# 4117                       Escalante        30151          3515
# 4118                       Escalante        30151          3515
# 4119                       Escalante        30151          3515
# 4120                       Escalante        30151          3515
# 4121                       Escalante        30151          3515
# 4122                       Escalante        30151          3515
# 4123                       Escalante        30151          3515
# 4124                       Escalante        30151          3515
# 4125                       Escalante        30151          3515
# 4126                       Escalante        30151          3515
# 4127                       Escalante        30151          3515
# 4128                       Escalante        30151          3515
# 4129                       Escalante        30151          3515
# 4130                       Escalante        30151          3515
# 4131                       Escalante        30151          3515
# 4132                       Escalante        30151          3515
# 4133                       Escalante        30151          3515
# 4134                       Escalante        30151          3515
# 4135                       Escalante        30151          3515
# 4136                       Escalante        30151          3515
# 4137                       Escalante        30151          3515
# 4138                       Escalante        30151          3515
# 4139                       Escalante        30151          3515
# 4140                       Escalante        30151          3515
# 4141                       Escalante        30151          3515
# 4142                       Escalante        30151          3515
# 4143                       Escalante        30151          3515
# 4144                       Escalante        30151          3515
# 4145                       Escalante        30151          3515
# ...                              ...          ...           ...
# 227574  JM Shafer Generating Station        30151          3515
# 227575  JM Shafer Generating Station        30151          3515
# 227576  JM Shafer Generating Station        30151          3515
# 227577  JM Shafer Generating Station        30151          3515
# 227578  JM Shafer Generating Station        30151          3515
# 227579  JM Shafer Generating Station        30151          3515
# 227652  JM Shafer Generating Station        30151          3515
# 227653  JM Shafer Generating Station        30151          3515
# 227654  JM Shafer Generating Station        30151          3515
# 227655  JM Shafer Generating Station        30151          3515
# 227656  JM Shafer Generating Station        30151          3515
# 227657  JM Shafer Generating Station        30151          3515
# 227658  JM Shafer Generating Station        30151          3515
# 227659  JM Shafer Generating Station        30151          3515
# 227660  JM Shafer Generating Station        30151          3515
# 227661  JM Shafer Generating Station        30151          3515
# 227662  JM Shafer Generating Station        30151          3515
# 227663  JM Shafer Generating Station        30151          3515
# 227736  JM Shafer Generating Station        30151          3515
# 227737  JM Shafer Generating Station        30151          3515
# 227738  JM Shafer Generating Station        30151          3515
# 227739  JM Shafer Generating Station        30151          3515
# 227740  JM Shafer Generating Station        30151          3515
# 227741  JM Shafer Generating Station        30151          3515
# 227742  JM Shafer Generating Station        30151          3515
# 227743  JM Shafer Generating Station        30151          3515
# 227744  JM Shafer Generating Station        30151          3515
# 227745  JM Shafer Generating Station        30151          3515
# 227746  JM Shafer Generating Station        30151          3515
# 227747  JM Shafer Generating Station        30151          3515
#
#                     operator_name    county state  capacity_factor  \
# 4116    Tri-State G & T Assn, Inc  McKinley    NM         0.842371
# 4117    Tri-State G & T Assn, Inc  McKinley    NM         0.796426
# 227746              6452.0             9.471402   40.0986  -104.7736
# 227747              5488.0             9.349776   40.0986  -104.7736
#
#         minimum_load_mw prime_mover retirement_date  nameplate_capacity_mw  \
# 4116                NaN          ST            None                  257.0
# 4117                NaN          ST            None                  257.0
# 4118                NaN          ST            None                  257.0
# 4119                NaN          ST            None                  257.0
# 4120                NaN          ST            None                  257.0
# 4121                NaN          ST            None                  257.0
# 4122                NaN          ST            None                  257.0
# 4123                NaN          ST            None                  257.0
# 4124                NaN          ST            None                  257.0
# 4125                NaN          ST            None                  257.0
# 4126                NaN          ST            None                  257.0
# 4127                NaN          ST            None                  257.0
# 4128                NaN          ST            None                  257.0
# 4129                NaN          ST            None                  257.0
# 4130                NaN          ST            None                  257.0
# 4131                NaN          ST            None                  257.0
# 4132                NaN          ST            None                  257.0
# 4133                NaN          ST            None                  257.0
# 4134                NaN          ST            None                  257.0
# 4135                NaN          ST            None                  257.0
# 4136                NaN          ST            None                  257.0
# 4137                NaN          ST            None                  257.0
# 4138                NaN          ST            None                  257.0
# 4139                NaN          ST            None                  257.0
# 4140                NaN          ST            None                  257.0
# 4141                NaN          ST            None                  257.0
# 4142                NaN          ST            None                  257.0
# 4143                NaN          ST            None                  257.0
# 4144                NaN          ST            None                  257.0
# 4145                NaN          ST            None                  257.0
# ...                 ...         ...             ...                    ...
# 227574             30.0          CA            None                   52.2
# 227575             30.0          CA            None                   52.2
# 227576             30.0          CA            None                   52.2
# 227577             30.0          CA            None                   52.2
# 227578             30.0          CA            None                   52.2
# 227579             30.0          CA            None                   52.2
# 227652             30.0          CA            None                   52.2
# 227653             30.0          CA            None                   52.2
# 227654             30.0          CA            None                   52.2
# 227655             30.0          CA            None                   52.2
# 227656             30.0          CA            None                   52.2
# 227657             30.0          CA            None                   52.2
# 227658             30.0          CA            None                   52.2
# 227659             30.0          CA            None                   52.2
# 227660             30.0          CA            None                   52.2
# 227661             30.0          CA            None                   52.2
# 227662             30.0          CA            None                   52.2
# 227663             30.0          CA            None                   52.2
# 227736             30.0          CA            None                   52.2
# 227737             30.0          CA            None                   52.2
# 227738             30.0          CA            None                   52.2
# 227739             30.0          CA            None                   52.2
# 227740             30.0          CA            None                   52.2
# 227741             30.0          CA            None                   52.2
# 227742             30.0          CA            None                   52.2
# 227743             30.0          CA            None                   52.2
# 227744             30.0          CA            None                   52.2
# 227745             30.0          CA            None                   52.2
# 227746             30.0          CA            None                   52.2
# 227747             30.0          CA            None                   52.2
#
#           status                        technology  summer_capacity_mw  \
# 4116    existing                              None               247.0
# 4117    existing                              None               247.0
# 4118    existing                              None               247.0
# 4119    existing                              None               247.0
# 4120    existing                              None               247.0
# 4121    existing                              None               247.0
# 4122    existing                              None               247.0
# 4123    existing                              None               247.0
# 4124    existing                              None               247.0
# 4125    existing                              None               247.0
# 4126    existing                              None               247.0
# 4127    existing                              None               247.0
# 4128    existing                              None               247.0
# 4129    existing                              None               247.0
# 4130    existing                              None               247.0
# 4131    existing                              None               247.0
# 4132    existing                              None               247.0
# 4133    existing                              None               247.0
# 4134    existing                              None               247.0
# 4135    existing                              None               247.0
# 4136    existing                              None               247.0
# 4137    existing                              None               247.0
# 4138    existing                              None               247.0
# 4139    existing                              None               247.0
# 4140    existing                              None               247.0
# 4141    existing                              None               247.0
# 4142    existing                              None               247.0
# 4143    existing                              None               247.0
# 4144    existing                              None               247.0
# 4145    existing                              None               247.0
# ...          ...                               ...                 ...
# 227574  existing  Natural Gas Fired Combined Cycle                52.0
# 227575  existing  Natural Gas Fired Combined Cycle                52.0
# 227576  existing  Natural Gas Fired Combined Cycle                52.0
# 227577  existing  Natural Gas Fired Combined Cycle                52.0
# 227578  existing  Natural Gas Fired Combined Cycle                52.0
# 227579  existing  Natural Gas Fired Combined Cycle                52.0
# 227652  existing  Natural Gas Fired Combined Cycle                52.0
# 227653  existing  Natural Gas Fired Combined Cycle                52.0
# 227654  existing  Natural Gas Fired Combined Cycle                52.0
# 227655  existing  Natural Gas Fired Combined Cycle                52.0
# 227656  existing  Natural Gas Fired Combined Cycle                52.0
# 227657  existing  Natural Gas Fired Combined Cycle                52.0
# 227658  existing  Natural Gas Fired Combined Cycle                52.0
# 227659  existing  Natural Gas Fired Combined Cycle                52.0
# 227660  existing  Natural Gas Fired Combined Cycle                52.0
# 227661  existing  Natural Gas Fired Combined Cycle                52.0
# 227662  existing  Natural Gas Fired Combined Cycle                52.0
# 227663  existing  Natural Gas Fired Combined Cycle                52.0
# 227736  existing  Natural Gas Fired Combined Cycle                52.0
# 227737  existing  Natural Gas Fired Combined Cycle                52.0
# 227738  existing  Natural Gas Fired Combined Cycle                52.0
# 227739  existing  Natural Gas Fired Combined Cycle                52.0
# 227740  existing  Natural Gas Fired Combined Cycle                52.0
# 227741  existing  Natural Gas Fired Combined Cycle                52.0
# 227742  existing  Natural Gas Fired Combined Cycle                52.0
# 227743  existing  Natural Gas Fired Combined Cycle                52.0
# 227744  existing  Natural Gas Fired Combined Cycle                52.0
# 227745  existing  Natural Gas Fired Combined Cycle                52.0
# 227746  existing  Natural Gas Fired Combined Cycle                52.0
# 227747  existing  Natural Gas Fired Combined Cycle                52.0
#
#        time_cold_shutdown_full_load  total_fuel_cost   total_mmbtu  \
# 4116                           None     2.523366e+06  1.746646e+06
# 4117                           None     2.226487e+06  1.482037e+06
# 4118                           None     2.492681e+06  1.667874e+06
# 4119                           None     2.558948e+06  1.666351e+06
# 4120                           None     2.595876e+06  1.738126e+06
# 4121                           None     2.306348e+06  1.644518e+06
# 4122                           None     2.436028e+06  1.731183e+06
# 4123                           None     2.601557e+06  1.788759e+06
# 4124                           None     2.282905e+06  1.589807e+06
# 4125                           None     2.557831e+06  1.750410e+06
# 4126                           None     2.537450e+06  1.685792e+06
# 4127                           None     2.694754e+06  1.766222e+06
# 4128                           None     3.994033e+06  1.743535e+06
# 4129                           None     3.402018e+06  1.419114e+06
# 4130                           None     3.845282e+06  1.673584e+06
# 4131                           None     1.380830e+06  4.662052e+05
# 4132                           None     3.457408e+06  1.511614e+06
# 227660                52.0
# 227661                52.0
# 227662                52.0
# 227663                52.0
# 227736                52.0
# 227737                52.0
# 227738                52.0
# 227739                52.0
# 227740                52.0
# 227741                52.0
# 227742                52.0
# 227743                52.0
# 227744                52.0
# 227745                52.0
# 227746                52.0
# 227747                52.0
#
# [1665 rows x 30 columns]

# %%
tristate_mcoe.to_csv('TriState_CostByGenerator.csv')

# %%
len(pudl_out.gens_eia860())
# Out:
# 186584

# %%
pudl_out.frc_eia923().sample(10)
# Out:
#        report_date  plant_id_eia  plant_id_pudl                  plant_name  \
# 98279   2009-11-01         10620           3345         Carthage Energy LLC
# 119289  2011-08-01         55099           4410       NRG Sterlington Power
# 4345    2014-05-01           165           1354                        GREC
# 58152   2013-04-01          3504           2368               Stryker Creek
# 75176   2009-07-01          6195           2574   John Twitty Energy Center
# 28848   2015-05-01          1571           1843             Chalk Point LLC
# 146891  2015-02-01         57037           5466  Kemper County IGCC Project
# 69426   2012-04-01          6074            235                   Greenwood
# 33475   2010-05-01          1877           1912              George Johnson
# 94416   2016-05-01         10208           3175               Escanaba Mill
#
#         operator_id  util_id_pudl                         operator_name  \
# 98279          3085           802                   Carthage Energy LLC
# 119289        13886          2701             NRG Sterlington Power LLC
# 4345           7490          1913             Grand River Dam Authority
# 58152         55983          2329       Luminant Generation Company LLC
# 75176         17833          1265  City Utilities of Springfield - (MO)
# 28848         12628          2672                   NRG Chalk Point LLC
# 146891        12686           190                  Mississippi Power Co
# 69426         56211           161  KCP&L Greater Missouri Operations Co
# 33475         20910           369           Wolverine Power Supply Coop
# 94416         55867          3661                    Verso Escanaba LLC
#
#         ash_content_pct  fuel_cost_per_mmbtu  fuel_quantity fuel_type_pudl  \
# 98279          0.000000                  NaN         9951.0            gas
# 119289         0.000000                  NaN         1416.0            gas
# 4345           0.000000             4.890000        54091.0            gas
# 58152          0.000000                  NaN       133196.0            gas
# 75176          4.985147             2.247603        58642.0           coal
# 28848          7.806187                  NaN        66316.0           coal
# 146891         0.000000             2.960000      2449478.0            gas
# 69426          0.000000             2.009000        33391.0            gas
# 33475          0.000000             6.752000        20900.0            gas
# 94416          0.000000                  NaN       482343.0            gas
#
#         heat_content_mmbtu_per_unit  mercury_content_ppm  sulfur_content_pct  \
# 98279                      1.003140                  NaN            0.000000
# 119289                     1.030000                  NaN            0.000000
# 4345                       1.040000                  0.0            0.000000
# 58152                      1.014000                  NaN            0.000000
# 75176                     17.693406                  NaN            0.284257
# 28848                     26.123641                  0.0            2.650343
# 146891                     1.048000                  0.0            0.000000
# 69426                      1.000000                  0.0            0.000000
# 33475                      1.024000                  NaN            0.000000
# 94416                      1.000000                  0.0            0.000000
#
#         total_fuel_cost  total_heat_content_mmbtu
# 98279               NaN                  9982.244
# 119289              NaN                  1458.480
# 4345       2.750852e+05                 56254.640
# 58152               NaN                135060.744
# 75176      2.332061e+06               1037576.724
# 28848               NaN               1732415.360
# 146891     7.598477e+06               2567052.944
# 69426      6.708252e+04                 33391.000
# 33475      1.445036e+05                 21401.600
# 94416               NaN                482343.000

# %%
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# ProgrammingError: column coalmine_eia923.name does not exist
# LINE 1: SELECT coalmine_eia923.id, coalmine_eia923.name, coalmine_ei...
#                                    ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-257-4f964532b944> in <module>()
# ----> 1 hwe_out.frc_eia923().to_csv(os.path.join(settings.PUDL_DIR, 'results', 'notebooks', 'headwaters', 'HWE_frc_eia923.csv'),index=False)
#       2 hwe_out.gens_eia860().to_csv(os.path.join(settings.PUDL_DIR, 'results', 'notebooks', 'headwaters', 'HWE_gens_eia860.csv'), index=False)
#
# ~/code/catalyst/pudl/pudl/outputs.py in frc_eia923(self, update)
#     184
#     185     def frc_eia923(self, update=False):
# --> 186         return(self.fuel_receipts_costs_eia923(update=update))
#     187
#     188     def boiler_fuel_eia923(self, update=False):
#
# ~/code/catalyst/pudl/pudl/outputs.py in fuel_receipts_costs_eia923(self, update)
#     180                                            start_date=self.start_date,
#     181                                            end_date=self.end_date,
# --> 182                                            testing=self.testing)
#     183         return(self._dfs['frc_eia923'])
#     184
#
# ~/code/catalyst/pudl/pudl/outputs.py in fuel_receipts_costs_eia923(freq, testing, start_date, end_date)
#     866     cmi_tbl = pt['coalmine_eia923']
#     867     cmi_select = sa.sql.select([cmi_tbl, ])
# --> 868     cmi_df = pd.read_sql(cmi_select, pudl_engine)
#     869
#     870     if start_date is not None:
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     414             sql, index_col=index_col, params=params,
#     415             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 416             chunksize=chunksize)
#     417
#     418
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1090         args = _convert_params(sql, params)
#    1091
# -> 1092         result = self.execute(*args)
#    1093         columns = result.keys()
#    1094
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     981     def execute(self, *args, **kwargs):
#     982         """Simple passthrough to SQLAlchemy connectable"""
# --> 983         return self.connectable.execute(*args, **kwargs)
#     984
#     985     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2062
#    2063         connection = self.contextual_connect(close_with_result=True)
# -> 2064         return connection.execute(statement, *multiparams, **params)
#    2065
#    2066     def scalar(self, statement, *multiparams, **params):
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     943             raise exc.ObjectNotExecutableError(object)
#     944         else:
# --> 945             return meth(self, multiparams, params)
#     946
#     947     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     261     def _execute_on_connection(self, connection, multiparams, params):
#     262         if self.supports_execution:
# --> 263             return connection._execute_clauseelement(self, multiparams, params)
#     264         else:
#     265             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1051             compiled_sql,
#    1052             distilled_params,
# -> 1053             compiled_sql, distilled_params
#    1054         )
#    1055         if self._has_events or self.engine._has_events:
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1400                 util.raise_from_cause(
#    1401                     sqlalchemy_exception,
# -> 1402                     exc_info
#    1403                 )
#    1404             else:
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1180                         statement,
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#    1184             self._handle_dbapi_exception(
#
# ~/anaconda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     468
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#     472     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.ProgrammingError) column coalmine_eia923.name does not exist
# LINE 1: SELECT coalmine_eia923.id, coalmine_eia923.name, coalmine_ei...
#                                    ^
#  [SQL: 'SELECT coalmine_eia923.id, coalmine_eia923.name, coalmine_eia923.mine_type, coalmine_eia923.state, coalmine_eia923.county_fips_id, coalmine_eia923.mine_id \nFROM coalmine_eia923']
